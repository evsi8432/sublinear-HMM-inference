# %%
import sys
import os

import pandas as pd
import numpy as np
import numdifftools as ndt
import statsmodels.api as sm

import matplotlib.pyplot as plt
import matplotlib.cm as cm
from matplotlib.patches import Patch
from matplotlib.patches import Rectangle
from matplotlib.lines import Line2D
from matplotlib.dates import DateFormatter

from scipy.stats import gamma
from scipy.stats import norm
from scipy.stats import truncnorm
from scipy.stats import vonmises
from scipy.stats import multivariate_normal
from scipy.stats import gaussian_kde
from scipy.stats import circstd
from scipy.special import iv
from scipy.special import expit
from scipy.special import logit
from scipy.special import logsumexp
from scipy.optimize import minimize
from scipy.optimize import minimize_scalar
from scipy.optimize import LinearConstraint
from scipy.optimize import linear_sum_assignment
from scipy.signal import convolve
from scipy.interpolate import interp1d
from scipy.linalg import block_diag

from datetime import datetime
from time import gmtime, strftime

from math import isclose
from copy import deepcopy
from itertools import product
import importlib
import time
import pickle
import random

import helper_funcs
import HHMM
import optimizor
import stoch_optimizor

from helper_funcs import eta_2_log_Gamma
from helper_funcs import eta0_2_log_delta
from helper_funcs import log_Gamma_2_eta
from helper_funcs import log_delta_2_eta0

np.random.seed(0)
random.seed(0)

# %%
#date = "Sep-25-2022" # both buffers
#date = "Sept-21-2022_large"
#date = "Sep-21-2022" # Beth's case study
#date = "Sep-19-2022" # No buffer for mini-batches, no buffer for weights
#date = "Sep-15-2022" # Make a buffer for mini-batches, but not for weights
#date = "Sep-16-2022" # Make a buffer for weights, but not for mini-batches
#date = "normal/Oct-31-2022" # no buffers, step size = 1/L
#date = "large/Nov-01-2022" # no buffers, step size = 1/L
#date = "normal/Nov-14-2022" # no buffers, step size = 1/3L
#date = "large/Nov-14-2022" # no buffers, step size = 1/3L
#date = "updown/2023-04-07"
date = "updown/2023-04-14"

#param_folder = "/Volumes/One Touch/sublinear-HMM-inference/case_study/" + date
param_folder = "/Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/" + date
plot_folder = "/Users/evsi8432/Documents/Research/sublinear-HMM-inference/plt/case_study/" + date

methods = ["control","BFGS","SAGA","SVRG","GD","CG"]

K = [3,3]
#K = [2,3]

partial_Es = [0.0,0.5,1.0]

tol = 1e-2

optims = {}
times_to_converge = {}
epochs_to_converge = {}
lls = {}

#"experiment_1_2022-08-05_20-27-39"
#"experiment_1_2022-08-05_20-26-58"
#"experiment_1_2022-08-05_20-26-22"
#"experiment_1_2022-08-05_20-25-49"
#"experiment_1_2022-08-05_20-25-36"
#"experiment_1_2022-08-05_20-27-53"
#"experiment_1_2022-08-05_20-25-18"
#"experiment_1_2022-08-05_20-25-12"

#with open("../params/experiment_1_2022-08-05_20-25-49","rb") as f:
#    optims = pickle.load(f)

# %%
for method in methods:
    for partial_E in partial_Es:
        if method in ["BFGS","CG","GD","control"] and partial_E > 0.0:
            pass
        else:
            
            # get best ll
            best_ll = -np.infty
            best_fname = param_folder + "/case_study_updown_K-%d-%d_%s_%.1f_%03d" % (K[0],K[1],method,partial_E,0)
            #best_fname = param_folder + "/K-%d-%d_%s_%.1f_%03d" % (K[0],K[1],method,partial_E,0)
            
            # initialize lls
            lls[(method,partial_E)] = []
            
            # initialize epochs
            epochs_to_converge[(method,partial_E)] = []
            
            # initialize times
            times_to_converge[(method,partial_E)] = []
            
            for rand_seed in range(50):
                
                fname = param_folder + "/case_study_updown_K-%d-%d_%s_%.1f_%03d" % (K[0],K[1],method,partial_E,rand_seed)
                #fname = param_folder + "/K-%d-%d_%s_%.1f_%03d" % (K[0],K[1],method,partial_E,rand_seed)
                
                try:
                    with open(fname, 'rb') as f:
                        optim = pickle.load(f)
                    print("loaded file %s" % fname)
                except:
                    print("file %s does not exist" % fname)
                    epochs_to_converge[(method,partial_E)].append(np.nan)
                    times_to_converge[(method,partial_E)].append(np.nan)
                    lls[(method,partial_E)].append(np.nan)
                    continue
                
                # check for some issue (likely nan in theta)
                if len(optim.time_trace) == 0:
                    print("file %s didn't optimize." % fname)
                    epochs_to_converge[(method,partial_E)].append(np.nan)
                    times_to_converge[(method,partial_E)].append(np.nan)
                    lls[(method,partial_E)].append(np.nan)
                    continue
                    
                
                # get convergence ind
                converge_ind = min(np.where(np.array(optim.grad_norm_trace) < tol)[0],
                                   default=len(optim.grad_norm_trace)-1)
                
                epochs_to_converge[(method,partial_E)].append(optim.epoch_trace[converge_ind])
                times_to_converge[(method,partial_E)].append(optim.time_trace[converge_ind])
                lls[(method,partial_E)].append(optim.log_like_trace[converge_ind])
                
                if optim.log_like_trace[-1] > best_ll:    
                    optims[(method,partial_E)] = optim
                    best_fname = fname
                    best_ll = optim.log_like_trace[-1]
                    
            print(best_fname)
            print(best_ll)
# Out:
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_control_0.0_000
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_control_0.0_001
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_control_0.0_002
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_control_0.0_003
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_control_0.0_004
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_control_0.0_005
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_control_0.0_006
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_control_0.0_007
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_control_0.0_008
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_control_0.0_009
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_control_0.0_010
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_control_0.0_011
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_control_0.0_012
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_control_0.0_013
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_control_0.0_014
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_control_0.0_015
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_control_0.0_016
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_control_0.0_017
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_control_0.0_018
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_control_0.0_019
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_control_0.0_020
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_control_0.0_021
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_control_0.0_022
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_control_0.0_023
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_control_0.0_024
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_control_0.0_025
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_control_0.0_026
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_control_0.0_027
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_control_0.0_028
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_control_0.0_029
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_control_0.0_030
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_control_0.0_031
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_control_0.0_032
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_control_0.0_033
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_control_0.0_034
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_control_0.0_035
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_control_0.0_036
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_control_0.0_037
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_control_0.0_038
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_control_0.0_039
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_control_0.0_040
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_control_0.0_041
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_control_0.0_042
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_control_0.0_043
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_control_0.0_044
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_control_0.0_045
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_control_0.0_046
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_control_0.0_047
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_control_0.0_048
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_control_0.0_049
# /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_control_0.0_023
# -0.48120538366137316
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_BFGS_0.0_000
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_BFGS_0.0_001
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_BFGS_0.0_002
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_BFGS_0.0_003
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_BFGS_0.0_004
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_BFGS_0.0_005
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_BFGS_0.0_006
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_BFGS_0.0_007
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_BFGS_0.0_008
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_BFGS_0.0_009
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_BFGS_0.0_010
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_BFGS_0.0_011
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_BFGS_0.0_012
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_BFGS_0.0_013
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_BFGS_0.0_014
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_BFGS_0.0_015
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_BFGS_0.0_016
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_BFGS_0.0_017
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_BFGS_0.0_018
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_BFGS_0.0_019
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_BFGS_0.0_020
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_BFGS_0.0_021
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_BFGS_0.0_022
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_BFGS_0.0_023
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_BFGS_0.0_024
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_BFGS_0.0_025
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_BFGS_0.0_026
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_BFGS_0.0_027
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_BFGS_0.0_028
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_BFGS_0.0_029
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_BFGS_0.0_030
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_BFGS_0.0_031
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_BFGS_0.0_032
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_BFGS_0.0_033
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_BFGS_0.0_034
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_BFGS_0.0_035
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_BFGS_0.0_036
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_BFGS_0.0_037
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_BFGS_0.0_038
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_BFGS_0.0_039
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_BFGS_0.0_040
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_BFGS_0.0_041
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_BFGS_0.0_042
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_BFGS_0.0_043
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_BFGS_0.0_044
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_BFGS_0.0_045
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_BFGS_0.0_046
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_BFGS_0.0_047
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_BFGS_0.0_048
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_BFGS_0.0_049
# /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_BFGS_0.0_035
# -0.4810617223844701
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.0_000
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.0_001
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.0_002
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.0_003
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.0_004
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.0_005
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.0_006
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.0_007
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.0_008
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.0_009
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.0_010
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.0_011
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.0_012
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.0_013
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.0_014
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.0_015
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.0_016
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.0_017
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.0_018
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.0_019
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.0_020
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.0_021
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.0_022
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.0_023
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.0_024
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.0_025
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.0_026
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.0_027
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.0_028
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.0_029
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.0_030
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.0_031
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.0_032
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.0_033
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.0_034
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.0_035
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.0_036
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.0_037
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.0_038
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.0_039
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.0_040
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.0_041
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.0_042
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.0_043
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.0_044
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.0_045
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.0_046
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.0_047
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.0_048
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.0_049
# /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.0_040
# -0.48121429194790716
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.5_000
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.5_001
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.5_002
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.5_003
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.5_004
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.5_005
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.5_006
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.5_007
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.5_008
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.5_009
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.5_010
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.5_011
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.5_012
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.5_013
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.5_014
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.5_015
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.5_016
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.5_017
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.5_018
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.5_019
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.5_020
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.5_021
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.5_022
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.5_023
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.5_024
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.5_025
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.5_026
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.5_027
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.5_028
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.5_029
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.5_030
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.5_031
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.5_032
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.5_033
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.5_034
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.5_035
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.5_036
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.5_037
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.5_038
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.5_039
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.5_040
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.5_041
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.5_042
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.5_043
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.5_044
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.5_045
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.5_046
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.5_047
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.5_048
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.5_049
# /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_0.5_035
# -0.4812053361526417
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_1.0_000
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_1.0_001
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_1.0_002
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_1.0_003
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_1.0_004
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_1.0_005
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_1.0_006
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_1.0_007
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_1.0_008
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_1.0_009
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_1.0_010
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_1.0_011
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_1.0_012
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_1.0_013
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_1.0_014
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_1.0_015
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_1.0_016
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_1.0_017
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_1.0_018
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_1.0_019
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_1.0_020
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_1.0_021
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_1.0_022
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_1.0_023
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_1.0_024
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_1.0_025
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_1.0_026
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_1.0_027
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_1.0_028
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_1.0_029
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_1.0_030
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_1.0_031
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_1.0_032
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_1.0_033
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_1.0_034
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_1.0_035
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_1.0_036
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_1.0_037
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_1.0_038
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_1.0_039
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_1.0_040
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_1.0_041
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_1.0_042
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_1.0_043
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_1.0_044
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_1.0_045
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_1.0_046
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_1.0_047
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_1.0_048
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_1.0_049
# /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SAGA_1.0_040
# -0.4809909563185551
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.0_000
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.0_001
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.0_002
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.0_003
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.0_004
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.0_005
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.0_006
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.0_007
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.0_008
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.0_009
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.0_010
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.0_011
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.0_012
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.0_013
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.0_014
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.0_015
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.0_016
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.0_017
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.0_018
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.0_019
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.0_020
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.0_021
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.0_022
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.0_023
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.0_024
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.0_025
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.0_026
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.0_027
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.0_028
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.0_029
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.0_030
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.0_031
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.0_032
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.0_033
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.0_034
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.0_035
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.0_036
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.0_037
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.0_038
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.0_039
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.0_040
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.0_041
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.0_042
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.0_043
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.0_044
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.0_045
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.0_046
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.0_047
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.0_048
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.0_049
# /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.0_040
# -0.48120534742637955
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.5_000
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.5_001
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.5_002
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.5_003
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.5_004
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.5_005
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.5_006
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.5_007
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.5_008
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.5_009
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.5_010
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.5_011
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.5_012
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.5_013
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.5_014
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.5_015
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.5_016
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.5_017
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.5_018
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.5_019
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.5_020
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.5_021
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.5_022
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.5_023
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_0.5_024
# ...
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_1.0_041
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_1.0_042
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_1.0_043
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_1.0_044
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_1.0_045
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_1.0_046
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_1.0_047
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_1.0_048
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_1.0_049
# /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_SVRG_1.0_040
# -0.4812353261008536
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_GD_0.0_000
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_GD_0.0_001
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_GD_0.0_002
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_GD_0.0_003
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_GD_0.0_004
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_GD_0.0_005
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_GD_0.0_006
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_GD_0.0_007
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_GD_0.0_008
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_GD_0.0_009
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_GD_0.0_010
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_GD_0.0_011
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_GD_0.0_012
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_GD_0.0_013
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_GD_0.0_014
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_GD_0.0_015
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_GD_0.0_016
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_GD_0.0_017
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_GD_0.0_018
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_GD_0.0_019
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_GD_0.0_020
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_GD_0.0_021
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_GD_0.0_022
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_GD_0.0_023
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_GD_0.0_024
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_GD_0.0_025
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_GD_0.0_026
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_GD_0.0_027
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_GD_0.0_028
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_GD_0.0_029
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_GD_0.0_030
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_GD_0.0_031
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_GD_0.0_032
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_GD_0.0_033
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_GD_0.0_034
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_GD_0.0_035
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_GD_0.0_036
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_GD_0.0_037
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_GD_0.0_038
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_GD_0.0_039
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_GD_0.0_040
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_GD_0.0_041
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_GD_0.0_042
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_GD_0.0_043
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_GD_0.0_044
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_GD_0.0_045
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_GD_0.0_046
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_GD_0.0_047
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_GD_0.0_048
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_GD_0.0_049
# /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_GD_0.0_049
# -0.601657911264172
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_CG_0.0_000
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_CG_0.0_001
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_CG_0.0_002
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_CG_0.0_003
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_CG_0.0_004
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_CG_0.0_005
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_CG_0.0_006
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_CG_0.0_007
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_CG_0.0_008
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_CG_0.0_009
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_CG_0.0_010
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_CG_0.0_011
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_CG_0.0_012
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_CG_0.0_013
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_CG_0.0_014
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_CG_0.0_015
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_CG_0.0_016
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_CG_0.0_017
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_CG_0.0_018
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_CG_0.0_019
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_CG_0.0_020
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_CG_0.0_021
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_CG_0.0_022
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_CG_0.0_023
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_CG_0.0_024
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_CG_0.0_025
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_CG_0.0_026
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_CG_0.0_027
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_CG_0.0_028
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_CG_0.0_029
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_CG_0.0_030
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_CG_0.0_031
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_CG_0.0_032
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_CG_0.0_033
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_CG_0.0_034
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_CG_0.0_035
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_CG_0.0_036
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_CG_0.0_037
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_CG_0.0_038
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_CG_0.0_039
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_CG_0.0_040
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_CG_0.0_041
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_CG_0.0_042
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_CG_0.0_043
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_CG_0.0_044
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_CG_0.0_045
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_CG_0.0_046
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_CG_0.0_047
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_CG_0.0_048
# loaded file /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_CG_0.0_049
# /Users/evsi8432/Documents/Research/sublinear-HMM-inference/params/case_study/updown/2023-04-14/case_study_updown_K-3-3_CG_0.0_008
# -0.4869439144839029

# %%
methods = ["BFGS","CG","GD","SAGA","SVRG"]
cmap = cm.get_cmap('tab10')

linestyles = {("BFGS",0.0):("black","-"),
              ("CG",0.0)  :("black","--"),
              ("GD",0.0)  :("black",":"),
              ("SAGA",0.0):(cmap(0),"-"),
              ("SAGA",0.5):(cmap(0),"--"),
              ("SAGA",1.0):(cmap(0),":"),
              ("SVRG",0.0):(cmap(1),"-"),
              ("SVRG",0.5):(cmap(1),"--"),
              ("SVRG",1.0):(cmap(1),":")}

ll_star = optims[("BFGS",0.0)].log_like_trace[-1]
theta_star = optims[("BFGS",0.0)].theta
eta_star = optims[("BFGS",0.0)].eta
eta0_star = optims[("BFGS",0.0)].eta0

for key in optims:
    
    print(key)
    print(optims[key].log_like_trace[-1])
    
    if ll_star < optims[key].log_like_trace[-1]:
        
        print("control model has lower likelihood than a test model")
        
        update_ll = True
        for feature,k0,k1 in product(optims[key].features,range(optims[key].K[0]),range(optims[key].K[1])):
            if "log_sig" in optims[key].theta[k0][feature]:
                if optims[key].theta[k0][feature]['log_sig'][k1] < -5:
                    print("...but the test model has ~0 varaince. continuing...")
                    update_ll = False
                    break
                        
        if update_ll:
            ll_star = optims[key].log_like_trace[-1]
            Gamma_star = np.exp(optims[key].log_Gamma)
            theta_star = optims[key].theta
            eta_star = optims[key].eta
            eta0_star = optims[key].eta0
# Out:
# ('control', 0.0)
# -0.48120538366137316
# ('BFGS', 0.0)
# -0.4810617223844701
# ('SAGA', 0.0)
# -0.48121429194790716
# ('SAGA', 0.5)
# -0.4812053361526417
# ('SAGA', 1.0)
# -0.4809909563185551
# control model has lower likelihood than a test model
# ('SVRG', 0.0)
# -0.48120534742637955
# ('SVRG', 0.5)
# -0.48120535864043396
# ('SVRG', 1.0)
# -0.4812353261008536
# ('GD', 0.0)
# -0.601657911264172
# ('CG', 0.0)
# -0.4869439144839029

# %% [markdown]
# # boxplots

# %%
fig1, axs1 = plt.subplots(1,2,figsize = (8,4))

cmap = cm.get_cmap('tab10')
partial_Es = [0,0.5,1]

keys = [("SAGA",0.0),
        ("SAGA",0.5),
        ("SAGA",1.0),
        ("SVRG",0.0),
        ("SVRG",0.5),
        ("SVRG",1.0),
        ("BFGS",0.0)]

labs = ["FE","PE1","PE2","FE","PE1","PE2","C"]

data_to_plot = []
for key in keys:
    
    data_to_plot.append(epochs_to_converge[key])

box = axs1[0].boxplot(data_to_plot, 
                      whiskerprops=dict(color="black"),
                      medianprops=dict(color="black"),
                      patch_artist=True,
                      labels=labs)#['BFGS',0,0.5,1])

linestyles = {("BFGS",0.0):("black","-"),
              ("CG",0.0)  :("black","--"),
              ("GD",0.0)  :("black",":"),
              ("SAGA",0.0):(cmap(0),"-"),
              ("SAGA",0.5):(cmap(0),"--"),
              ("SAGA",1.0):(cmap(0),":"),
              ("SVRG",0.0):(cmap(1),"-"),
              ("SVRG",0.5):(cmap(1),"--"),
              ("SVRG",1.0):(cmap(1),":")}

for patch, key in zip(box['boxes'], keys):
    print(key)
    patch.set_facecolor(linestyles[key][0])
    patch.set_alpha(0.5)

axs1[0].set_ylabel("Epochs to Converge",fontsize=16)
axs1[0].set_ylim([0,150])
axs1[0].set_title("Epochs until Convergence",fontsize=16)
axs1[0].tick_params(axis='both', which='major', labelsize=12)

#######

data_to_plot = []
for key in keys:
    data_to_plot.append(ll_star - lls[key])

box = axs1[1].boxplot(data_to_plot, 
                       whiskerprops=dict(color="black"),
                       medianprops=dict(color="black"),
                       patch_artist=True,
                       labels=labs)#['BFGS',0,0.5,1])

linestyles = {("BFGS",0.0):("black","-"),
              ("CG",0.0)  :("black","--"),
              ("GD",0.0)  :("black",":"),
              ("SAGA",0.0):(cmap(0),"-"),
              ("SAGA",0.5):(cmap(0),"--"),
              ("SAGA",1.0):(cmap(0),":"),
              ("SVRG",0.0):(cmap(1),"-"),
              ("SVRG",0.5):(cmap(1),"--"),
              ("SVRG",1.0):(cmap(1),":")}

for patch, key in zip(box['boxes'], keys):
    patch.set_facecolor(linestyles[key][0])
    patch.set_alpha(0.5)

axs1[1].set_ylabel(r"$\frac{1}{T} \left[\ell(\phi^*) - \ell(\phi)\right]$",fontsize=16)
axs1[1].set_yscale("log")
#axs2.set_ylim([1e-8,1e0])
axs1[1].set_title("Loss at Convergence",fontsize=16)
axs1[1].tick_params(axis='both', which='major', labelsize=12)
axs1[1].yaxis.tick_right()


if not os.path.isdir(plot_folder):
    os.mkdir(plot_folder)

fig1.savefig(plot_folder + '/boxplots_case_study.png',dpi=500,bbox_inches='tight')
# Out:
# ('SAGA', 0.0)
# ('SAGA', 0.5)
# ('SAGA', 1.0)
# ('SVRG', 0.0)
# ('SVRG', 0.5)
# ('SVRG', 1.0)
# ('BFGS', 0.0)

# %%
fig1, axs1 = plt.subplots(1,1,figsize = (8,6))

cmap = cm.get_cmap('tab10')
partial_Es = [0,0.5,1]

keys = [("SAGA",0.0),
        ("SAGA",0.5),
        ("SAGA",1.0),
        ("SVRG",0.0),
        ("SVRG",0.5),
        ("SVRG",1.0),
        ("BFGS",0.0),
        ("CG",0.0)]

labs = ["BFGS",0,0.5,1,0,0.5,1]

# define linestyles
pointstyles = {("BFGS",0.0):("black","o"),
               ("CG",0.0)  :("black","s"),
               ("GD",0.0)  :("black","*"),
               ("SVRG",0.0):(cmap(1),"o"),
               ("SVRG",0.5):(cmap(1),"s"),
               ("SVRG",1.0):(cmap(1),"*"),
               ("SAGA",0.0):(cmap(0),"o"),
               ("SAGA",0.5):(cmap(0),"s"),
               ("SAGA",1.0):(cmap(0),"*")}

legend_elem = {("BFGS",0.0): "BFGS",
               ("CG",0.0)  : "Conjugate Gradient",
               ("GD",0.0)  : "GD",
               ("SVRG",0.0): "SVRG-FE, M=T",
               ("SVRG",0.5): "SVRG-PE, M=T",
               ("SVRG",1.0): "SVRG-PE, M=10T",
               ("SAGA",0.0): "SAGA-FE, M=T",
               ("SAGA",0.5): "SAGA-PE, M=T",
               ("SAGA",1.0): "SAGA-PE, M=10T"}

# get data
epochs_to_plot = []
for key in keys:
    epochs_to_plot.append(epochs_to_converge[key])

lls_to_plot = []
for key in keys:
    lls_to_plot.append(ll_star - lls[key])

# plot data
for key,epoch_data,ll_data in zip(keys,epochs_to_plot,lls_to_plot):
    axs1.scatter(epoch_data,ll_data,
                 color = pointstyles[key][0],
                 marker = pointstyles[key][1])

# adjust axes
axs1.set_yscale('log')
axs1.set_ylabel(r"$\frac{1}{T} \left[\ell(\phi^*) - \ell(\phi)\right]$",fontsize=16)
axs1.set_xlabel("Epochs to converge",fontsize=16)
axs1.set_xlim([0,None])

axs1.tick_params(axis='both', which='major', labelsize=14)
axs1.tick_params(axis='both', which='minor', labelsize=14)

fig1.legend([legend_elem[key] for key in keys],
            loc='upper center', 
            fontsize=14,
            bbox_to_anchor=(0.5, 1.06),
            ncol=3)

#axs1.legend([legend_elem[key] for key in keys],fontsize=12)

if not os.path.isdir(plot_folder):
    os.mkdir(plot_folder)

fig1.savefig(plot_folder + '/scatterplot_case_study.png',dpi=500,bbox_inches='tight')

# %%
fig, axs = plt.subplots(3,4,figsize = (12,9))

ylabs = {("SAGA",0.0) : "Full E, M=T",
         ("SAGA",0.5) : "Partial E, M=T",
         ("SAGA",1.0) : "Partial E, M=10T",} 

keys = [("BFGS",0.0),("SVRG",0.0),("SVRG",0.5),("SVRG",1.0),("SAGA",0.0),("SAGA",0.5),("SAGA",1.0)]

for i,key in enumerate(keys):
    
    if key == ("BFGS",0.0):
        continue
    elif key[0] == "SAGA":
        yind = i-4
        xind = 0
    else:
        yind = i-1
        xind = 2
    
    axs[yind,xind].scatter(epochs_to_converge[('BFGS', 0.0)],
                           epochs_to_converge[key],
                           color = pointstyles[key][0],
                           marker = pointstyles[key][1])
    
    max_epochs = max(axs[yind,xind].get_xlim()[1],axs[yind,xind].get_ylim()[1])
    axs[yind,xind].plot([0,max_epochs],[0,max_epochs],'k')
    
    if yind == 0:
        axs[yind,xind].set_title("Epochs to Converge",fontsize=16)
    if yind == 2:
        axs[yind,xind].set_xlabel("BFGS",fontsize=16)
    if xind == 0:
        axs[yind,xind].set_ylabel(ylabs[key],fontsize=16)
        
    axs[yind,xind].tick_params(axis='both', which='major', labelsize=11)
    axs[yind,xind].tick_params(axis='both', which='minor', labelsize=11)
    
    axs[yind,xind+1].scatter([-x for x in lls[('BFGS', 0.0)]],
                             [-x for x in lls[key]],
                              color = pointstyles[key][0],
                              marker = pointstyles[key][1])
    
    #axs[yind,xind+1].set_xlim([3.1,3.2])
    #axs[yind,xind+1].set_ylim([3.1,3.2])
    
    max_epochs = max(axs[yind,xind+1].get_xlim()[1],axs[yind,xind+1].get_ylim()[1])
    min_epochs = min(axs[yind,xind+1].get_xlim()[0],axs[yind,xind+1].get_ylim()[0])
    axs[yind,xind+1].plot([min_epochs,max_epochs],[min_epochs,max_epochs],'k')
    
    if yind == 0:
        axs[yind,xind+1].set_title("Loss at Convergence",fontsize=16)
    if yind == 2:
        axs[yind,xind+1].set_xlabel("BFGS",fontsize=16)
        
    axs[yind,xind+1].tick_params(axis='both', which='major', labelsize=11)
    axs[yind,xind+1].tick_params(axis='both', which='minor', labelsize=11)

        
fig.savefig(plot_folder + '/paired_scatterplot_case_study.png',dpi=500,bbox_inches='tight')

# %% [markdown]
# # Plot Results

# %%
def find_perm(optim,eta_star,theta_star):
    
    # get the coarse-scale permutation of states
    cost_matrix = np.zeros((optim.K[0],optim.K[0]))
    
    # get the coarse-scale permutation
    Gamma_coarse_star = np.exp(eta_2_log_Gamma(eta_star)[0])
    Gamma_fine_star = np.exp(eta_2_log_Gamma(eta_star)[1])

    Gamma_coarse_optm = np.exp(eta_2_log_Gamma(optim.eta)[0])
    Gamma_fine_optm = np.exp(eta_2_log_Gamma(optim.eta)[1])

    # get the trace of each fine-scale ptm
    for k0_star in range(optim.K[0]):
        square_dists = np.zeros(optim.K[0])
        for k0_optm in range(optim.K[0]):
            square_dists[k0_optm] += (Gamma_coarse_star[k0_star,k0_star] - \
                                      Gamma_coarse_optm[k0_optm,k0_optm])**2 
            square_dists[k0_optm] += (np.trace(Gamma_fine_star[k0_star]) - \
                                      np.trace(Gamma_fine_optm[k0_optm]))**2 

        cost_matrix[k0_star] = square_dists

    star_states_coarse, optim_states_coarse = linear_sum_assignment(cost_matrix)

    # get the fine-scale permutations
    star_states_fine = [None for _ in range(optim.K[0])]
    optim_states_fine = [None for _ in range(optim.K[0])]

    for k0_star in range(optim.K[0]):
        k0_optm = optim_states_coarse[k0_star]

        # get the fine-scale permutation of states
        cost_matrix = np.zeros((optim.K[1],optim.K[1]))

        # get the fine-scale permutation
        Gamma_fine_star = np.exp(eta_2_log_Gamma(eta_star)[1][k0_star])
        Gamma_fine_optm = np.exp(eta_2_log_Gamma(optim.eta)[1][k0_optm])

        for k1_star in range(optim.K[1]):
            square_dists = np.zeros(optim.K[1])
            for k1_optm in range(optim.K[1]):
                for feature in ['delt_d']:#optim.features:
                    square_dists[k1_optm] += (theta_star[k0_star][feature]['mu'][k1_star] - \
                                              optim.theta[k0_optm][feature]['mu'][k1_optm])**2 
                    square_dists[k1_optm] += (np.exp(theta_star[k0_star][feature]['log_sig'][k1_star]) - \
                                              np.exp(optim.theta[k0_optm][feature]['log_sig'][k1_optm]))**2 
                square_dists[k1_optm] += (Gamma_fine_star[k1_star,k1_star] - \
                                          Gamma_fine_optm[k1_optm,k1_optm])**2 

            cost_matrix[k1_star] = square_dists

        star_states_fine[k0_star], optim_states_fine[k0_optm] = linear_sum_assignment(cost_matrix)

    return optim_states_coarse,optim_states_fine

# %%
def find_distances(optim,theta_star,eta_star,eta0_star):

    # get permutation
    optim_states_coarse,optim_states_fine = find_perm(optim,eta_star,theta_star)
    
    # now get distances
    square_dists = np.zeros(len(optim.epoch_trace))

    Gamma_coarse_star = np.exp(eta_2_log_Gamma(eta_star)[0])
    Gamma_fine_star = np.exp(eta_2_log_Gamma(eta_star)[1])

    delta_coarse_star = np.exp(eta0_2_log_delta(eta0_star)[0])
    delta_fine_star = np.exp(eta0_2_log_delta(eta0_star)[1])

    for i in range(len(optim.epoch_trace)):

        # add theta
        for k0_star in range(optim.K[0]):
            k0_optm = optim_states_coarse[k0_star]
            for k1_star in range(optim.K[1]):
                k1_optm = optim_states_fine[k0_optm][k1_star]
                for feature in ['delt_d']:#optim.features:
                    square_dists[i] += (theta_star[k0_star][feature]['mu'][k1_star] - \
                                        optim.theta_trace[i][k0_optm][feature]['mu'][k1_optm])**2 
                    square_dists[i] += (np.exp(theta_star[k0_star][feature]['log_sig'][k1_star]) - \
                                        np.exp(optim.theta_trace[i][k0_optm][feature]['log_sig'][k1_optm]))**2 

        
        # get Gamma and delta
        Gamma_coarse_optm = np.exp(eta_2_log_Gamma(optim.eta_trace[i])[0])
        Gamma_fine_optm = np.exp(eta_2_log_Gamma(optim.eta_trace[i])[1])

        delta_coarse_optm = np.exp(eta0_2_log_delta(optim.eta0_trace[i])[0])
        delta_fine_optm = np.exp(eta0_2_log_delta(optim.eta0_trace[i])[1])

        # add coarse Gamma and delta
        for i_star in range(optim.K[0]):
            i_optm = optim_states_coarse[i_star]

            for j_star in range(optim.K[0]):
                j_optm = optim_states_coarse[j_star]

                square_dists[i] += (Gamma_coarse_star[i_star,j_star] - \
                                    Gamma_coarse_optm[i_optm,j_optm])**2

            # BUG IN CODE NEED TO FIX :(
            #square_dists[i] += (delta_coarse_star[i_star] - \
            #                    delta_coarse_optm[i_optm])**2
            

        # add fine Gamma and delta
        for k0_star in range(optim.K[0]):
            k0_optm = optim_states_coarse[k0_star]

            for i_star in range(optim.K[1]):
                i_optm = optim_states_fine[k0_optm][i_star]

                for j_star in range(optim.K[1]):
                    j_optm = optim_states_fine[k0_optm][j_star]

                    square_dists[i] += (Gamma_fine_star[k0_star][i_star,j_star] - \
                                        Gamma_fine_optm[k0_optm][i_optm,j_optm])**2

                # BUG IN CODE NEED TO FIX :(
                #square_dists[i] += (delta_fine_star[k0_star][i_star] - \
                #delta_fine_optm[k0_optm][i_optm])**2
                
    return square_dists

# %%
def plot_dists(optims,theta_star,eta_star,eta0_star,x_time=False,xlims=None,ylims=None):
    
    legend = []
    plt.figure(figsize=(8,6))
    
    for method in methods:
        
        for partial_E in [0,0.5,1]:
            
            PE = (partial_E == 0.5) or (partial_E == 1)
            M = int(partial_E == 0) + int(partial_E == 0.5) + 10*(partial_E == 1)
            
            if (method,partial_E) in optims:
                
                optim = optims[(method,partial_E)]
                lcol = linestyles[(method,partial_E)][0]
                ltyp = linestyles[(method,partial_E)][1]
                
                dists = find_distances(optim,theta_star,eta_star,eta0_star)
                
                if x_time:
                    plt.plot(optim.time_trace,dists,
                             color=lcol,linestyle=ltyp)
                else:
                    plt.plot(optim.epoch_trace,dists,
                             color=lcol,linestyle=ltyp)   
                title = method 
                if partial_E:
                    title += ", partial E"
                else:
                    title += ", no partial E"
                title += ", M = %dT" % M
                
                legend.append(title)
                
    plt.ylabel(r"$||(\theta^*, \eta^*) - (\theta, \eta)||^2_2$")
    plt.yscale("log")
    plt.legend(legend,loc='upper center', bbox_to_anchor=(0.5, 1.2),
               ncol=3)
    #plt.legend(legend)
    
    if x_time:
        plt.xlabel("Seconds of Computation")
        plt.savefig(plot_folder + "/dist_v_time_K-%d-%d.png"%(K[0],K[1]),dpi=500,bbox_inches='tight')
    else:
        plt.xlabel("Epoch")
        plt.savefig(plot_folder + "/dist_v_epoch_K-%d-%d.png"%(K[0],K[1]),dpi=500,bbox_inches='tight')
        
    if not xlims is None:
        plt.xlim(xlims)
    if not ylims is None:
        plt.ylim(ylims)
        
    plt.show()
                
    return

# %%
def plot_results(optim,ll_star,method,partial_E,M,features,iters=None):
    
    title = method 
    if partial_E:
        title += ", partial E-step"
    else:
        title += ", no partial E"
    title += ", M = %dT" % M
    
    if iters is None:
        iters=len(optim.theta_trace)
        
    x = optim.epoch_trace
    
    # plot log of gradient of log-likelihood
    plt.plot(optim.epoch_trace,np.log10(optim.grad_norm_trace))
    plt.axhline(-3, c = 'k', linestyle = "--")
    plt.title(r"$\log_{10}$ of Gradient Norm v Epoch, %s" % title)
    plt.xlabel("Epoch (k)")
    plt.ylabel(r"$\log ||\widehat \nabla_\theta F^{(k,m)} + \widehat \nabla_\eta G^{(k,m)}||$")
    plt.savefig(plot_folder + "/grad-hat-ll-%s-%s-K-%d-%d.png"%(method,partial_E,K[0],K[1]),dpi=500,bbox_inches='tight')
    plt.show()
    
    for feature in features:
        
        # plot means
        legend = []
        for k0 in range(optim.K[0]):
            for k1 in range(optim.K[1]):
                plt.plot(x,[optim.theta_trace[t][k0][feature]['mu'][k1] for t in range(len(optim.theta_trace))])
                legend.append(r"$\mu^{(%d,%d)}$"%(k0+1,k1+1))

        plt.title(feature + r" $\mu$ v Epoch, %s" % title)
        plt.xlabel("Epoch")
        plt.legend(legend)
        plt.savefig(plot_folder + "/mu-%s-%s-%d-K-%d-%d.png"%(method,partial_E,M,K[0],K[1]),dpi=500,bbox_inches='tight')
        plt.show()

        # plot log(sigma)
        legend = []
        for k0 in range(optim.K[0]):
            for k1 in range(optim.K[1]):
                plt.plot(x,[optim.theta_trace[t][k0][feature]['log_sig'][k1] for t in range(len(optim.theta_trace))])
                legend.append(r"$\log\left(\sigma^{(%d,%d)}\right)$"%(k0+1,k1+1))

        plt.title(feature + r" $\log\left(\sigma\right)$ v Epoch, %s" % title)
        plt.xlabel("Epoch")
        plt.legend(legend)
        plt.savefig(plot_folder + "/log-sig-%s-%s-%d-K-%d-%d.png"%(method,partial_E,M,K[0],K[1]),dpi=500,bbox_inches='tight')
        plt.show()
    
    # plot eta_coarse
    legend = []
    for k in range(optim.K[0]):
        for l in range(optim.K[0]):
            if k != l:
                plt.plot(x,[optim.eta_trace[i][0][k,l] for i in range(len(optim.eta_trace))])
                legend.append(r"$\eta^{(%d,%d)}$" % (k+1,l+1))
    plt.title(r"$\eta$ v Epoch, %s" % title)
    plt.xlabel("Epoch")
    plt.legend(legend)
    plt.savefig(plot_folder + "/eta-%s-%s-%d-K-%d-%d.png"%(method,partial_E,M,K[0],K[1]),dpi=500,bbox_inches='tight')
    plt.show()
    
    # plot eta_fine
    legend = []
    for k0 in range(optim.K[0]):
        for i in range(optim.K[1]):
            for j in range(optim.K[1]):
                if i != j:
                    plt.plot(x,[optim.eta_trace[t][1][k0][i,j] for t in range(len(optim.eta_trace))])
                    legend.append(r"$\eta_%d^{*(%d,%d)}$" % (k0,i+1,j+1))
    plt.title(r"$\eta^*$ v Epoch, %s" % title)
    plt.xlabel("Epoch")
    plt.legend(legend)
    plt.savefig(plot_folder + "/eta-fine-%s-%s-%d-K-%d-%d.png"%(method,partial_E,M,K[0],K[1]),dpi=500,bbox_inches='tight')
    plt.show()
    
    #plt.plot([optim.grad_theta_trace[i][0]['Y']['log_sig'][0] for i in range(len(optim.theta_trace))])
    #plt.plot([optim.grad_theta_trace[i][0]['Y']['log_sig'][1] for i in range(len(optim.theta_trace))])
    #plt.plot([optim.grad_theta_trace[i][0]['Y']['log_sig'][2] for i in range(len(optim.theta_trace))])
    #plt.title("Gradients of Standard Deviations v iteration number")
    #plt.show()

# %%
def plot_ll(optims,x_time=False,xlims=None,ylims=None):
    
    labels = {("SAGA",0.0): "SAGA-FE, M=T",
          ("SAGA",0.5): "SVRG-PE, M=T",
          ("SAGA",1.0): "SVRG-PE, M=10T",
          ("SVRG",0.0): "SVRG-FE, M=T",
          ("SVRG",0.5): "SVRG-PE, M=T",
          ("SVRG",1.0): "SVRG-PE, M=10T",
          ("BFGS",0.0): "BFGS",
          ("CG",0.0)  : "Conjugate Gradient",
          ("GD",0.0)  : "Gradient Descent",}
    
    linestyles = {("BFGS",0.0):("black","-"),
              ("CG",0.0)  :("black","--"),
              ("GD",0.0)  :("black",":"),
              ("SAGA",0.0):(cmap(0),"-"),
              ("SAGA",0.5):(cmap(0),"--"),
              ("SAGA",1.0):(cmap(0),":"),
              ("SVRG",0.0):(cmap(1),"-"),
              ("SVRG",0.5):(cmap(1),"--"),
              ("SVRG",1.0):(cmap(1),":")}
    
    labels = {("SAGA",0.0): "SAGA-FE, M=T",
              ("SAGA",0.5): "SVRG-PE, M=T",
              ("SAGA",1.0): "SVRG-PE, M=10T",
              ("SVRG",0.0): "SVRG-FE, M=T",
              ("SVRG",0.5): "SVRG-PE, M=T",
              ("SVRG",1.0): "SVRG-PE, M=10T",
              ("BFGS",0.0): "BFGS",
              ("CG",0.0)  : "Conjugate Gradient",
              ("GD",0.0)  : "Gradient Descent"}

    legend_elements = []

    for key in labels:
        legend_elements.append(Line2D([0], [0], 
                                      color=linestyles[key][0], 
                                      linestyle=linestyles[key][1], 
                                      label=labels[key]))
    plt.figure(figsize=(8,6))
    
    # make lines
    for method in methods:
        for partial_E in [0,0.5,1]:
            PE = (partial_E == 0.5) or (partial_E == 1)
            M = int(partial_E == 0) + int(partial_E == 0.5) + 10*(partial_E == 1)
            if (method,partial_E) in optims:
                
                optim = optims[(method,partial_E)]
                ltyp = linestyles[(method,partial_E)][1]
                
                eind = min(np.where(np.array(optim.epoch_trace) >= 150)[0],
                           default=len(optim.grad_norm_trace))
                
                if x_time:
                    plt.plot(optim.time_trace[:eind],
                             ll_star-optim.log_like_trace[:eind],
                             color=linestyles[(method,partial_E)][0],
                             linestyle=linestyles[(method,partial_E)][1])
                else:
                    plt.plot(optim.epoch_trace[:eind],
                             ll_star-optim.log_like_trace[:eind],
                             color=linestyles[(method,partial_E)][0],
                             linestyle=linestyles[(method,partial_E)][1])
                title = method 
                if partial_E:
                    title += ", partial E"
                else:
                    title += ", no partial E"
                title += ", M = %dT" % M
         
        
    plt.ylabel(r"$\frac{1}{T} \left[\ell(\phi^*) - \ell(\phi)\right]$",fontsize=18)
    plt.yscale("log")
    plt.legend(handles=legend_elements,
               loc='upper center', 
               fontsize=14,
               bbox_to_anchor=(0.5, 1.24),
               ncol=3)

    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    
    # add points          
    for method in methods:
        for partial_E in [0,0.5,1]:
            PE = (partial_E == 0.5) or (partial_E == 1)
            M = int(partial_E == 0) + int(partial_E == 0.5) + 10*(partial_E == 1)
            if (method,partial_E) in optims:
                optim = optims[(method,partial_E)]
                eind = min(np.where(np.array(optim.epoch_trace) >= 150)[0],
                           default=len(optim.grad_norm_trace))
                converge_ind = min(np.where(np.array(optim.grad_norm_trace) < tol)[0],
                                   default=len(optim.grad_norm_trace)-1)
                
                if converge_ind >= eind-1:
                    continue
                    
                if x_time:
                    plt.plot(optim.time_trace[converge_ind],
                             ll_star-optim.log_like_trace[converge_ind],
                             color = pointstyles[(method,partial_E)][0],
                             marker = pointstyles[(method,partial_E)][1])
                else:
                    plt.plot(optim.epoch_trace[converge_ind],
                             ll_star-optim.log_like_trace[converge_ind],
                             color = pointstyles[(method,partial_E)][0],
                             marker = pointstyles[(method,partial_E)][1])
    
    if x_time:
        plt.xlabel("Seconds of Computation",fontsize=18)
        plt.savefig(plot_folder + "/log-like_v_time_K-%d-%d.png"%(K[0],K[1]),
                    dpi=500,
                    bbox_inches='tight')
    else:
        plt.xlabel("Epoch",fontsize=18)
        plt.savefig(plot_folder + "/log-like_v_epoch_K-%d-%d.png"%(K[0],K[1]),
                    dpi=500,
                    bbox_inches='tight')
        
    if not xlims is None:
        plt.xlim(xlims)
    if not ylims is None:
        plt.ylim(ylims)
        
    plt.show()
                
    return

# %%
if not os.path.isdir(plot_folder):
    os.mkdir(plot_folder)

# %%
plot_ll(optims,x_time=True)#,xlims=[0,600],ylims=[1e-2,1e1])
plot_ll(optims,x_time=False)#,xlims=[0,10],ylims=[1e-2,1e1])

# %%
optims[("SVRG",1.0)].log_like_trace
# Out:
# [-1.0441291175158576,
#  -0.6788010830924888,
#  -0.667279383293187,
#  -0.652591033723364,
#  -0.6318571625780273,
#  -0.6350142203041154,
#  -0.6139990897054185,
#  -0.6020637716982781,
#  -0.6008760963278104,
#  -0.5856969997565175,
#  -0.5856969997565175,
#  -0.5125301226493755,
#  -0.5034556235747801,
#  -0.5024873537858753,
#  -0.49831928212928434,
#  -0.4966119990200092,
#  -0.49594218704267723,
#  -0.4944949517415189,
#  -0.4925283670968578,
#  -0.4926127227469775,
#  -0.4926127227469775,
#  -0.4837715294675814,
#  -0.4832777154063272,
#  -0.4830313764404655,
#  -0.4829013809246124,
#  -0.4827429827623099,
#  -0.4825706603174142,
#  -0.48248294529875513,
#  -0.48238615327592826,
#  -0.48230881941580456,
#  -0.48230881941580456,
#  -0.48152050219558873,
#  -0.4814135654071725,
#  -0.48137006193756593,
#  -0.48132480956650203,
#  -0.48129961309872027,
#  -0.4812929943129398,
#  -0.48126331301080766,
#  -0.48123894878409246,
#  -0.4812353261008536]

# %%
for key in keys:
    print(key)
    print(optims[key].grad_norm_trace[-1])
    print("")
# Out:
# ('BFGS', 0.0)
# 0.0006861186496676901
#
# ('SVRG', 0.0)
# 6.441840123242435e-05
#
# ('SVRG', 0.5)
# 1.1328496794091829e-05
#
# ('SVRG', 1.0)
# 0.010956606363595642
#
# ('SAGA', 0.0)
# 0.002518905924679342
#
# ('SAGA', 0.5)
# 1.0118412099687745e-05
#
# ('SAGA', 1.0)
# 0.0009969957631585401

# %%
plot_dists(optims,theta_star,eta_star,eta0_star,x_time=True)
plot_dists(optims,theta_star,eta_star,eta0_star,x_time=False)

# %%
for method in methods:#["EM","SGD","SAG","SVRG","SAGA"]:
    for partial_E in [0,0.5,1]:
        PE = (partial_E == 0.5) or (partial_E == 1)
        M = int(partial_E == 0) + int(partial_E == 0.5) + 10*(partial_E == 1)
        if (method,partial_E) in optims:
            plot_results(optims[(method,partial_E)],
                         ll_star,method,PE,M,optims[("control",0.0)].features)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [54], in <cell line: 1>()
#       4 M = int(partial_E == 0) + int(partial_E == 0.5) + 10*(partial_E == 1)
#       5 if (method,partial_E) in optims:
# ----> 6     plot_results(optims[(method,partial_E)],
#       7                  ll_star,method,PE,M,optims[("control",0.0)].features)
#
# Input In [48], in plot_results(optim, ll_star, method, partial_E, M, features, iters)
#      28 for k0 in range(optim.K[0]):
#      29     for k1 in range(optim.K[1]):
# ---> 30         plt.plot(x,[optim.theta_trace[t][k0][feature]['mu'][k1] for t in range(len(optim.theta_trace))])
#      31         legend.append(r"$\mu^{(%d,%d)}$"%(k0+1,k1+1))
#      33 plt.title(feature + r" $\mu$ v Epoch, %s" % title)
#
# Input In [48], in <listcomp>(.0)
#      28 for k0 in range(optim.K[0]):
#      29     for k1 in range(optim.K[1]):
# ---> 30         plt.plot(x,[optim.theta_trace[t][k0][feature]['mu'][k1] for t in range(len(optim.theta_trace))])
#      31         legend.append(r"$\mu^{(%d,%d)}$"%(k0+1,k1+1))
#      33 plt.title(feature + r" $\mu$ v Epoch, %s" % title)
#
# KeyError: 'mu'

# %%
optims[("BFGS",0.0)].theta
# Out:
# [{'delt_d': {'mu': array([ 0.73887897,  0.04406452, -0.66592225]),
#    'log_sig': array([-0.7831662 , -1.45438091, -0.88476496])},
#   'e_dive': {'logit_p': array([-100.        , -100.        ,   -2.03573142])}},
#  {'delt_d': {'mu': array([ 2.80233859,  0.03698333, -2.530211  ]),
#    'log_sig': array([ 0.63486415, -0.4167749 ,  0.47744247])},
#   'e_dive': {'logit_p': array([-100.        , -100.        ,   -3.20363884])}},
#  {'delt_d': {'mu': array([ 0.36034692,  0.0237998 , -0.42821934]),
#    'log_sig': array([-1.85396414, -1.85810687, -1.53378368])},
#   'e_dive': {'logit_p': array([-1.00000000e+02, -1.00000000e+02, -9.64694089e-02])}}]

# %%
optims[("SAGA",1.0)].theta
# Out:
# [{'delt_d': {'mu': array([ 0.74051803,  0.044094  , -0.6656825 ]),
#    'log_sig': array([-0.78191974, -1.45397754, -0.88280862])},
#   'e_dive': {'logit_p': array([-100.        , -100.        ,   -2.03996012])}},
#  {'delt_d': {'mu': array([ 0.36032022,  0.02381687, -0.42845113]),
#    'log_sig': array([-1.85237005, -1.85737121, -1.53312489])},
#   'e_dive': {'logit_p': array([-100.        , -100.        ,   -0.10156359])}},
#  {'delt_d': {'mu': array([ 2.79202869,  0.03702426, -2.529067  ]),
#    'log_sig': array([ 0.63527761, -0.4173019 ,  0.47739288])},
#   'e_dive': {'logit_p': array([-100.        , -100.        ,   -3.20408755])}}]
