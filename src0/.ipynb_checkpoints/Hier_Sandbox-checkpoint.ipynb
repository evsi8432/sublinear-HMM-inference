# %%
import sys
#sys.path.remove('/Users/evsi8432/Documents/Research/CarHHMM-DFT/Repository/Code')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm

from scipy.stats import gamma
from scipy.stats import norm
from scipy.stats import vonmises
from scipy.stats import multivariate_normal
from scipy.stats import gaussian_kde
from scipy.stats import circstd
from scipy.special import iv
from scipy.special import expit
from scipy.special import logit
from scipy.special import logsumexp
from scipy.optimize import minimize
from scipy.optimize import minimize_scalar
from scipy.optimize import LinearConstraint
from scipy.signal import convolve
from scipy.interpolate import interp1d
from scipy.linalg import block_diag

from math import isclose

from copy import deepcopy

import importlib

import time
import pickle
import random

# %%
import hier_optimizor

#from optimizor import eta_2_Gamma
#from optimizor import Gamma_2_eta
#from optimizor import logdotexp

from hier_optimizor import delta_2_eta0
from hier_optimizor import Gamma_2_eta

np.random.seed(0)
random.seed(0)

# %% [markdown]
# # Initialize Parameters

# %%
np.kron(Gamma[0],np.ones((2,2)))
# Out:
# array([[0.9, 0.9, 0.1, 0.1],
#        [0.9, 0.9, 0.1, 0.1],
#        [0.1, 0.1, 0.9, 0.9],
#        [0.1, 0.1, 0.9, 0.9]])

# %%
# parameters for data
pars = Parameters.Parameters()
pars.features = [{'Y':{'corr':False,'f':'normal'}}, # coarse-scale
                 {'Y_star':{'corr':False,'f':'normal'}}] # fine-scale
pars.K = [2,2]
T = 1000
experiment = 1


if experiment == 1:
    
    Gamma = [np.array([[0.9,0.1],
                       [0.1,0.9]]),
             [np.array([[0.75,0.25],
                        [0.25,0.75]]),
              np.array([[0.25,0.75],
                        [0.75,0.25]])]]

    delta = [np.array([0.9,0.1]),
             [np.array([0.9,0.1]),
              np.array([0.1,0.9])]]
    
    
    Gamma_coarse_full = np.kron(Gamma[0],np.ones((2,2)))
    Gamma_fine_full = np.block([[Gamma[1][0],np.tile(delta[1][1],(2,1))],
                                [np.tile(delta[1][0],(2,1)),Gamma[1][1]]])
    
    Gamma_full = Gamma_coarse_full * Gamma_fine_full
    delta_full = np.repeat(delta[0],2) * np.concatenate(delta[1])
    
    mus = {'Y'      : np.array([1,1,2,2]), # coarse-scale mus
           'Y_star' : np.array([1,2,1,2])} # fine-scale mus
    
    sigs = {'Y'      : np.exp(np.array([-1,-1,-1,-1])), # coarse-scale sigs
            'Y_star' : np.exp(np.array([-1,-1,-1,-1]))} # fine-scale sigs
    
elif experiment == 2:
    
    Gamma = np.array([[0.99,0.005,0.005],
                      [0.005,0.99,0.005],
                      [0.005,0.005,0.99]])
    delta = np.ones(pars.K[0])/pars.K[0]
    mus = np.array(range(pars.K[0])).astype("float64")
    sigs = np.exp(np.array([-1.0,1.0,0.0]))

    
# optimization parameters 
methods = ["SAGA","EM"]#,"BFGS","CG"]
# methods = ["EM","SGD","SAG","SVRG","SAGA","GD","BFGS","Nelder-Mead"]

# pick optimization settings
step_sizes = {"EM"  : [None,None],
              "CG": [None,None],
              "BFGS": [None,None],
              "GD"  : [0.01,0.01],
              "SGD" : [0.01,0.01],
              "SAG" : [0.01,0.01],
              "SVRG": [0.01,0.01],
              "SAGA": [0.01,0.01]}

num_epochs = 100
tol = 1e-15
grad_tol = 1e-8

# %% [markdown]
# # Simulate Data

# %%
X = np.zeros(T,dtype=int)
data = []

for t in range(T):
    
    if t == 0:
        X[t] = np.random.choice(pars.K[0]*pars.K[1],p=delta_full)
    else:
        X[t] = np.random.choice(pars.K[0]*pars.K[1],p=Gamma_full[X[t-1]])

    data.append({'Y'      : mus['Y'][X[t]] + sigs['Y'][X[t]]*np.random.normal(),
                 'Y_star' : mus['Y_star'][X[t]] + sigs['Y_star'][X[t]]*np.random.normal()})

# %%
plt.plot(X)
plt.show()
plt.plot([x["Y"] for x in data],'.')
plt.plot([x["Y_star"] for x in data],'.')
plt.show()

# save data
np.savetxt('../dat/data.csv', 
           np.array([x['Y'] for x in data]), 
           delimiter=',')

# %% [markdown]
# # Train the HMM

# %%
# initialize optims
optims = {}
times = {}

# %%
importlib.reload(hier_optimizor)
for method in methods:
    
    for partial_E in [0,0.5,1]:
        
        if partial_E > 0 and method in ["EM","BFGS","Nelder-Mead","CG"]:
            continue
        
        print(method,partial_E)
        print("")

        optims[(method,partial_E)] = hier_optimizor.optimizor(pars,data)
        optims[(method,partial_E)].step_size = step_sizes[method]
        optims[(method,partial_E)].param_bounds["Y"]["mu"] = [-100,100]
        optims[(method,partial_E)].param_bounds["Y"]["log_sig"] = [-5,5]
        
        # set parameters
        '''
        optims[(method,partial_E)].theta = [{'Y': {'mu': np.array([1,2]),
                                                   'log_sig': np.array([-1,-1]),
                                                   'corr': np.array([0,0])}},
                                                 [{'Y_star': {'mu': np.array([1,2]),
                                                    'log_sig': np.array([-1,-1]),
                                                    'corr': np.array([0,0])}},
                                                  {'Y_star': {'mu': np.array([1,2]),
                                                    'log_sig': np.array([-1,-1]),
                                                    'corr': np.array([0,0])}}]]
        
        optims[(method,partial_E)].Gamma = [np.array([[0.8,0.2],
                                                      [0.2,0.8]]),
                                            [np.array([[0.6,0.4],
                                                       [0.4,0.6]]),
                                             np.array([[0.4,0.6],
                                                       [0.6,0.4]])]]
        
        optims[(method,partial_E)].delta = [np.array([0.9,0.1]),
                                             [np.array([0.9,0.1]),
                                              np.array([0.1,0.9])]]
        
        optims[(method,partial_E)].eta0 = delta_2_eta0(optims[(method,partial_E)].delta)
        optims[(method,partial_E)].eta = Gamma_2_eta(optims[(method,partial_E)].Gamma)
        '''
        
        if not (step_sizes[method][0] is None):
            optims[(method,partial_E)].L_theta = 1.0 / step_sizes[method][0]
            optims[(method,partial_E)].L_eta = 1.0 / step_sizes[method][1]
        
        if partial_E == 0:
            optims[(method,partial_E)].train_HHMM(num_epochs=num_epochs,
                                                  method=method,
                                                  max_iters=T,
                                                  partial_E=False,
                                                  alpha_theta=step_sizes[method][0],
                                                  alpha_eta=step_sizes[method][1],
                                                  tol=tol,
                                                  grad_tol=grad_tol,
                                                  record_like = True)
        elif partial_E == 0.5:
            if method in ["SGD","SAG","SVRG","SAGA"]:
                optims[(method,partial_E)].train_HHMM(num_epochs=num_epochs,
                                                      method=method,
                                                      max_iters=T,
                                                      partial_E=True,
                                                      alpha_theta=step_sizes[method][0],
                                                      alpha_eta=step_sizes[method][1],
                                                      tol=tol,
                                                      grad_tol=grad_tol,
                                                      record_like = True)
        elif partial_E == 1:
            if method in ["SGD","SAG","SVRG","SAGA"]:
                optims[(method,partial_E)].train_HHMM(num_epochs=num_epochs,
                                                      method=method,
                                                      max_iters=10*T,
                                                      partial_E=True,
                                                      alpha_theta=step_sizes[method][0],
                                                      alpha_eta=step_sizes[method][1],
                                                      tol=tol,
                                                      grad_tol=grad_tol,
                                                      record_like = True)
# Out:
# EM 0
#
# starting epoch 0.0
#
# starting E-step...
# /Users/evsi8432/Documents/Research/sublinear-HMM-inference/src/hier_optimizor.py:319: RuntimeWarning:
#
# divide by zero encountered in true_divide
#
# /Users/evsi8432/Documents/Research/sublinear-HMM-inference/src/hier_optimizor.py:320: RuntimeWarning:
#
# divide by zero encountered in true_divide
#
# /Users/evsi8432/Documents/Research/sublinear-HMM-inference/src/hier_optimizor.py:334: RuntimeWarning:
#
# divide by zero encountered in double_scalars
# ...done
# -1877.0220950254452
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 1.0
#
# starting E-step...
# /Users/evsi8432/Documents/Research/sublinear-HMM-inference/src/hier_optimizor.py:1438: RuntimeWarning:
#
# invalid value encountered in double_scalars
# ...done
# -1867.9633138925626
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 2.0
#
# starting E-step...
# ...done
# -1866.8621931253458
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 3.0
#
# starting E-step...
# ...done
# -1866.433754080109
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 4.0
#
# starting E-step...
# ...done
# -1866.176258130265
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 5.0
#
# starting E-step...
# ...done
# -1865.9435929939177
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 6.0
#
# starting E-step...
# ...done
# -1865.6893671139906
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 7.0
#
# starting E-step...
# ...done
# -1865.3961878212308
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 8.0
#
# starting E-step...
# ...done
# -1865.0553399446492
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 9.0
#
# starting E-step...
# ...done
# -1864.6610118604044
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 10.0
#
# starting E-step...
# ...done
# -1864.208744914423
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 11.0
#
# starting E-step...
# ...done
# -1863.6950076315181
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 12.0
#
# starting E-step...
# ...done
# -1863.1168606977344
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 13.0
#
# starting E-step...
# ...done
# -1862.471257851398
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 14.0
#
# starting E-step...
# ...done
# -1861.7536886671953
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 15.0
#
# starting E-step...
# ...done
# -1860.9559281893914
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 16.0
#
# starting E-step...
# ...done
# -1860.0627000871261
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 17.0
#
# starting E-step...
# ...done
# -1859.0470842304528
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 18.0
#
# starting E-step...
# ...done
# -1857.8644730036965
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 19.0
#
# starting E-step...
# ...done
# -1856.444781344447
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 20.0
#
# starting E-step...
# ...done
# -1854.6825079435216
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 21.0
#
# starting E-step...
# ...done
# -1852.424433163168
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 22.0
#
# starting E-step...
# ...done
# -1849.4561133630345
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 23.0
#
# starting E-step...
# ...done
# -1845.4931273835412
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 24.0
#
# starting E-step...
# ...done
# -1840.195953099227
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 25.0
#
# starting E-step...
# ...done
# -1833.2542816481189
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 26.0
#
# starting E-step...
# ...done
# -1824.6170875296045
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 27.0
#
# starting E-step...
# ...done
# -1814.8911963898136
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 28.0
#
# starting E-step...
# ...done
# -1805.6003897370804
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 29.0
#
# starting E-step...
# ...done
# -1798.5792393142651
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 30.0
#
# starting E-step...
# ...done
# -1794.5735692375679
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 31.0
#
# starting E-step...
# ...done
# -1792.8290372880733
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 32.0
#
# starting E-step...
# ...done
# -1792.191263775869
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 33.0
#
# starting E-step...
# ...done
# -1791.950141595749
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 34.0
#
# starting E-step...
# ...done
# -1791.8236929742627
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 35.0
#
# starting E-step...
# ...done
# -1791.7240269075176
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 36.0
#
# starting E-step...
# ...done
# -1791.6263455503426
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 37.0
#
# starting E-step...
# ...done
# -1791.5230836528074
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 38.0
#
# starting E-step...
# ...done
# -1791.4108093079412
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 39.0
#
# starting E-step...
# ...done
# -1791.286737131284
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 40.0
#
# starting E-step...
# ...done
# -1791.1477145776248
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 41.0
#
# starting E-step...
# ...done
# -1790.9897662469125
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 42.0
#
# starting E-step...
# ...done
# -1790.807689604237
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 43.0
#
# starting E-step...
# ...done
# -1790.5945341586769
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 44.0
#
# starting E-step...
# ...done
# -1790.3408550839292
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 45.0
#
# starting E-step...
# ...done
# -1790.0336098229668
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 46.0
#
# starting E-step...
# ...done
# -1789.6545049686674
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 47.0
#
# starting E-step...
# ...done
# -1789.1775059366782
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 48.0
#
# starting E-step...
# ...done
# -1788.565100751702
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 49.0
#
# starting E-step...
# ...done
# -1787.762812929617
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 50.0
#
# starting E-step...
# ...done
# -1786.6915903942916
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 51.0
#
# starting E-step...
# ...done
# -1785.2386972805364
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 52.0
#
# starting E-step...
# ...done
# -1783.2513027657665
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 53.0
#
# starting E-step...
# ...done
# -1780.546615019781
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 54.0
#
# starting E-step...
# ...done
# -1776.9714063999922
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 55.0
#
# starting E-step...
# ...done
# -1772.5578174579678
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 56.0
#
# starting E-step...
# ...done
# -1767.753744493687
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 57.0
#
# starting E-step...
# ...done
# -1763.4551885219314
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 58.0
#
# starting E-step...
# ...done
# -1760.4759825289998
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 59.0
#
# starting E-step...
# ...done
# -1758.8961024640312
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 60.0
#
# starting E-step...
# ...done
# -1758.2169321035922
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 61.0
#
# starting E-step...
# ...done
# -1757.951810317968
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 62.0
#
# starting E-step...
# ...done
# -1757.8449823028075
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 63.0
#
# starting E-step...
# ...done
# -1757.7963248051474
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 64.0
#
# starting E-step...
# ...done
# -1757.7708598736504
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 65.0
#
# starting E-step...
# ...done
# -1757.7561166697178
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 66.0
#
# starting E-step...
# ...done
# -1757.7470820559467
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 67.0
#
# starting E-step...
# ...done
# -1757.7413870502871
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 68.0
#
# starting E-step...
# ...done
# -1757.737746988631
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 69.0
#
# starting E-step...
# ...done
# -1757.7354023759635
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 70.0
#
# starting E-step...
# ...done
# -1757.7338835312812
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 71.0
#
# starting E-step...
# ...done
# -1757.7328937429222
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 72.0
#
# starting E-step...
# ...done
# -1757.7322437500661
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 73.0
#
# starting E-step...
# ...done
# -1757.73181231186
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 74.0
#
# starting E-step...
# ...done
# -1757.7315216152992
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 75.0
#
# starting E-step...
# ...done
# -1757.7313216788725
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 76.0
#
# starting E-step...
# ...done
# -1757.7311803861505
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 77.0
#
# starting E-step...
# ...done
# -1757.7310770957824
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 78.0
#
# starting E-step...
# ...done
# -1757.7309985387762
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 79.0
#
# starting E-step...
# ...done
# -1757.7309361828259
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 80.0
#
# starting E-step...
# ...done
# -1757.73088453888
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 81.0
#
# starting E-step...
# ...done
# -1757.7308400730806
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 82.0
#
# starting E-step...
# ...done
# -1757.7308005077368
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 83.0
#
# starting E-step...
# ...done
# -1757.7307643721977
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 84.0
#
# starting E-step...
# ...done
# -1757.7307307143913
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 85.0
#
# starting E-step...
# ...done
# -1757.730698915489
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 86.0
#
# starting E-step...
# ...done
# -1757.7306685709261
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 87.0
#
# starting E-step...
# ...done
# -1757.7306394138998
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 88.0
#
# starting E-step...
# ...done
# -1757.7306112663093
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 89.0
#
# starting E-step...
# ...done
# -1757.7305840071754
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 90.0
#
# starting E-step...
# ...done
# -1757.7305575524142
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 91.0
#
# starting E-step...
# ...done
# -1757.7305318418043
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 92.0
#
# starting E-step...
# ...done
# -1757.730506830614
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 93.0
#
# starting E-step...
# ...done
# -1757.7304824842433
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 94.0
#
# starting E-step...
# ...done
# -1757.7304587747587
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 95.0
#
# starting E-step...
# ...done
# -1757.730435678658
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 96.0
#
# starting E-step...
# ...done
# -1757.7304131754586
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 97.0
#
# starting E-step...
# ...done
# -1757.730391246742
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 98.0
#
# starting E-step...
# ...done
# -1757.7303698755898
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 99.0
#
# starting E-step...
# ...done
# -1757.7303490461527
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# maximum number of epochs (100.0) reached. Returning...
# SAGA 0
#
# starting epoch 0.0
#
# starting E-step...
# ...done
# -1869.883833345098
# starting M-step...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-a2162eb90c03> in <module>
#      55                                                   tol=tol,
#      56                                                   grad_tol=grad_tol,
# ---> 57                                                   record_like = True)
#      58         elif partial_E == 0.5:
#      59             if method in ["SGD","SAG","SVRG","SAGA"]:
#
# ~/Documents/Research/sublinear-HMM-inference/src/hier_optimizor.py in train_HHMM(self, num_epochs, max_iters, alpha_theta, alpha_eta, tol, grad_tol, method, partial_E, record_like)
#    1451                         partial_E=partial_E,
#    1452                         tol=grad_tol,
# -> 1453                         record_like=record_like)
#    1454             print("...done")
#    1455             print("")
#
# ~/Documents/Research/sublinear-HMM-inference/src/hier_optimizor.py in M_step(self, max_iters, alpha_theta, alpha_eta, method, partial_E, tol, record_like)
#    1177                     delta = alpha_eta * (new_E_grad_log_Gamma \
#    1178                                    - old_E_grad_log_Gamma \
# -> 1179                                    + self.grad_eta_G/self.T)
#    1180                     self.eta[0] += delta
#    1181
#
# TypeError: unsupported operand type(s) for -: 'tuple' and 'list'

# %%
grad_eta_G_t,grad_eta0_G_t = self.get_grad_eta_G_t(t)
grad_eta_G_t[1][0]
# Out:
# array([[ 0.        ,  0.21744979],
#        [-0.00369096,  0.        ]])

# %%
# get optimal value via EM:
optims["control"] = hier_optimizor.optimizor(pars,data)
optims["control"].step_size = [None,None]
optims["control"].param_bounds["Y"]["mu"] = [-100,100]
optims["control"].param_bounds["Y"]["log_sig"] = [-5,5]

optims["control"].train_HHMM(num_epochs=num_epochs,
                                        method="EM",
                                        tol=1e-15)
optim_ll = optims["control"].log_like_trace[-1]
# Out:
# starting epoch 0.0
#
# starting E-step...
# ...done
# -1872.781786671706
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 1.0
#
# starting E-step...
# ...done
# -1865.9107030862087
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 2.0
#
# starting E-step...
# ...done
# -1864.8651431906792
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 3.0
#
# starting E-step...
# ...done
# -1864.2492549363476
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 4.0
#
# starting E-step...
# ...done
# -1863.6800384864623
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 5.0
#
# starting E-step...
# ...done
# -1863.027295271153
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 6.0
#
# starting E-step...
# ...done
# -1862.2317744119453
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 7.0
#
# starting E-step...
# ...done
# -1861.2522426148025
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 8.0
#
# starting E-step...
# ...done
# -1860.0486299510628
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 9.0
#
# starting E-step...
# ...done
# -1858.5745937447164
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 10.0
#
# starting E-step...
# ...done
# -1856.7699554387473
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 11.0
#
# starting E-step...
# ...done
# -1854.548628249095
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 12.0
#
# starting E-step...
# ...done
# -1851.779804991029
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 13.0
#
# starting E-step...
# ...done
# -1848.2634128886311
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 14.0
#
# starting E-step...
# ...done
# -1843.7088613938154
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 15.0
#
# starting E-step...
# ...done
# -1837.7445601874226
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 16.0
#
# starting E-step...
# ...done
# -1830.0200196314083
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 17.0
#
# starting E-step...
# ...done
# -1820.4940466095732
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 18.0
#
# starting E-step...
# ...done
# -1809.914604540118
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 19.0
#
# starting E-step...
# ...done
# -1800.0663162313701
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 20.0
#
# starting E-step...
# ...done
# -1792.9304133070439
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 21.0
#
# starting E-step...
# ...done
# -1789.0820543253253
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 22.0
#
# starting E-step...
# ...done
# -1787.5048252119927
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 23.0
#
# starting E-step...
# ...done
# -1786.9595879482947
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 24.0
#
# starting E-step...
# ...done
# -1786.7671432078623
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 25.0
#
# starting E-step...
# ...done
# -1786.6786274419317
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 26.0
#
# starting E-step...
# ...done
# -1786.6196763722594
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 27.0
#
# starting E-step...
# ...done
# -1786.569355387458
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 28.0
#
# starting E-step...
# ...done
# -1786.521432083258
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 29.0
#
# starting E-step...
# ...done
# -1786.473761082089
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 30.0
#
# starting E-step...
# ...done
# -1786.4254461396677
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 31.0
#
# starting E-step...
# ...done
# -1786.3760263573265
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 32.0
#
# starting E-step...
# ...done
# -1786.3252080107486
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 33.0
#
# starting E-step...
# ...done
# -1786.272760599593
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 34.0
#
# starting E-step...
# ...done
# -1786.2184702925024
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 35.0
#
# starting E-step...
# ...done
# -1786.1621162435904
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 36.0
#
# starting E-step...
# ...done
# -1786.1034566604326
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 37.0
#
# starting E-step...
# ...done
# -1786.0422189014566
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 38.0
#
# starting E-step...
# ...done
# -1785.9780908179955
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 39.0
#
# starting E-step...
# ...done
# -1785.9107118184427
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 40.0
#
# starting E-step...
# ...done
# -1785.8396626683325
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 41.0
#
# starting E-step...
# ...done
# -1785.7644532233305
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 42.0
#
# starting E-step...
# ...done
# -1785.684507278991
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 43.0
#
# starting E-step...
# ...done
# -1785.5991435742822
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 44.0
#
# starting E-step...
# ...done
# -1785.507551720018
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 45.0
#
# starting E-step...
# ...done
# -1785.4087614238024
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 46.0
#
# starting E-step...
# ...done
# -1785.3016028100058
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 47.0
#
# starting E-step...
# ...done
# -1785.1846548206374
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 48.0
#
# starting E-step...
# ...done
# -1785.056177528707
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 49.0
#
# starting E-step...
# ...done
# -1784.9140225496735
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 50.0
#
# starting E-step...
# ...done
# -1784.7555133760368
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 51.0
#
# starting E-step...
# ...done
# -1784.5772840633128
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 52.0
#
# starting E-step...
# ...done
# -1784.3750597998423
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 53.0
#
# starting E-step...
# ...done
# -1784.1433558605445
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 54.0
#
# starting E-step...
# ...done
# -1783.8750614511243
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 55.0
#
# starting E-step...
# ...done
# -1783.5608610932454
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 56.0
#
# starting E-step...
# ...done
# -1783.1884279539927
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 57.0
#
# starting E-step...
# ...done
# -1782.741302111792
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 58.0
#
# starting E-step...
# ...done
# -1782.1973488593947
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 59.0
#
# starting E-step...
# ...done
# -1781.5266990976775
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 60.0
#
# starting E-step...
# ...done
# -1780.6891627427824
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 61.0
#
# starting E-step...
# ...done
# -1779.6314131049983
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 62.0
#
# starting E-step...
# ...done
# -1778.285052001038
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 63.0
#
# starting E-step...
# ...done
# -1776.5684648433503
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 64.0
#
# starting E-step...
# ...done
# -1774.398561979938
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 65.0
#
# starting E-step...
# ...done
# -1771.721859152892
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 66.0
#
# starting E-step...
# ...done
# -1768.5709990819387
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 67.0
#
# starting E-step...
# ...done
# -1765.1274844103255
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 68.0
#
# starting E-step...
# ...done
# -1761.7209087660958
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 69.0
#
# starting E-step...
# ...done
# -1758.6870208960183
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 70.0
#
# starting E-step...
# ...done
# -1756.1465259913252
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 71.0
#
# starting E-step...
# ...done
# -1753.9218929459287
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 72.0
#
# starting E-step...
# ...done
# -1751.6717385509708
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 73.0
#
# starting E-step...
# ...done
# -1749.0782611213062
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 74.0
#
# starting E-step...
# ...done
# -1745.9721816466724
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 75.0
#
# starting E-step...
# ...done
# -1742.4327600164347
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 76.0
#
# starting E-step...
# ...done
# -1738.8553607835038
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 77.0
#
# starting E-step...
# ...done
# -1735.825676065513
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 78.0
#
# starting E-step...
# ...done
# -1733.7456965928463
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 79.0
#
# starting E-step...
# ...done
# -1732.5780024760306
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 80.0
#
# starting E-step...
# ...done
# -1732.0102076373162
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 81.0
#
# starting E-step...
# ...done
# -1731.7482117849365
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 82.0
#
# starting E-step...
# ...done
# -1731.6228105209234
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 83.0
#
# starting E-step...
# ...done
# -1731.557487412968
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 84.0
#
# starting E-step...
# ...done
# -1731.5205006577557
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 85.0
#
# starting E-step...
# ...done
# -1731.4982997773789
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 86.0
#
# starting E-step...
# ...done
# -1731.484509006469
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 87.0
#
# starting E-step...
# ...done
# -1731.4757796220301
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 88.0
#
# starting E-step...
# ...done
# -1731.4701965278075
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 89.0
#
# starting E-step...
# ...done
# -1731.4666044407977
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 90.0
#
# starting E-step...
# ...done
# -1731.4642849456345
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 91.0
#
# starting E-step...
# ...done
# -1731.4627836589523
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 92.0
#
# starting E-step...
# ...done
# -1731.4618103813084
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 93.0
#
# starting E-step...
# ...done
# -1731.4611786765008
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 94.0
#
# starting E-step...
# ...done
# -1731.460768316057
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 95.0
#
# starting E-step...
# ...done
# -1731.4605015683517
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 96.0
#
# starting E-step...
# ...done
# -1731.460328086009
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 97.0
#
# starting E-step...
# ...done
# -1731.4602152152397
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 98.0
#
# starting E-step...
# ...done
# -1731.4601417565345
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# starting epoch 99.0
#
# starting E-step...
# ...done
# -1731.4600939361674
# starting M-step...
# ...done
#
# L_theta:  0.0
# L_eta:  0.0
#
# maximum number of epochs (100.0) reached. Returning...

# %% [markdown]
# # Plot Results

# %%
def plot_ll(optims,x_time=False):
    
    ll_star = optims["control"].log_like_trace[-1]
    legend = []
    
    for method in methods:
        
        for partial_E in [0,0.5,1]:
            
            PE = (partial_E == 0.5) or (partial_E == 1)
            M = int(partial_E == 0) + int(partial_E == 0.5) + 10*(partial_E == 1)
            
            if (method,partial_E) in optims:
                
                optim = optims[(method,partial_E)]
                if x_time:
                    plt.plot(optim.time_trace,np.log10(ll_star-optim.log_like_trace))
                else:
                    plt.plot(optim.epoch_trace,np.log10(ll_star-optim.log_like_trace))    
                title = method 
                if partial_E:
                    title += ", partial E"
                else:
                    title += ", no partial E"
                title += ", M = %dT" % M
                
                legend.append(title)
                
    plt.ylabel(r"$\log_{10}\left[\log p(\mathbf{y} ; \theta^*, \eta^*) - \log p(\mathbf{y} ; \theta, \eta)\right]$")
    plt.legend(legend)
    if x_time:
        plt.xlabel("Seconds of Computation")
        plt.savefig("../plt/log-like_v_time_exp_%d.png" % experiment,dpi=500)
    else:
        plt.xlabel("Epoch")
        plt.savefig("../plt/log-like_v_epoch_exp_%d.png" % experiment,dpi=500)
    plt.show()
                
    return

def plot_results(optim,ll_star,method,partial_E,M,experiment=1,iters=None):
    
    title = method 
    if partial_E:
        title += ", partial E-step"
    title += ", M = %dT" % M
    
    if iters is None:
        iters=len(optim.theta_trace)
        
    if method.startswith("SAGA"):
        x = (np.arange(iters) / optim.T)
    else:
        x = np.arange(iters)
    
    # plot log of gradient of log-likelihood
    plt.plot(np.log10(optim.grad_norm_trace))
    plt.axhline(-3, c = 'k', linestyle = "--")
    plt.title(r"$\log_{10}$ of Gradient Norm v Epoch, %s" % title)
    plt.xlabel("Epoch (k)")
    plt.ylabel(r"$\log ||\widehat \nabla_\theta F^{(k,m)} + \widehat \nabla_\eta G^{(k,m)}||$")
    plt.savefig("../plt/grad-hat-ll-%s-%s-%d-%d.png"%(method,partial_E,M,experiment),dpi=300)
    plt.show()

    # plot means
    legend = []
    for k in range(optim.K[0]):
        plt.plot(x,[optim.theta_trace[i][0]['Y']['mu'][k] for i in range(iters)])
        legend.append(r"$\mu^{(%d)}$"%(k+1))
    for hline in range(optim.K[0]):
        plt.axhline(hline, c = 'k', linestyle = "--")
        
    plt.title("$\mu$ v Epoch, %s" % title)
    plt.xlabel("Epoch")
    plt.legend(legend)
    plt.savefig("../plt/mu-%s-%s-%d-%d.png"%(method,partial_E,M,experiment),dpi=500)
    plt.show()
    
    # plot log(sigma)
    legend = []
    for k in range(optim.K[0]):
        plt.plot(x,[optim.theta_trace[i][0]['Y']['log_sig'][k] for i in range(len(optim.theta_trace))])
        legend.append(r"$\log\left(\sigma^{(%d)}\right)$"%(k+1))
    for hline in range(optim.K[0]):
        plt.axhline(hline-1, c = 'k', linestyle = "--")
        
    plt.title(r"$\log\left(\sigma\right)$ v Epoch, %s" % title)
    plt.xlabel("Epoch")
    plt.legend(legend)
    plt.savefig("../plt/log-sig-%s-%s-%d-%d.png"%(method,partial_E,M,experiment),dpi=500)
    plt.show()
    
    # plot eta
    legend = []
    for k in range(optim.K[0]):
        for l in range(optim.K[0]):
            if k != l:
                plt.plot(x,[optim.eta_trace[i][0][k,l] for i in range(len(optim.eta_trace))])
                legend.append(r"$\eta^{(%d,%d)}$" % (k+1,l+1))
    plt.title(r"$\eta$ v Epoch, %s" % title)
    plt.xlabel("Epoch")
    plt.legend(legend)
    plt.savefig("../plt/eta-%s-%s-%d-%d.png"%(method,partial_E,M,experiment),dpi=500)
    plt.show()
    
    #plt.plot([optim.grad_theta_trace[i][0]['Y']['log_sig'][0] for i in range(len(optim.theta_trace))])
    #plt.plot([optim.grad_theta_trace[i][0]['Y']['log_sig'][1] for i in range(len(optim.theta_trace))])
    #plt.plot([optim.grad_theta_trace[i][0]['Y']['log_sig'][2] for i in range(len(optim.theta_trace))])
    #plt.title("Gradients of Standard Deviations v iteration number")
    #plt.show()

# %%
plot_ll(optims,x_time=True)
plot_ll(optims,x_time=False)

for method in methods:#["EM","SGD","SAG","SVRG","SAGA"]:
    for partial_E in [0,0.5,1]:
        PE = (partial_E == 0.5) or (partial_E == 1)
        M = int(partial_E == 0) + int(partial_E == 0.5) + 10*(partial_E == 1)
        if (method,partial_E) in optims:
            plot_results(optims[(method,partial_E)],optim_ll,method,PE,M)

# %%
print(optims["control"].theta[0])
print(optims["control"].theta[1][0])
print(optims["control"].theta[1][1])
print("")
print(optims[("EM",0)].theta[0])
print(optims[("EM",0)].theta[1][0])
print(optims[("EM",0)].theta[1][1])
# Out:
# {'Y': {'mu': array([2.04075572, 1.04343665]), 'log_sig': array([-1.14993213, -0.97605221]), 'corr': array([-0.90225268, -1.14689843])}}
# {'Y_star': {'mu': array([2.00991142, 0.96026613]), 'log_sig': array([-1.06778828, -0.98864382]), 'corr': array([-0.93130503, -0.93116713])}}
# {'Y_star': {'mu': array([1.927838  , 0.95938765]), 'log_sig': array([-0.95380117, -1.04581559]), 'corr': array([-1.0169088 , -0.84463729])}}
#
# {'Y': {'mu': array([2.01975222, 1.02141634]), 'log_sig': array([-1.10805379, -1.0034253 ]), 'corr': array([-1.15276319, -0.90712581])}}
# {'Y_star': {'mu': array([0.88707782, 1.96493151]), 'log_sig': array([-1.16283433, -0.99978389]), 'corr': array([-0.92061196, -1.06992153])}}
# {'Y_star': {'mu': array([1.43983894, 1.37260598]), 'log_sig': array([-0.4955464 , -0.51204283]), 'corr': array([-1.13920159, -0.94077943])}}

# %%
print(optims["control"].Gamma)
print(optims[("EM",0)].Gamma)
# Out:
# [array([[0.75241257, 0.24758743],
#        [0.25234422, 0.74765578]]), [array([[0.33267761, 0.66732239],
#        [0.63728405, 0.36271595]]), array([[0.65575252, 0.34424748],
#        [0.34919477, 0.65080523]])]]
# [array([[0.7582693 , 0.2417307 ],
#        [0.26858804, 0.73141196]]), [array([[0.2948584 , 0.7051416 ],
#        [0.59281365, 0.40718635]]), array([[0.46377861, 0.53622139],
#        [0.52009795, 0.47990205]])]]

# %%
print(optims["control"].delta)
print(optims[("EM",0)].delta)
