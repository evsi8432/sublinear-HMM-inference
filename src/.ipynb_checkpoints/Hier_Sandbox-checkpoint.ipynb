# %%
import sys
#sys.path.remove('/Users/evsi8432/Documents/Research/CarHHMM-DFT/Repository/Code')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm

from scipy.stats import gamma
from scipy.stats import norm
from scipy.stats import vonmises
from scipy.stats import multivariate_normal
from scipy.stats import gaussian_kde
from scipy.stats import circstd
from scipy.special import iv
from scipy.special import expit
from scipy.special import logit
from scipy.special import logsumexp
from scipy.optimize import minimize
from scipy.optimize import minimize_scalar
from scipy.optimize import LinearConstraint
from scipy.signal import convolve
from scipy.interpolate import interp1d
from scipy.linalg import block_diag

from math import isclose

from copy import deepcopy

import importlib

import time
import pickle
import random

# %%
import Preprocessor
import Parameters
import HHMM
import Visualisor
import optimizor

#from optimizor import eta_2_Gamma
#from optimizor import Gamma_2_eta
#from optimizor import logdotexp

from optimizor import delta_2_eta0
from optimizor import Gamma_2_eta

np.random.seed(0)
random.seed(0)

# %% [markdown]
# # Initialize Parameters

# %%
# parameters for data
pars = Parameters.Parameters()
features = [{},
            {'Y'      : {'f'           : 'normal',
                         'lower_bound' : None,
                         'upper_bound' : None},
             'Y_star' : {'f'           : 'normal',
                         'lower_bound' : None,
                         'upper_bound' : None}}]
K = [2,2]
T = 100
experiment = 1


if experiment == 1:
    
    Gamma = [np.array([[0.9,0.1],
                       [0.1,0.9]]),
             [np.array([[0.75,0.25],
                        [0.25,0.75]]),
              np.array([[0.25,0.75],
                        [0.75,0.25]])]]

    delta = [np.array([0.9,0.1]),
             [np.array([0.9,0.1]),
              np.array([0.1,0.9])]]
    
    
    Gamma_coarse_full = np.kron(Gamma[0],np.ones((2,2)))
    Gamma_fine_full = np.block([[Gamma[1][0],np.tile(delta[1][1],(2,1))],
                                [np.tile(delta[1][0],(2,1)),Gamma[1][1]]])
    
    Gamma_full = Gamma_coarse_full * Gamma_fine_full
    delta_full = np.repeat(delta[0],2) * np.concatenate(delta[1])
    
    mus = {'Y'      : np.array([1.0,2.0,3.0,4.0])}#, # coarse-scale mus
           #'Y_star' : np.array([1,2,1,2])} # fine-scale mus
    
    sigs = {'Y'      : np.exp(np.array([-2.0,-2.0,-2.0,-2.0]))}#, # coarse-scale sigs
            #'Y_star' : np.exp(np.array([-1,-1,-1,-1]))} # fine-scale sigs
    
elif experiment == 2:
    
    Gamma = np.array([[0.99,0.005,0.005],
                      [0.005,0.99,0.005],
                      [0.005,0.005,0.99]])
    delta = np.ones(pars.K[0])/pars.K[0]
    mus = np.array(range(pars.K[0])).astype("float64")
    sigs = np.exp(np.array([-1.0,1.0,0.0]))

    
# optimization parameters 
methods = ["SAGA","BFGS"]#,"EM"]#,"BFGS","CG"]
# methods = ["EM","SGD","SAG","SVRG","SAGA","GD","BFGS","Nelder-Mead"]

# pick optimization settings
step_sizes = {"EM"  : [None,None],
              "CG": [None,None],
              "BFGS": [None,None],
              "GD"  : [0.01,0.01],
              "SGD" : [0.01,0.01],
              "SAG" : [0.01,0.01],
              "SVRG": [0.01,0.01],
              "SAGA": [0.01,0.01]}

num_epochs = 10
tol = 1e-15
grad_tol = 1e-8

# %% [markdown]
# # Simulate Data

# %%
X = np.zeros(T,dtype=int)
data = []

for t in range(T):
    
    if t == 0:
        X[t] = np.random.choice(K[0]*K[1],p=delta_full)
    else:
        X[t] = np.random.choice(K[0]*K[1],p=Gamma_full[X[t-1]])

    data.append({'Y'      : mus['Y'][X[t]] + sigs['Y'][X[t]]*np.random.normal()})#,
                 #'Y_star' : mus['Y_star'][X[t]] + sigs['Y_star'][X[t]]*np.random.normal()})

# %%
plt.plot(X)
plt.show()
plt.plot([x["Y"] for x in data],'.')
#plt.plot([x["Y_star"] for x in data],'.')
plt.show()

# save data
np.savetxt('../dat/data.csv', 
           np.array([x['Y'] for x in data]), 
           delimiter=',')

# %% [markdown]
# # Train the HMM

# %%
K = [2,2]
jump_every = 1
features = [{},
            {'Y'      : {'f'           : 'normal',
                         'lower_bound' : None,
                         'upper_bound' : None}}]#,
             #'Y_star' : {'f'           : 'normal',
             #            'lower_bound' : None,
             #            'upper_bound' : None}}]

# %%
# initialize optims
optims = {}
times = {}

# %%
importlib.reload(optimizor)
for method in methods:
    
    for partial_E in [0,0.5,1]:
        
        if partial_E > 0 and method in ["EM","BFGS","Nelder-Mead","CG"]:
            continue
        
        print(method,partial_E)
        print("")

        optims[(method,partial_E)] = optimizor.optimizor(data,features,K)
        optims[(method,partial_E)].step_size = step_sizes[method]
        optims[(method,partial_E)].param_bounds[1]["Y"]["mu"] = [-100,100]
        optims[(method,partial_E)].param_bounds[1]["Y"]["log_sig"] = [-5,5]
        print(optims[(method,partial_E)].theta)
        #optims[(method,partial_E)].param_bounds[1]["Y_star"]["mu"] = [-100,100]
        #optims[(method,partial_E)].param_bounds[1]["Y_star"]["log_sig"] = [-5,5]
        
        # set parameters
        
        optims[(method,partial_E)].theta = [{},
                                            [{'Y': {'mu': np.array([1.0,2.0]),
                                                    'log_sig': np.array([-2.0,-2.0])}},
                                             {'Y': {'mu': np.array([3.0,4.0]),
                                                    'log_sig': np.array([-2.0,-2.0])}}]]
        
        optims[(method,partial_E)].Gamma = [np.array([[0.9,0.1],
                                                      [0.1,0.9]]),
                                            [np.array([[0.75,0.25],
                                                       [0.25,0.75]]),
                                             np.array([[0.25,0.75],
                                                       [0.75,0.25]])]]
        
        optims[(method,partial_E)].delta = [np.array([0.9,0.1]),
                                             [np.array([0.9,0.1]),
                                              np.array([0.1,0.9])]]
        
        optims[(method,partial_E)].eta0 = delta_2_eta0(optims[(method,partial_E)].delta)
        optims[(method,partial_E)].eta = Gamma_2_eta(optims[(method,partial_E)].Gamma)
        
        if not (step_sizes[method][0] is None):
            optims[(method,partial_E)].L_theta = 1.0 / step_sizes[method][0]
            optims[(method,partial_E)].L_eta = 1.0 / step_sizes[method][1]
        
        if partial_E == 0:
            optims[(method,partial_E)].train_HHMM(num_epochs=num_epochs,
                                                  method=method,
                                                  max_iters=T,
                                                  partial_E=False,
                                                  alpha_theta=step_sizes[method][0],
                                                  alpha_eta=step_sizes[method][1],
                                                  tol=tol,
                                                  grad_tol=grad_tol,
                                                  record_like = True)
        elif partial_E == 0.5:
            if method in ["SGD","SAG","SVRG","SAGA"]:
                optims[(method,partial_E)].train_HHMM(num_epochs=num_epochs,
                                                      method=method,
                                                      max_iters=T,
                                                      partial_E=True,
                                                      alpha_theta=step_sizes[method][0],
                                                      alpha_eta=step_sizes[method][1],
                                                      tol=tol,
                                                      grad_tol=grad_tol,
                                                      record_like = True)
        elif partial_E == 1:
            if method in ["SGD","SAG","SVRG","SAGA"]:
                optims[(method,partial_E)].train_HHMM(num_epochs=num_epochs,
                                                      method=method,
                                                      max_iters=10*T,
                                                      partial_E=True,
                                                      alpha_theta=step_sizes[method][0],
                                                      alpha_eta=step_sizes[method][1],
                                                      tol=tol,
                                                      grad_tol=grad_tol,
                                                      record_like = True)
# Out:
# SAGA 0
#
# [{}, [{'Y': {'mu': array([2.99936   , 2.52161096]), 'log_sig': array([-1.11055614, -0.329404  ])}}, {'Y': {'mu': array([1.10714811, 4.37575236]), 'log_sig': array([-1.64817099,  0.7614577 ])}}]]
# starting epoch 0.0
#
# starting E-step...
# ...done
# -122.8132607056558
# starting M-step...
# /Users/evsi8432/Documents/Research/sublinear-HMM-inference/src/optimizor.py:1836: RuntimeWarning:
#
# invalid value encountered in double_scalars
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# L_theta:  100.69555500567215
# L_eta:  202.79189595800636
#
# starting epoch 1.0
#
# starting E-step...
# ...done
# -3254.9245059181553
# log likelihood increased. Trying again...
# starting M-step...
# /Users/evsi8432/Documents/Research/sublinear-HMM-inference/src/optimizor.py:96: RuntimeWarning:
#
# divide by zero encountered in log
#
# /Users/evsi8432/Documents/Research/sublinear-HMM-inference/src/optimizor.py:767: RuntimeWarning:
#
# invalid value encountered in subtract
#
# /Users/evsi8432/Documents/Research/sublinear-HMM-inference/src/optimizor.py:792: RuntimeWarning:
#
# invalid value encountered in subtract
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# L_theta:  50.34777750283621
# L_eta:  101.39594797900345
#
# starting epoch 2.0
#
# starting E-step...
# ...done
# nan
# starting M-step...
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# L_theta:  25.173888751418172
# L_eta:  50.69797398950186
#
# starting epoch 3.0
#
# starting E-step...
# ...done
# nan
# starting M-step...
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# L_theta:  12.586944375709114
# L_eta:  25.348986994750987
#
# starting epoch 4.0
#
# starting E-step...
# ...done
# nan
# starting M-step...
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# L_theta:  6.293472187854572
# L_eta:  12.674493497375524
#
# starting epoch 5.0
#
# starting E-step...
# ...done
# nan
# starting M-step...
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# L_theta:  3.1467360939272946
# L_eta:  6.337246748687779
#
# starting epoch 6.0
#
# starting E-step...
# ...done
# nan
# starting M-step...
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# L_theta:  1.5733680469636522
# L_eta:  3.1686233743438996
#
# starting epoch 7.0
#
# starting E-step...
# ...done
# nan
# starting M-step...
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# L_theta:  0.7866840234818282
# L_eta:  1.584311687171954
#
# starting epoch 8.0
#
# starting E-step...
# ...done
# nan
# starting M-step...
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# L_theta:  0.39334201174091493
# L_eta:  0.7921558435859787
#
# starting epoch 9.0
#
# starting E-step...
# ...done
# nan
# starting M-step...
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# L_theta:  0.1966710058704578
# L_eta:  0.39607792179299
#
# starting epoch 10.0
#
# starting E-step...
# ...done
# nan
# starting M-step...
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# L_theta:  0.09833550293522915
# L_eta:  0.1980389608964955
#
# starting epoch 11.0
#
# starting E-step...
# ...done
# nan
# starting M-step...
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# L_theta:  0.049167751467614686
# L_eta:  0.09901948044824797
#
# starting epoch 12.0
#
# starting E-step...
# ...done
# nan
# starting M-step...
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# L_theta:  0.024583875733807395
# L_eta:  0.04950974022412409
#
# starting epoch 13.0
#
# starting E-step...
# ...done
# nan
# starting M-step...
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# L_theta:  0.012291937866903725
# L_eta:  0.0247548701120621
#
# starting epoch 14.0
#
# starting E-step...
# ...done
# nan
# starting M-step...
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# L_theta:  0.006145968933451881
# L_eta:  0.012377435056031089
#
# starting epoch 15.0
#
# starting E-step...
# ...done
# nan
# starting M-step...
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# L_theta:  0.003072984466725948
# L_eta:  0.00618871752801556
#
# starting epoch 16.0
#
# starting E-step...
# ...done
# nan
# starting M-step...
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# L_theta:  0.0015364922333629789
# L_eta:  0.0030943587640077895
#
# starting epoch 17.0
#
# starting E-step...
# ...done
# nan
# starting M-step...
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# L_theta:  0.000768246116681492
# L_eta:  0.0015471793820039
#
# starting epoch 18.0
#
# starting E-step...
# ...done
# nan
# starting M-step...
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# L_theta:  0.00038412305834074705
# L_eta:  0.000773589691001952
#
# starting epoch 19.0
#
# starting E-step...
# ...done
# nan
# starting M-step...
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# L_theta:  0.00019206152917037388
# L_eta:  0.0003867948455009767
#
# starting epoch 20.0
#
# starting E-step...
# ...done
# nan
# starting M-step...
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# L_theta:  9.603076458518714e-05
# L_eta:  0.00019339742275048877
#
# starting epoch 21.0
#
# starting E-step...
# ...done
# nan
# starting M-step...
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# L_theta:  4.801538229259368e-05
# L_eta:  9.66987113752446e-05
#
# starting epoch 22.0
#
# starting E-step...
# ...done
# nan
# starting M-step...
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# L_theta:  2.40076911462969e-05
# L_eta:  4.834935568762243e-05
#
# starting epoch 23.0
#
# starting E-step...
# ...done
# nan
# starting M-step...
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# L_theta:  1.2003845573148476e-05
# L_eta:  2.4174677843811265e-05
#
# starting epoch 24.0
#
# starting E-step...
# ...done
# nan
# starting M-step...
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# L_theta:  6.001922786574255e-06
# L_eta:  1.2087338921905667e-05
#
# starting epoch 25.0
#
# starting E-step...
# ...done
# nan
# starting M-step...
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# L_theta:  3.0009613932871367e-06
# L_eta:  6.043669460952852e-06
#
# starting epoch 26.0
#
# starting E-step...
# ...done
# nan
# starting M-step...
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# L_theta:  1.5004806966435724e-06
# L_eta:  3.021834730476434e-06
#
# starting epoch 27.0
#
# starting E-step...
# ...done
# nan
# starting M-step...
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# L_theta:  7.502403483217884e-07
# L_eta:  1.5109173652382215e-06
#
# starting epoch 28.0
#
# starting E-step...
# ...done
# nan
# starting M-step...
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# L_theta:  3.751201741608952e-07
# L_eta:  7.554586826191127e-07
#
# starting epoch 29.0
#
# starting E-step...
# ...done
# nan
# starting M-step...
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# L_theta:  1.875600870804481e-07
# L_eta:  3.7772934130955743e-07
#
# starting epoch 30.0
#
# starting E-step...
# ...done
# nan
# starting M-step...
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# L_theta:  9.378004354022429e-08
# L_eta:  1.888646706547792e-07
#
# starting epoch 31.0
#
# starting E-step...
# ...done
# nan
# starting M-step...
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# L_theta:  4.689002177011226e-08
# L_eta:  9.443233532738982e-08
#
# starting epoch 32.0
#
# starting E-step...
# ...done
# nan
# starting M-step...
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# L_theta:  2.344501088505617e-08
# L_eta:  4.721616766369499e-08
#
# starting epoch 33.0
#
# starting E-step...
# ...done
# nan
# starting M-step...
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# L_theta:  1.1722505442528104e-08
# L_eta:  2.3608083831847534e-08
#
# starting epoch 34.0
#
# starting E-step...
# ...done
# nan
# starting M-step...
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# L_theta:  5.861252721264064e-09
# L_eta:  1.180404191592379e-08
#
# starting epoch 35.0
#
# starting E-step...
# ...done
# nan
# starting M-step...
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# L_theta:  2.93062636063204e-09
# L_eta:  5.902020957961912e-09
#
# starting epoch 36.0
#
# starting E-step...
# ...done
# nan
# starting M-step...
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# L_theta:  1.4653131803160248e-09
# L_eta:  2.9510104789809654e-09
#
# starting epoch 37.0
#
# starting E-step...
# ...done
# nan
# starting M-step...
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# L_theta:  7.326565901580145e-10
# L_eta:  1.4755052394904868e-09
#
# starting epoch 38.0
#
# starting E-step...
# ...done
# nan
# starting M-step...
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# L_theta:  3.66328295079008e-10
# L_eta:  7.377526197452451e-10
#
# starting epoch 39.0
#
# starting E-step...
# ...done
# nan
# starting M-step...
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# L_theta:  1.8316414753950453e-10
# L_eta:  3.6887630987262357e-10
#
# starting epoch 40.0
#
# starting E-step...
# ...done
# nan
# starting M-step...
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# L_theta:  9.158207376975247e-11
# L_eta:  1.844381549363122e-10
#
# starting epoch 41.0
#
# starting E-step...
# ...done
# nan
# starting M-step...
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# L_theta:  4.579103688487636e-11
# L_eta:  9.221907746815634e-11
#
# starting epoch 42.0
#
# starting E-step...
# ...done
# nan
# starting M-step...
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# L_theta:  2.2895518442438244e-11
# L_eta:  4.61095387340783e-11
#
# starting epoch 43.0
#
# starting E-step...
# ...done
# nan
# starting M-step...
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# L_theta:  1.1447759221219153e-11
# L_eta:  2.3054769367039212e-11
#
# starting epoch 44.0
#
# starting E-step...
# ...done
# nan
# starting M-step...
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# L_theta:  5.7238796106095876e-12
# L_eta:  1.1527384683519629e-11
#
# starting epoch 45.0
#
# starting E-step...
# ...done
# nan
# starting M-step...
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# L_theta:  2.8619398053048e-12
# L_eta:  5.7636923417598265e-12
#
# starting epoch 46.0
#
# starting E-step...
# ...done
# nan
# starting M-step...
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# L_theta:  1.4309699026524036e-12
# L_eta:  2.881846170879921e-12
#
# starting epoch 47.0
#
# starting E-step...
# ...done
# nan
# starting M-step...
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# L_theta:  7.154849513262038e-13
# L_eta:  1.4409230854399645e-12
#
# starting epoch 48.0
#
# starting E-step...
# ...done
# nan
# starting M-step...
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# L_theta:  3.577424756631028e-13
# L_eta:  7.204615427199841e-13
#
# starting epoch 49.0
#
# starting E-step...
# ...done
# nan
# starting M-step...
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# L_theta:  1.788712378315518e-13
# L_eta:  3.6023077135999284e-13
#
# starting epoch 50.0
#
# starting E-step...
# ...done
# nan
# starting M-step...
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# L_theta:  8.943561891577613e-14
# L_eta:  1.8011538567999687e-13
#
# starting epoch 51.0
#
# starting E-step...
# ...done
# nan
# starting M-step...
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# L_theta:  4.471780945788818e-14
# L_eta:  9.005769283999866e-14
#
# starting epoch 52.0
#
# starting E-step...
# ...done
# nan
# starting M-step...
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# L_theta:  2.2358904728944162e-14
# L_eta:  4.502884641999948e-14
#
# starting epoch 53.0
#
# starting E-step...
# ...done
# nan
# starting M-step...
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# L_theta:  1.1179452364472111e-14
# L_eta:  2.25144232099998e-14
#
# starting epoch 54.0
#
# starting E-step...
# ...done
# nan
# starting M-step...
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# L_theta:
#          2.49928256e+00, -9.29647786e-02,  2.14620112e+00,
#          6.53020090e-17, -6.77934118e-01, -7.12768314e-01,
#          1.34414191e-01, -6.31091703e-03,  1.16367324e+00,
#          9.39245039e+00,  2.79749851e-01],
#        [ 1.00675198e-01,  7.00536306e-03,  1.09715031e-01,
#         -1.46354638e-03, -1.33195257e-02,  1.27900990e-02,
#          8.42096795e-02, -3.09565369e-03,  7.15574627e-02,
#          2.22291176e-18, -2.95973960e-02, -1.99658547e-02,
#          4.48705108e-03, -2.10217757e-04,  3.87838805e-02,
#          2.79749851e-01,  1.00933869e+00]])
#       jac: array([-2.68988117e-03,  1.52913472e-04,  1.65206280e-03, -3.03365507e-05,
#         3.28290924e-03,  2.84578268e-04, -3.86690371e-03, -6.52728932e-05,
#         1.54518778e-03, -3.93850279e-23, -1.68854688e-03, -9.11125400e-04,
#         9.92681416e-05, -4.44745971e-06,  8.34185450e-04,  6.12803991e-03,
#         2.06603645e-04])
#   message: 'Desired error not necessarily achieved due to precision loss.'
#      nfev: 74
#       nit: 17
#      njev: 62
#    status: 2
#   success: False
#         x: array([ 3.83436947,  4.97387499,  1.72102849, -0.01039049, -0.00534894,
#        -0.2116046 ,  0.02719477,  0.38678665, -1.68908548, -1.66329277,
#        -1.50751157, -1.86913324, -0.71598557, -0.70126202, -1.05267155,
#         0.72618682,  0.01378403])

# %% [markdown]
# # Plot Results

# %%
def plot_ll(optims,x_time=False):
    
    ll_star = optims["control"].log_like_trace[-1]
    legend = []
    
    for method in methods:
        
        for partial_E in [0,0.5,1]:
            
            PE = (partial_E == 0.5) or (partial_E == 1)
            M = int(partial_E == 0) + int(partial_E == 0.5) + 10*(partial_E == 1)
            
            if (method,partial_E) in optims:
                
                optim = optims[(method,partial_E)]
                if x_time:
                    plt.plot(optim.time_trace,np.log10(ll_star-optim.log_like_trace))
                else:
                    plt.plot(optim.epoch_trace,np.log10(ll_star-optim.log_like_trace))    
                title = method 
                if partial_E:
                    title += ", partial E"
                else:
                    title += ", no partial E"
                title += ", M = %dT" % M
                
                legend.append(title)
                
    plt.ylabel(r"$\log_{10}\left[\log p(\mathbf{y} ; \theta^*, \eta^*) - \log p(\mathbf{y} ; \theta, \eta)\right]$")
    plt.legend(legend)
    if x_time:
        plt.xlabel("Seconds of Computation")
        plt.savefig("../plt/log-like_v_time_exp_%d.png" % experiment,dpi=500)
    else:
        plt.xlabel("Epoch")
        plt.savefig("../plt/log-like_v_epoch_exp_%d.png" % experiment,dpi=500)
    plt.show()
                
    return

def plot_results(optim,ll_star,method,partial_E,M,experiment=1,iters=None):
    
    title = method 
    if partial_E:
        title += ", partial E-step"
    title += ", M = %dT" % M
    
    if iters is None:
        iters=len(optim.theta_trace)
        
    if method.startswith("SAGA"):
        x = (np.arange(iters) / optim.T)
    else:
        x = np.arange(iters)
    
    # plot log of gradient of log-likelihood
    plt.plot(np.log10(optim.grad_norm_trace))
    plt.axhline(-3, c = 'k', linestyle = "--")
    plt.title(r"$\log_{10}$ of Gradient Norm v Epoch, %s" % title)
    plt.xlabel("Epoch (k)")
    plt.ylabel(r"$\log ||\widehat \nabla_\theta F^{(k,m)} + \widehat \nabla_\eta G^{(k,m)}||$")
    plt.savefig("../plt/grad-hat-ll-%s-%s-%d-%d.png"%(method,partial_E,M,experiment),dpi=300)
    plt.show()

    # plot means
    legend = []
    for k0 in range(optim.K[0]):
        for k1 in range(optim.K[1]):
            plt.plot(x,[optim.theta_trace[t][1][k0]['Y']['mu'][k1] for t in range(len(optim.theta_trace))])
            legend.append(r"$\mu^{(%d,%d)}$"%(k0+1,k1+1))
    for hline in range(optim.K[0]):
        plt.axhline(hline, c = 'k', linestyle = "--")
        
    plt.title("$\mu$ v Epoch, %s" % title)
    plt.xlabel("Epoch")
    plt.legend(legend)
    plt.savefig("../plt/mu-%s-%s-%d-%d.png"%(method,partial_E,M,experiment),dpi=500)
    plt.show()
    
    # plot log(sigma)
    legend = []
    for k0 in range(optim.K[0]):
        for k1 in range(optim.K[1]):
            plt.plot(x,[optim.theta_trace[t][1][k0]['Y']['log_sig'][k1] for t in range(len(optim.theta_trace))])
            legend.append(r"$\log\left(\sigma^{(%d,%d)}\right)$"%(k0+1,k1+1))
    for hline in range(optim.K[0]):
        plt.axhline(hline-1, c = 'k', linestyle = "--")
        
    plt.title(r"$\log\left(\sigma\right)$ v Epoch, %s" % title)
    plt.xlabel("Epoch")
    plt.legend(legend)
    plt.savefig("../plt/log-sig-%s-%s-%d-%d.png"%(method,partial_E,M,experiment),dpi=500)
    plt.show()
    
    # plot eta
    legend = []
    for k in range(optim.K[0]):
        for l in range(optim.K[0]):
            if k != l:
                plt.plot(x,[optim.eta_trace[i][0][k,l] for i in range(len(optim.eta_trace))])
                legend.append(r"$\eta^{(%d,%d)}$" % (k+1,l+1))
    plt.title(r"$\eta$ v Epoch, %s" % title)
    plt.xlabel("Epoch")
    plt.legend(legend)
    plt.savefig("../plt/eta-%s-%s-%d-%d.png"%(method,partial_E,M,experiment),dpi=500)
    plt.show()
    
    #plt.plot([optim.grad_theta_trace[i][0]['Y']['log_sig'][0] for i in range(len(optim.theta_trace))])
    #plt.plot([optim.grad_theta_trace[i][0]['Y']['log_sig'][1] for i in range(len(optim.theta_trace))])
    #plt.plot([optim.grad_theta_trace[i][0]['Y']['log_sig'][2] for i in range(len(optim.theta_trace))])
    #plt.title("Gradients of Standard Deviations v iteration number")
    #plt.show()

# %%
plot_ll(optims,x_time=True)
plot_ll(optims,x_time=False)

for method in methods:#["EM","SGD","SAG","SVRG","SAGA"]:
    for partial_E in [0,0.5,1]:
        PE = (partial_E == 0.5) or (partial_E == 1)
        M = int(partial_E == 0) + int(partial_E == 0.5) + 10*(partial_E == 1)
        if (method,partial_E) in optims:
            plot_results(optims[(method,partial_E)],optim_ll,method,PE,M)
# Out:
# /Users/evsi8432/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:17: RuntimeWarning:
#
# invalid value encountered in log10
#
# /Users/evsi8432/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:17: RuntimeWarning:
#
# invalid value encountered in log10
#
# /Users/evsi8432/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:17: RuntimeWarning:
#
# invalid value encountered in log10
# /Users/evsi8432/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:19: RuntimeWarning:
#
# invalid value encountered in log10
#
# /Users/evsi8432/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:19: RuntimeWarning:
#
# invalid value encountered in log10
#
# /Users/evsi8432/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:19: RuntimeWarning:
#
# invalid value encountered in log10

# %%
print(optims["control"].theta[0])
print(optims["control"].theta[1][0])
print(optims["control"].theta[1][1])
print("")
print(optims[("EM",0)].theta[0])
print(optims[("EM",0)].theta[1][0])
print(optims[("EM",0)].theta[1][1])

# %%
print(optims["control"].Gamma)
print(optims[("EM",0)].Gamma)

# %%
print(optims["control"].delta)
print(optims[("EM",0)].delta)
