# %%
import sys
#sys.path.remove('/Users/evsi8432/Documents/Research/CarHHMM-DFT/Repository/Code')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm

from scipy.stats import gamma
from scipy.stats import norm
from scipy.stats import vonmises
from scipy.stats import multivariate_normal
from scipy.stats import gaussian_kde
from scipy.stats import circstd
from scipy.special import iv
from scipy.special import expit
from scipy.special import logit
from scipy.special import logsumexp
from scipy.optimize import minimize
from scipy.optimize import minimize_scalar
from scipy.optimize import LinearConstraint
from scipy.signal import convolve
from scipy.interpolate import interp1d

from copy import deepcopy

from importlib import reload

import time
import pickle

# %%
import Preprocessor
import Parameters
import HHMM
import Visualisor
import optimizor

from optimizor import eta_2_Gamma
from optimizor import Gamma_2_eta
from optimizor import logdotexp

# %% [markdown]
# # Initialize Parameters

# %%
# make parameters
pars = Parameters.Parameters()
pars.features = [{'Y':{'corr':False,'f':'normal'}}, # coarse-scale
                 {}]
pars.K = [3,1]
T = 100

# %% [markdown]
# # Simulate Data

# %%
N = 3
X = np.zeros(T,dtype=int)
data = []

# define parameters
Gamma = np.array([[0.5,0.25,0.25],
                  [0.25,0.5,0.25],
                  [0.25,0.25,0.5]])
delta = np.ones(pars.K[0])/pars.K[0]

mus = [-1,0,1]
sigs = [1.0,1.0,1.0]

for t in range(T):
    
    if t == 0:
        X[t] = np.random.choice(pars.K[0],p=delta)
    else:
        X[t] = np.random.choice(pars.K[0],p=Gamma[X[t-1]])

    data.append({'Y':mus[X[t]] + sigs[X[t]]*np.random.normal(),
                 'subdive_features':[]})

# %%
plt.plot(X)
plt.show()
plt.plot([x["Y"] for x in data],'.')
plt.show()

# %% [markdown]
# # Initialize optimizor and select intial values

# %%
# initialize objects
hhmm = HHMM.HHMM(pars,data)

hhmm.theta = [{'Y': {'mu': np.array([-2.0,  -1.0,  0.0]),
                     'log_sig': np.array([0.0, 0.0, 0.0]),
                     'corr': np.array([0.0, 0.0, 0.0])}},
               [{}, {}, {}]]

hhmm.Gamma = [np.array([[0.50, 0.25, 0.25],
                        [0.25, 0.50, 0.25],
                        [0.25, 0.25, 0.50]]),
               [np.array([[1.]]), np.array([[1.]]), np.array([[1.]])]]

hhmm.eta = Gamma_2_eta(hhmm.Gamma)

# %%
#L = 0.5*(4/np.exp(0))**2 # lipschitz constant

optim1 = optimizor.optimizor(hhmm)
optim1.step_size = 1e-3
optim1.param_bounds["Y"]["mu"] = [-100,100]
optim1.param_bounds["Y"]["log_sig"] = [-1,1]

# set theta and eta to true values
optim2 = optimizor.optimizor(hhmm)
optim2.step_size = 1e-3 / np.sqrt(T)
optim2.param_bounds["Y"]["mu"] = [-100,100]
optim2.param_bounds["Y"]["log_sig"] = [-1,1]

# print values
print(optim1.theta)
print(optim1.eta)
print(optim1.param_bounds)
print(optim1.step_size)
# Out:
# [{'Y': {'mu': array([-2., -1.,  0.]), 'log_sig': array([0., 0., 0.]), 'corr': array([0., 0., 0.])}}, [{}, {}, {}]]
# [array([[ 0.        , -0.69314718, -0.69314718],
#        [-0.69314718,  0.        , -0.69314718],
#        [-0.69314718, -0.69314718,  0.        ]]), [array([[0.]]), array([[0.]]), array([[0.]])]]
# {'Y': {'mu': [-100, 100], 'log_sig': [-1, 1]}}
# 0.001

# %% [markdown]
# # Train the HMM

# %%
# do first optimization
num_epochs = 250
optim1.step_num = 1
optim1.train_HHMM(num_epochs,random_t=False,decay_ind=np.infty)

# do second optimization
num_epochs = 250
optim2.step_num = 1
optim2.train_HHMM(num_epochs,h=np.sqrt(T),decay_ind=np.infty)
# Out:
# finished epoch num:  0
# last direction:  forward
# log-likelihood:  -171.14211107514487
# finished epoch num:  1
# last direction:  backward
# log-likelihood:  -171.1418772199725
# finished epoch num:  2
# last direction:  forward
# log-likelihood:  -171.14152655898008
# finished epoch num:  3
# last direction:  backward
# log-likelihood:  -171.14130215106584
# finished epoch num:  4
# last direction:  forward
# log-likelihood:  -171.14096635262192
# finished epoch num:  5
# last direction:  backward
# log-likelihood:  -171.14075080823696
# finished epoch num:  6
# last direction:  forward
# log-likelihood:  -171.14042911320564
# finished epoch num:  7
# last direction:  backward
# log-likelihood:  -171.14022188700116
# finished epoch num:  8
# last direction:  forward
# log-likelihood:  -171.1399135793411
# finished epoch num:  9
# last direction:  backward
# log-likelihood:  -171.1397141619098
# finished epoch num:  10
# last direction:  forward
# log-likelihood:  -171.13941856615088
# finished epoch num:  11
# last direction:  backward
# log-likelihood:  -171.1392264817341
# finished epoch num:  12
# last direction:  forward
# log-likelihood:  -171.13894296060008
# finished epoch num:  13
# last direction:  backward
# log-likelihood:  -171.13875776493356
# finished epoch num:  14
# last direction:  forward
# log-likelihood:  -171.138485717101
# finished epoch num:  15
# last direction:  backward
# log-likelihood:  -171.13830699539042
# finished epoch num:  16
# last direction:  forward
# log-likelihood:  -171.13804585337738
# finished epoch num:  17
# last direction:  backward
# log-likelihood:  -171.1378732183971
# finished epoch num:  18
# last direction:  forward
# log-likelihood:  -171.13762244657468
# finished epoch num:  19
# last direction:  backward
# log-likelihood:  -171.13745553688258
# finished epoch num:  20
# last direction:  forward
# log-likelihood:  -171.13721462960157
# finished epoch num:  21
# last direction:  backward
# log-likelihood:  -171.13705310786426
# finished epoch num:  22
# last direction:  forward
# log-likelihood:  -171.13682158769197
# finished epoch num:  23
# last direction:  backward
# log-likelihood:  -171.13666513911195
# finished epoch num:  24
# last direction:  forward
# log-likelihood:  -171.1364425551725
# finished epoch num:  25
# last direction:  backward
# log-likelihood:  -171.13629088601385
# finished epoch num:  26
# last direction:  forward
# log-likelihood:  -171.1360768124249
# finished epoch num:  27
# last direction:  backward
# log-likelihood:  -171.13592964863068
# finished epoch num:  28
# last direction:  forward
# log-likelihood:  -171.13572368303306
# finished epoch num:  29
# last direction:  backward
# log-likelihood:  -171.13558076892923
# finished epoch num:  30
# last direction:  forward
# log-likelihood:  -171.13538253110335
# finished epoch num:  31
# last direction:  backward
# log-likelihood:  -171.1352436281833
# finished epoch num:  32
# last direction:  forward
# log-likelihood:  -171.13505275874763
# finished epoch num:  33
# last direction:  backward
# log-likelihood:  -171.1349176445339
# finished epoch num:  34
# last direction:  forward
# log-likelihood:  -171.1347338037205
# finished epoch num:  35
# last direction:  backward
# log-likelihood:  -171.13460227069893
# finished epoch num:  36
# last direction:  forward
# log-likelihood:  -171.13442513720116
# finished epoch num:  37
# last direction:  backward
# log-likelihood:  -171.13429699182242
# finished epoch num:  38
# last direction:  forward
# log-likelihood:  -171.13412626171242
# finished epoch num:  39
# last direction:  backward
# log-likelihood:  -171.13400132345694
# finished epoch num:  40
# last direction:  forward
# log-likelihood:  -171.13383670916664
# finished epoch num:  41
# last direction:  backward
# log-likelihood:  -171.1337148096701
# finished epoch num:  42
# last direction:  forward
# log-likelihood:  -171.13355603903406
# finished epoch num:  43
# last direction:  backward
# log-likelihood:  -171.13343702126878
# finished epoch num:  44
# last direction:  forward
# log-likelihood:  -171.13328383662326
# finished epoch num:  45
# last direction:  backward
# log-likelihood:  -171.1331675541324
# finished epoch num:  46
# last direction:  forward
# log-likelihood:  -171.13301971146902
# finished epoch num:  47
# last direction:  backward
# log-likelihood:  -171.13290602765045
# finished epoch num:  48
# last direction:  forward
# log-likelihood:  -171.132763295821
# finished epoch num:  49
# last direction:  backward
# log-likelihood:  -171.13265208325728
# finished epoch num:  50
# last direction:  forward
# log-likelihood:  -171.132514243225
# finished epoch num:  51
# last direction:  backward
# log-likelihood:  -171.13240538305854
# finished epoch num:  52
# last direction:  forward
# log-likelihood:  -171.1322722271954
# finished epoch num:  53
# last direction:  backward
# log-likelihood:  -171.13216560854258
# finished epoch num:  54
# last direction:  forward
# log-likelihood:  -171.1320369399685
# finished epoch num:  55
# last direction:  backward
# log-likelihood:  -171.1319324593734
# finished epoch num:  56
# last direction:  forward
# log-likelihood:  -171.13180809133556
# finished epoch num:  57
# last direction:  backward
# log-likelihood:  -171.1317056522595
# finished epoch num:  58
# last direction:  forward
# log-likelihood:  -171.13158540754787
# finished epoch num:  59
# last direction:  backward
# log-likelihood:  -171.13148491989298
# finished epoch num:  60
# last direction:  forward
# log-likelihood:  -171.1313686302924
# finished epoch num:  61
# last direction:  backward
# log-likelihood:  -171.131270009956
# finished epoch num:  62
# last direction:  forward
# log-likelihood:  -171.13115751573037
# finished epoch num:  63
# last direction:  backward
# log-likelihood:  -171.13106068419003
# finished epoch num:  64
# last direction:  forward
# log-likelihood:  -171.1309518335975
# finished epoch num:  65
# last direction:  backward
# log-likelihood:  -171.13085671752276
# finished epoch num:  66
# last direction:  forward
# log-likelihood:  -171.13075136636084
# finished epoch num:  67
# last direction:  backward
# log-likelihood:  -171.13065789725204
# finished epoch num:  68
# last direction:  forward
# log-likelihood:  -171.13055590842907
# finished epoch num:  69
# last direction:  backward
# log-likelihood:  -171.1304640222797
# finished epoch num:  70
# last direction:  forward
# log-likelihood:  -171.13036526541293
# finished epoch num:  71
# last direction:  backward
# log-likelihood:  -171.13027490239483
# finished epoch num:  72
# last direction:  forward
# log-likelihood:  -171.13017925343226
# finished epoch num:  73
# last direction:  backward
# log-likelihood:  -171.1300903576021
# finished epoch num:  74
# last direction:  forward
# log-likelihood:  -171.12999769846684
# finished epoch num:  75
# last direction:  backward
# log-likelihood:  -171.12991021749357
# finished epoch num:  76
# last direction:  forward
# log-likelihood:  -171.12982043574968
# finished epoch num:  77
# last direction:  backward
# log-likelihood:  -171.12973432065854
# finished epoch num:  78
# last direction:  forward
# log-likelihood:  -171.12964730919737
# finished epoch num:  79
# last direction:  backward
# log-likelihood:  -171.12956251413317
# finished epoch num:  80
# last direction:  forward
# log-likelihood:  -171.1294781708777
# finished epoch num:  81
# last direction:  backward
# log-likelihood:  -171.129394652883
# finished epoch num:  82
# last direction:  forward
# log-likelihood:  -171.12931288051035
# finished epoch num:  83
# last direction:  backward
# log-likelihood:  -171.1292305993206
# finished epoch num:  84
# last direction:  forward
# log-likelihood:  -171.12915130500068
# finished epoch num:  85
# last direction:  backward
# log-likelihood:  -171.12907022285137
# finished epoch num:  86
# last direction:  forward
# log-likelihood:  -171.1289933180019
# finished epoch num:  87
# last direction:  backward
# log-likelihood:  -171.12891339945037
# finished epoch num:  88
# last direction:  forward
# log-likelihood:  -171.12883879950547
# finished epoch num:  89
# last direction:  backward
# log-likelihood:  -171.12876001126514
# finished epoch num:  90
# last direction:  forward
# log-likelihood:  -171.12868763545856
# finished epoch num:  91
# last direction:  backward
# log-likelihood:  -171.12860994624427
# finished epoch num:  92
# last direction:  forward
# log-likelihood:  -171.12853971740458
# finished epoch num:  93
# last direction:  backward
# log-likelihood:  -171.1284630977886
# finished epoch num:  94
# last direction:  forward
# log-likelihood:  -171.12839494214728
# finished epoch num:  95
# last direction:  backward
# log-likelihood:  -171.12831936442578
# finished epoch num:  96
# last direction:  forward
# log-likelihood:  -171.12825321143626
# finished epoch num:  97
# last direction:  backward
# log-likelihood:  -171.1281786495052
# finished epoch num:  98
# last direction:  forward
# log-likelihood:  -171.12811443167269
# finished epoch num:  99
# last direction:  backward
# log-likelihood:  -171.1280408609119
# finished epoch num:  100
# last direction:  forward
# log-likelihood:  -171.1279785136333
# finished epoch num:  101
# last direction:  backward
# log-likelihood:  -171.12790591079946
# finished epoch num:  102
# last direction:  forward
# log-likelihood:  -171.127845372212
# finished epoch num:  103
# last direction:  backward
# log-likelihood:  -171.12777371533923
# finished epoch num:  104
# last direction:  forward
# log-likelihood:  -171.12771492617858
# finished epoch num:  105
# last direction:  backward
# log-likelihood:  -171.12764419448524
# finished epoch num:  106
# last direction:  forward
# log-likelihood:  -171.12758709795193
# finished epoch num:  107
# last direction:  backward
# log-likelihood:  -171.12751727175518
# finished epoch num:  108
# last direction:  forward
# log-likelihood:  -171.12746181338846
# finished epoch num:  109
# last direction:  backward
# log-likelihood:  -171.12739287402422
# finished epoch num:  110
# last direction:  forward
# log-likelihood:  -171.12733900158335
# finished epoch num:  111
# last direction:  backward
# log-likelihood:  -171.12727093133188
# finished epoch num:  112
# last direction:  forward
# log-likelihood:  -171.1272185946842
# finished epoch num:  113
# last direction:  backward
# log-likelihood:  -171.1271513767023
# finished epoch num:  114
# last direction:  forward
# log-likelihood:  -171.1271005277175
# finished epoch num:  115
# last direction:  backward
# log-likelihood:  -171.12703414597405
# finished epoch num:  116
# last direction:  forward
# log-likelihood:  -171.12698473842542
# finished epoch num:  117
# last direction:  backward
# log-likelihood:  -171.12691917764255
# finished epoch num:  118
# last direction:  forward
# log-likelihood:  -171.12687116711245
# finished epoch num:  119
# last direction:  backward
# log-likelihood:  -171.12680641271098
# finished epoch num:  120
# last direction:  forward
# log-likelihood:  -171.12675975650268
# finished epoch num:  121
# last direction:  backward
# log-likelihood:  -171.12669579455095
# finished epoch num:  122
# last direction:  forward
# log-likelihood:  -171.12665045160534
# finished epoch num:  123
# last direction:  backward
# log-likelihood:  -171.12658726877277
# finished epoch num:  124
# last direction:  forward
# log-likelihood:  -171.12654319958932
# finished epoch num:  125
# last direction:  backward
# log-likelihood:  -171.1264807831025
# finished epoch num:  126
# last direction:  forward
# log-likelihood:  -171.12643794966525
# finished epoch num:  127
# last direction:  backward
# log-likelihood:  -171.12637628726736
# finished epoch num:  128
# last direction:  forward
# log-likelihood:  -171.12633465297444
# finished epoch num:  129
# last direction:  backward
# log-likelihood:  -171.12627373288905
# finished epoch num:  130
# last direction:  forward
# log-likelihood:  -171.12623326248607
# finished epoch num:  131
# last direction:  backward
# log-likelihood:  -171.12617307338164
# finished epoch num:  132
# last direction:  forward
# log-likelihood:  -171.1261337329
# finished epoch num:  133
# last direction:  backward
# log-likelihood:  -171.1260742638582
# finished epoch num:  134
# last direction:  forward
# log-likelihood:  -171.12603602055466
# finished epoch num:  135
# last direction:  backward
# log-likelihood:  -171.12597726104119
# finished epoch num:  136
# last direction:  forward
# log-likelihood:  -171.1259400833428
# finished epoch num:  137
# last direction:  backward
# log-likelihood:  -171.12588202318
# finished epoch num:  138
# last direction:  forward
# log-likelihood:  -171.12584588063055
# finished epoch num:  139
# last direction:  backward
# log-likelihood:  -171.12578850997198
# finished epoch num:  140
# last direction:  forward
# log-likelihood:  -171.12575337318268
# finished epoch num:  141
# last direction:  backward
# log-likelihood:  -171.12569668249014
# finished epoch num:  142
# last direction:  forward
# log-likelihood:  -171.12566252309102
# finished epoch num:  143
# last direction:  backward
# log-likelihood:  -171.1256065031133
# finished epoch num:  144
# last direction:  forward
# log-likelihood:  -171.12557329370958
# finished epoch num:  145
# last direction:  backward
# log-likelihood:  -171.12551793546191
# finished epoch num:  146
# last direction:  forward
# log-likelihood:  -171.12548564959073
# finished epoch num:  147
# last direction:  backward
# log-likelihood:  -171.12543094433738
# finished epoch num:  148
# last direction:  forward
# log-likelihood:  -171.1253995564276
# finished epoch num:  149
# last direction:  backward
# log-likelihood:  -171.12534549566456
# finished epoch num:  150
# last direction:  forward
# log-likelihood:  -171.12531498099887
# finished epoch num:  151
# last direction:  backward
# log-likelihood:  -171.12526155643852
# finished epoch num:  152
# last direction:  forward
# log-likelihood:  -171.12523189111712
# finished epoch num:  153
# last direction:  backward
# log-likelihood:  -171.12517909467363
# finished epoch num:  154
# last direction:  forward
# log-likelihood:  -171.12515025557977
# finished epoch num:  155
# last direction:  backward
# log-likelihood:  -171.12509807935626
# finished epoch num:  156
# last direction:  forward
# log-likelihood:  -171.12507004412439
# finished epoch num:  157
# last direction:  backward
# log-likelihood:  -171.12501848040068
# finished epoch num:  158
# last direction:  forward
# log-likelihood:  -171.1249912273842
# finished epoch num:  159
# last direction:  backward
# log-likelihood:  -171.12494026860588
# finished epoch num:  160
# last direction:  forward
# log-likelihood:  -171.1249137768493
# finished epoch num:  161
# last direction:  backward
# log-likelihood:  -171.124863415617
# finished epoch num:  162
# last direction:  forward
# log-likelihood:  -171.12483766482708
# finished epoch num:  163
# last direction:  backward
# log-likelihood:  -171.12478789388737
# finished epoch num:  164
# last direction:  forward
# log-likelihood:  -171.12476286440682
# finished epoch num:  165
# last direction:  backward
# log-likelihood:  -171.12471367664406
# finished epoch num:  166
# last direction:  forward
# log-likelihood:  -171.12468934942657
# finished epoch num:  167
# last direction:  backward
# log-likelihood:  -171.12464073785372
# finished epoch num:  168
# last direction:  forward
# log-likelihood:  -171.12461709444025
# finished epoch num:  169
# last direction:  backward
# log-likelihood:  -171.12456905219264
# finished epoch num:  170
# last direction:  forward
# log-likelihood:  -171.12454607468788
# finished epoch num:  171
# last direction:  backward
# log-likelihood:  -171.1244985950159
# finished epoch num:  172
# last direction:  forward
# log-likelihood:  -171.12447626606738
# finished epoch num:  173
# last direction:  backward
# log-likelihood:  -171.124429342331
# finished epoch num:  174
# last direction:  forward
# log-likelihood:  -171.1244076451079
# finished epoch num:  175
# last direction:  backward
# log-likelihood:  -171.12436127077027
# finished epoch num:  176
# last direction:  forward
# log-likelihood:  -171.124340188944
# finished epoch num:  177
# last direction:  backward
# log-likelihood:  -171.12429435756692
# finished epoch num:  178
# last direction:  forward
# log-likelihood:  -171.12427387529246
# finished epoch num:  179
# last direction:  backward
# log-likelihood:  -171.12422858053134
# finished epoch num:  180
# last direction:  forward
# log-likelihood:  -171.12420868242913
# finished epoch num:  181
# last direction:  backward
# log-likelihood:  -171.12416391802847
# finished epoch num:  182
# last direction:  forward
# log-likelihood:  -171.12414458916763
# finished epoch num:  183
# last direction:  backward
# log-likelihood:  -171.12410034895777
# finished epoch num:  184
# last direction:  forward
# log-likelihood:  -171.1240815748394
# finished epoch num:  185
# last direction:  backward
# log-likelihood:  -171.12403785273244
# finished epoch num:  186
# last direction:  forward
# log-likelihood:  -171.1240196192746
# finished epoch num:  187
# last direction:  backward
# log-likelihood:  -171.12397640926088
# finished epoch num:  188
# last direction:  forward
# log-likelihood:  -171.1239587027837
# finished epoch num:  189
# last direction:  backward
# log-likelihood:  -171.12391599892922
# finished epoch num:  190
# last direction:  forward
# log-likelihood:  -171.12389880614015
# finished epoch num:  191
# last direction:  backward
# log-likelihood:  -171.12385660258377
# finished epoch num:  192
# last direction:  forward
# log-likelihood:  -171.12383991056498
# finished epoch num:  193
# last direction:  backward
# log-likelihood:  -171.12379820151548
# finished epoch num:  194
# last direction:  forward
# log-likelihood:  -171.12378199770998
# finished epoch num:  195
# last direction:  backward
# log-likelihood:  -171.12374077744437
# finished epoch num:  196
# last direction:  forward
# log-likelihood:  -171.1237250496443
# finished epoch num:  197
# last direction:  backward
# log-likelihood:  -171.12368431250536
# finished epoch num:  198
# last direction:  forward
# log-likelihood:  -171.12366904883976
# finished epoch num:  199
# last direction:  backward
# log-likelihood:  -171.12362878923432
# finished epoch num:  200
# last direction:  forward
# log-likelihood:  -171.1236139781581
# finished epoch num:  201
# last direction:  backward
# log-likelihood:  -171.12357419055488
# finished epoch num:  202
# last direction:  forward
# log-likelihood:  -171.12355982083753
# finished epoch num:  203
# last direction:  backward
# log-likelihood:  -171.12352049976596
# finished epoch num:  204
# last direction:  forward
# log-likelihood:  -171.1235065604816
# finished epoch num:  205
# last direction:  backward
# log-likelihood:  -171.12346770053054
# finished epoch num:  206
# last direction:  forward
# log-likelihood:  -171.12345418104746
# finished epoch num:  207
# last direction:  backward
# log-likelihood:  -171.12341577686342
# finished epoch num:  208
# last direction:  forward
# log-likelihood:  -171.12340266683503
# finished epoch num:  209
# last direction:  backward
# log-likelihood:  -171.12336471312122
# finished epoch num:  210
# last direction:  forward
# log-likelihood:  -171.1233520024763
# finished epoch num:  211
# last direction:  backward
# log-likelihood:  -171.12331449399136
# finished epoch num:  212
# last direction:  forward
# log-likelihood:  -171.12330217292583
# finished epoch num:  213
# last direction:  backward
# log-likelihood:  -171.12326510448312
# finished epoch num:  214
# last direction:  forward
# log-likelihood:  -171.12325316345115
# finished epoch num:  215
# last direction:  backward
# log-likelihood:  -171.1232165299174
# finished epoch num:  216
# last direction:  forward
# log-likelihood:  -171.12320495962317
# finished epoch num:  217
# last direction:  backward
# log-likelihood:  -171.1231687559184
# finished epoch num:  218
# last direction:  forward
# log-likelihood:  -171.12315754730895
# finished epoch num:  219
# last direction:  backward
# log-likelihood:  -171.1231217684045
# finished epoch num:  220
# last direction:  forward
# log-likelihood:  -171.12311091266164
# finished epoch num:  221
# last direction:  backward
# log-likelihood:  -171.12307555358078
# finished epoch num:  222
# last direction:  forward
# log-likelihood:  -171.12306504211378
# finished epoch num:  223
# last direction:  backward
# log-likelihood:  -171.12303009793027
# finished epoch num:  224
# last direction:  forward
# log-likelihood:  -171.12301992236937
# finished epoch num:  225
# last direction:  backward
# log-likelihood:  -171.12298538820684
# finished epoch num:  226
# last direction:  forward
# log-likelihood:  -171.1229755403966
# finished epoch num:  227
# last direction:  backward
# log-likelihood:  -171.1229414114286
# finished epoch num:  228
# last direction:  forward
# log-likelihood:  -171.1229318834209
# finished epoch num:  229
# last direction:  backward
# log-likelihood:  -171.1228981548695
# finished epoch num:  230
# last direction:  forward
# log-likelihood:  -171.12288893891773
# finished epoch num:  231
# last direction:  backward
# log-likelihood:  -171.1228556060539
# finished epoch num:  232
# last direction:  forward
# log-likelihood:  -171.12284669460718
# finished epoch num:  233
# last direction:  backward
# log-likelihood:  -171.1228137527499
# finished epoch num:  234
# last direction:  forward
# log-likelihood:  -171.1228051384468
# finished epoch num:  235
# last direction:  backward
# log-likelihood:  -171.12277258296254
# finished epoch num:  236
# last direction:  forward
# log-likelihood:  -171.12276425862603
# finished epoch num:  237
# last direction:  backward
# log-likelihood:  -171.122732084929
# finished epoch num:  238
# last direction:  forward
# log-likelihood:  -171.12272404356062
# finished epoch num:  239
# last direction:  backward
# log-likelihood:  -171.12269224711164
# finished epoch num:  240
# last direction:  forward
# log-likelihood:  -171.12268448188723
# finished epoch num:  241
# last direction:  backward
# log-likelihood:  -171.1226530581937
# finished epoch num:  242
# last direction:  forward
# log-likelihood:  -171.12264556245714
# finished epoch num:  243
# last direction:  backward
# log-likelihood:  -171.12261450707274
# finished epoch num:  244
# last direction:  forward
# log-likelihood:  -171.1226072743325
# finished epoch num:  245
# last direction:  backward
# log-likelihood:  -171.12257658285674
# finished epoch num:  246
# last direction:  forward
# log-likelihood:  -171.12256960678013
# finished epoch num:  247
# last direction:  backward
# log-likelihood:  -171.12253927485875
# finished epoch num:  248
# last direction:  forward
# log-likelihood:  -171.12253254926782
# finished epoch num:  249
# last direction:  backward
# log-likelihood:  -171.12250257259126
# finished epoch num:  0
# last direction:  forward
# log-likelihood:  -173.10562401341505
# finished epoch num:  1
# last direction:  backward
# log-likelihood:  -173.06070186960537
# finished epoch num:  2
# last direction:  forward
# log-likelihood:  -173.0554176188402
# finished epoch num:  3
# last direction:  backward
# log-likelihood:  -172.98410314452104
# finished epoch num:  4
# last direction:  forward
# log-likelihood:  -172.96528141354406
# finished epoch num:  5
# last direction:  backward
# log-likelihood:  -173.111128151804
# finished epoch num:  6
# last direction:  forward
# log-likelihood:  -173.0981508281588
# finished epoch num:  7
# last direction:  backward
# log-likelihood:  -172.94529580903472
# finished epoch num:  8
# last direction:  forward
# log-likelihood:  -173.04590616001653
# finished epoch num:  9
# last direction:  backward
# log-likelihood:  -173.18888882712452
# finished epoch num:  10
# last direction:  forward
# log-likelihood:  -172.98665626127604
# finished epoch num:  11
# last direction:  backward
# log-likelihood:  -173.0432797813664
# finished epoch num:  12
# last direction:  forward
# log-likelihood:  -172.987628261382
# finished epoch num:  13
# last direction:  backward
# log-likelihood:  -172.93074742514855
# finished epoch num:  14
# last direction:  forward
# log-likelihood:  -172.92048565607072
# finished epoch num:  15
# last direction:  backward
# log-likelihood:  -172.92584314608916
# finished epoch num:  16
# last direction:  forward
# log-likelihood:  -172.9959140154759
# finished epoch num:  17
# last direction:  backward
# log-likelihood:  -173.07309923810075
# finished epoch num:  18
# last direction:  forward
# log-likelihood:  -172.98759251029608
# finished epoch num:  19
# last direction:  backward
# log-likelihood:  -172.97128248982975
# finished epoch num:  20
# last direction:  forward
# log-likelihood:  -173.02230470913224
# finished epoch num:  21
# last direction:  backward
# log-likelihood:  -172.97029055500522
# finished epoch num:  22
# last direction:  forward
# log-likelihood:  -173.02218424629652
# finished epoch num:  23
# last direction:  backward
# log-likelihood:  -173.0222589479571
# finished epoch num:  24
# last direction:  forward
# log-likelihood:  -172.8666586056995
# finished epoch num:  25
# last direction:  backward
# log-likelihood:  -172.9647729948303
# finished epoch num:  26
# last direction:  forward
# log-likelihood:  -173.0686198526479
# finished epoch num:  27
# last direction:  backward
# log-likelihood:  -172.87920993809718
# finished epoch num:  28
# last direction:  forward
# log-likelihood:  -172.83984811444176
# finished epoch num:  29
# last direction:  backward
# log-likelihood:  -172.91339686854727
# finished epoch num:  30
# last direction:  forward
# log-likelihood:  -172.95598171511378
# finished epoch num:  31
# last direction:  backward
# log-likelihood:  -172.9661863221912
# finished epoch num:  32
# last direction:  forward
# log-likelihood:  -172.81584677211697
# finished epoch num:  33
# last direction:  backward
# log-likelihood:  -172.8087621521224
# finished epoch num:  34
# last direction:  forward
# log-likelihood:  -172.83863159076142
# finished epoch num:  35
# last direction:  backward
# log-likelihood:  -172.80394410711116
# finished epoch num:  36
# last direction:  forward
# log-likelihood:  -172.79255296708098
# finished epoch num:  37
# last direction:  backward
# log-likelihood:  -172.79812824155127
# finished epoch num:  38
# last direction:  forward
# log-likelihood:  -172.8663140499575
# finished epoch num:  39
# last direction:  backward
# log-likelihood:  -172.78192150668826
# finished epoch num:  40
# last direction:  forward
# log-likelihood:  -172.7984858441236
# finished epoch num:  41
# last direction:  backward
# log-likelihood:  -172.8348827837389
# finished epoch num:  42
# last direction:  forward
# log-likelihood:  -172.73542752324892
# finished epoch num:  43
# last direction:  backward
# log-likelihood:  -172.88652851293554
# finished epoch num:  44
# last direction:  forward
# log-likelihood:  -172.94279601141
# finished epoch num:  45
# last direction:  backward
# log-likelihood:  -172.76532281173516
# finished epoch num:  46
# last direction:  forward
# log-likelihood:  -172.73130459930124
# finished epoch num:  47
# last direction:  backward
# log-likelihood:  -172.83812797951592
# finished epoch num:  48
# last direction:  forward
# log-likelihood:  -172.7161740003958
# finished epoch num:  49
# last direction:  backward
# log-likelihood:  -172.71668246547222
# finished epoch num:  50
# last direction:  forward
# log-likelihood:  -172.7585287146294
# finished epoch num:  51
# last direction:  backward
# log-likelihood:  -172.88683855286354
# finished epoch num:  52
# last direction:  forward
# log-likelihood:  -172.93911545621813
# finished epoch num:  53
# last direction:  backward
# log-likelihood:  -172.9289092886964
# finished epoch num:  54
# last direction:  forward
# log-likelihood:  -172.82308532078372
# finished epoch num:  55
# last direction:  backward
# log-likelihood:  -172.72177844162871
# finished epoch num:  56
# last direction:  forward
# log-likelihood:  -172.82235151114992
# finished epoch num:  57
# last direction:  backward
# log-likelihood:  -172.71447887426575
# finished epoch num:  58
# last direction:  forward
# log-likelihood:  -172.83664738005547
# finished epoch num:  59
# last direction:  backward
# log-likelihood:  -172.7159325946325
# finished epoch num:  60
# last direction:  forward
# log-likelihood:  -172.75461267108594
# finished epoch num:  61
# last direction:  backward
# log-likelihood:  -172.7493982265277
# finished epoch num:  62
# last direction:  forward
# log-likelihood:  -172.81569099549367
# finished epoch num:  63
# last direction:  backward
# log-likelihood:  -172.69576206115065
# finished epoch num:  64
# last direction:  forward
# log-likelihood:  -172.74784568137628
# finished epoch num:  65
# last direction:  backward
# log-likelihood:  -172.6951216412367
# finished epoch num:  66
# last direction:  forward
# log-likelihood:  -172.6948083240332
# finished epoch num:  67
# last direction:  backward
# log-likelihood:  -172.62434398166386
# finished epoch num:  68
# last direction:  forward
# log-likelihood:  -172.80182939060379
# finished epoch num:  69
# last direction:  backward
# log-likelihood:  -172.60404414511274
# finished epoch num:  70
# last direction:  forward
# log-likelihood:  -172.73742865858765
# finished epoch num:  71
# last direction:  backward
# log-likelihood:  -172.69075081030562
# finished epoch num:  72
# last direction:  forward
# log-likelihood:  -172.60650552276178
# finished epoch num:  73
# last direction:  backward
# log-likelihood:  -172.68968423230234
# finished epoch num:  74
# last direction:  forward
# log-likelihood:  -172.6691564238483
# finished epoch num:  75
# last direction:  backward
# log-likelihood:  -172.7422612624431
# finished epoch num:  76
# last direction:  forward
# log-likelihood:  -172.6633865241532
# finished epoch num:  77
# last direction:  backward
# log-likelihood:  -172.58662904488347
# finished epoch num:  78
# last direction:  forward
# log-likelihood:  -172.5770194323582
# finished epoch num:  79
# last direction:  backward
# log-likelihood:  -172.69122645596875
# finished epoch num:  80
# last direction:  forward
# log-likelihood:  -172.66924814258843
# finished epoch num:  81
# last direction:  backward
# log-likelihood:  -172.57200946458346
# finished epoch num:  82
# last direction:  forward
# log-likelihood:  -172.55429575421655
# finished epoch num:  83
# last direction:  backward
# log-likelihood:  -172.73446692688452
# finished epoch num:  84
# last direction:  forward
# log-likelihood:  -172.54203298244317
# finished epoch num:  85
# last direction:  backward
# log-likelihood:  -172.55115800318316
# finished epoch num:  86
# last direction:  forward
# log-likelihood:  -172.56671043182715
# finished epoch num:  87
# last direction:  backward
# log-likelihood:  -172.59399102464502
# finished epoch num:  88
# last direction:  forward
# log-likelihood:  -172.58910789752784
# finished epoch num:  89
# last direction:  backward
# log-likelihood:  -172.52343899981878
# finished epoch num:  90
# last direction:  forward
# log-likelihood:  -172.50590371004904
# finished epoch num:  91
# last direction:  backward
# log-likelihood:  -172.58764954679594
# finished epoch num:  92
# last direction:  forward
# log-likelihood:  -172.66917128678617
# finished epoch num:  93
# last direction:  backward
# log-likelihood:  -172.51254942854413
# finished epoch num:  94
# last direction:  forward
# log-likelihood:  -172.4952376077668
# finished epoch num:  95
# last direction:  backward
# log-likelihood:  -172.66783577511572
# finished epoch num:  96
# last direction:  forward
# log-likelihood:  -172.73319252111511
# finished epoch num:  97
# last direction:  backward
# log-likelihood:  -172.58087490640185
# finished epoch num:  98
# last direction:  forward
# log-likelihood:  -172.56935743200754
# finished epoch num:  99
# last direction:  backward
# log-likelihood:  -172.49617134814818
# finished epoch num:  100
# last direction:  forward
# log-likelihood:  -172.6657826888874
# finished epoch num:  101
# last direction:  backward
# log-likelihood:  -172.43364418843998
# finished epoch num:  102
# last direction:  forward
# log-likelihood:  -172.53666654544284
# finished epoch num:  103
# last direction:  backward
# log-likelihood:  -172.49363186501517
# finished epoch num:  104
# last direction:  forward
# log-likelihood:  -172.53527025610757
# finished epoch num:  105
# last direction:  backward
# log-likelihood:  -172.47990277592965
# finished epoch num:  106
# last direction:  forward
# log-likelihood:  -172.54704277662339
# finished epoch num:  107
# last direction:  backward
# log-likelihood:  -172.48605427890405
# finished epoch num:  108
# last direction:  forward
# log-likelihood:  -172.55722656477212
# finished epoch num:  109
# last direction:  backward
# log-likelihood:  -172.4960616081689
# finished epoch num:  110
# last direction:  forward
# log-likelihood:  -172.55933604782763
# finished epoch num:  111
# last direction:  backward
# log-likelihood:  -172.39885929985104
# finished epoch num:  112
# last direction:  forward
# log-likelihood:  -172.39634441370458
# finished epoch num:  113
# last direction:  backward
# log-likelihood:  -172.45693124132129
# finished epoch num:  114
# last direction:  forward
# log-likelihood:  -172.4862898380352
# finished epoch num:  115
# last direction:  backward
# log-likelihood:  -172.52278591473268
# finished epoch num:  116
# last direction:  forward
# log-likelihood:  -172.40607588309385
# finished epoch num:  117
# last direction:  backward
# log-likelihood:  -172.3680678386956
# finished epoch num:  118
# last direction:  forward
# log-likelihood:  -172.55570941278447
# finished epoch num:  119
# last direction:  backward
# log-likelihood:  -172.44850498139525
# finished epoch num:  120
# last direction:  forward
# log-likelihood:  -172.3513567662237
# finished epoch num:  121
# last direction:  backward
# log-likelihood:  -172.50893052635524
# finished epoch num:  122
# last direction:  forward
# log-likelihood:  -172.53756065631518
# finished epoch num:  123
# last direction:  backward
# log-likelihood:  -172.33708591891724
# finished epoch num:  124
# last direction:  forward
# log-likelihood:  -172.43291121162923
# finished epoch num:  125
# last direction:  backward
# log-likelihood:  -172.33461986780443
# finished epoch num:  126
# last direction:  forward
# log-likelihood:  -172.3485481520322
# finished epoch num:  127
# last direction:  backward
# log-likelihood:  -172.5074828312951
# finished epoch num:  128
# last direction:  forward
# log-likelihood:  -172.42963560788397
# finished epoch num:  129
# last direction:  backward
# log-likelihood:  -172.3176435220997
# finished epoch num:  130
# last direction:  forward
# log-likelihood:  -172.3360505745366
# finished epoch num:  131
# last direction:  backward
# log-likelihood:  -172.36476963349395
# finished epoch num:  132
# last direction:  forward
# log-likelihood:  -172.32947825298595
# finished epoch num:  133
# last direction:  backward
# log-likelihood:  -172.336235232403
# finished epoch num:  134
# last direction:  forward
# log-likelihood:  -172.30993405156195
# finished epoch num:  135
# last direction:  backward
# log-likelihood:  -172.42792491103174
# finished epoch num:  136
# last direction:  forward
# log-likelihood:  -172.32957681527128
# finished epoch num:  137
# last direction:  backward
# log-likelihood:  -172.42306415267382
# finished epoch num:  138
# last direction:  forward
# log-likelihood:  -172.30334337059958
# finished epoch num:  139
# last direction:  backward
# log-likelihood:  -172.33376059359887
# finished epoch num:  140
# last direction:  forward
# log-likelihood:  -172.29110776311953
# finished epoch num:  141
# last direction:  backward
# log-likelihood:  -172.28516229686986
# finished epoch num:  142
# last direction:  forward
# log-likelihood:  -172.35237720821218
# finished epoch num:  143
# last direction:  backward
# log-likelihood:  -172.31906597859657
# finished epoch num:  144
# last direction:  forward
# log-likelihood:  -172.26732556751614
# finished epoch num:  145
# last direction:  backward
# log-likelihood:  -172.37672360670754
# finished epoch num:  146
# last direction:  forward
# log-likelihood:  -172.28890441021875
# finished epoch num:  147
# last direction:  backward
# log-likelihood:  -172.3079566962784
# finished epoch num:  148
# last direction:  forward
# log-likelihood:  -172.27964253862615
# finished epoch num:  149
# last direction:  backward
# log-likelihood:  -172.33003584244256
# finished epoch num:  150
# last direction:  forward
# log-likelihood:  -172.24410122427892
# finished epoch num:  151
# last direction:  backward
# log-likelihood:  -172.2425117352075
# finished epoch num:  152
# last direction:  forward
# log-likelihood:  -172.28068335219692
# finished epoch num:  153
# last direction:  backward
# log-likelihood:  -172.23259729554195
# finished epoch num:  154
# last direction:  forward
# log-likelihood:  -172.2355630713395
# finished epoch num:  155
# last direction:  backward
# log-likelihood:  -172.27315276767848
# finished epoch num:  156
# last direction:  forward
# log-likelihood:  -172.272511883889
# finished epoch num:  157
# last direction:  backward
# log-likelihood:  -172.2383688679816
# finished epoch num:  158
# last direction:  forward
# log-likelihood:  -172.21717964871664
# finished epoch num:  159
# last direction:  backward
# log-likelihood:  -172.26713093978086
# finished epoch num:  160
# last direction:  forward
# log-likelihood:  -172.2344530678534
# finished epoch num:  161
# last direction:  backward
# log-likelihood:  -172.22887046802185
# finished epoch num:  162
# last direction:  forward
# log-likelihood:  -172.31627777927602
# finished epoch num:  163
# last direction:  backward
# log-likelihood:  -172.22295524395705
# finished epoch num:  164
# last direction:  forward
# log-likelihood:  -172.31830429285907
# finished epoch num:  165
# last direction:  backward
# log-likelihood:  -172.22415250004963
# finished epoch num:  166
# last direction:  forward
# log-likelihood:  -172.22402936179884
# finished epoch num:  167
# last direction:  backward
# log-likelihood:  -172.1694742053807
# finished epoch num:  168
# last direction:  forward
# log-likelihood:  -172.15165332382745
# finished epoch num:  169
# last direction:  backward
# log-likelihood:  -172.1505380814743
# finished epoch num:  170
# last direction:  forward
# log-likelihood:  -172.2359571102441
# finished epoch num:  171
# last direction:  backward
# log-likelihood:  -172.27853406782523
# finished epoch num:  172
# last direction:  forward
# log-likelihood:  -172.25050608447398
# finished epoch num:  173
# last direction:  backward
# log-likelihood:  -172.1745327724536
# finished epoch num:  174
# last direction:  forward
# log-likelihood:  -172.14573488597236
# finished epoch num:  175
# last direction:  backward
# log-likelihood:  -172.27832999041965
# finished epoch num:  176
# last direction:  forward
# log-likelihood:  -172.1710491805185
# finished epoch num:  177
# last direction:  backward
# log-likelihood:  -172.14609423621187
# finished epoch num:  178
# last direction:  forward
# log-likelihood:  -172.12704518565135
# finished epoch num:  179
# last direction:  backward
# log-likelihood:  -172.1279614833963
# finished epoch num:  180
# last direction:  forward
# log-likelihood:  -172.22775259300764
# finished epoch num:  181
# last direction:  backward
# log-likelihood:  -172.17482379082887
# finished epoch num:  182
# last direction:  forward
# log-likelihood:  -172.13662152920932
# finished epoch num:  183
# last direction:  backward
# log-likelihood:  -172.21440508156496
# finished epoch num:  184
# last direction:  forward
# log-likelihood:  -172.1512687649518
# finished epoch num:  185
# last direction:  backward
# log-likelihood:  -172.1051227748168
# finished epoch num:  186
# last direction:  forward
# log-likelihood:  -172.13517853611555
# finished epoch num:  187
# last direction:  backward
# log-likelihood:  -172.2759056160019
# finished epoch num:  188
# last direction:  forward
# log-likelihood:  -172.19655922284198
# finished epoch num:  189
# last direction:  backward
# log-likelihood:  -172.21324462758787
# finished epoch num:  190
# last direction:  forward
# log-likelihood:  -172.27509663677017
# finished epoch num:  191
# last direction:  backward
# log-likelihood:  -172.2760719850373
# finished epoch num:  192
# last direction:  forward
# log-likelihood:  -172.1034046888663
# finished epoch num:  193
# last direction:  backward
# log-likelihood:  -172.09071825557774
# finished epoch num:  194
# last direction:  forward
# log-likelihood:  -172.21750667279522
# finished epoch num:  195
# last direction:  backward
# log-likelihood:  -172.1891752087216
# finished epoch num:  196
# last direction:  forward
# log-likelihood:  -172.07982630839751
# finished epoch num:  197
# last direction:  backward
# log-likelihood:  -172.07726981046557
# finished epoch num:  198
# last direction:  forward
# log-likelihood:  -172.0856547565418
# finished epoch num:  199
# last direction:  backward
# log-likelihood:  -172.06479279388415
# finished epoch num:  200
# last direction:  forward
# log-likelihood:  -172.1859363836654
# finished epoch num:  201
# last direction:  backward
# log-likelihood:  -172.13283357825551
# finished epoch num:  202
# last direction:  forward
# log-likelihood:  -172.0608796608448
# finished epoch num:  203
# last direction:  backward
# log-likelihood:  -172.1279725128553
# finished epoch num:  204
# last direction:  forward
# log-likelihood:  -172.04365550051867
# finished epoch num:  205
# last direction:  backward
# log-likelihood:  -172.05498235523584
# finished epoch num:  206
# last direction:  forward
# log-likelihood:  -172.09720981339086
# finished epoch num:  207
# last direction:  backward
# log-likelihood:  -172.09241487379256
# finished epoch num:  208
# last direction:  forward
# log-likelihood:  -172.04064813046784
# finished epoch num:  209
# last direction:  backward
# log-likelihood:  -172.132236018894
# finished epoch num:  210
# last direction:  forward
# log-likelihood:  -172.131961659182
# finished epoch num:  211
# last direction:  backward
# log-likelihood:  -172.05296223865426
# finished epoch num:  212
# last direction:  forward
# log-likelihood:  -172.0530497994569
# finished epoch num:  213
# last direction:  backward
# log-likelihood:  -172.12772745897232
# finished epoch num:  214
# last direction:  forward
# log-likelihood:  -172.12856845010205
# finished epoch num:  215
# last direction:  backward
# log-likelihood:  -172.06256553797422
# finished epoch num:  216
# last direction:  forward
# log-likelihood:  -172.0501222839942
# finished epoch num:  217
# last direction:  backward
# log-likelihood:  -172.07970661466987
# finished epoch num:  218
# last direction:  forward
# log-likelihood:  -172.134967490446
# finished epoch num:  219
# last direction:  backward
# log-likelihood:  -172.00923090441157
# finished epoch num:  220
# last direction:  forward
# log-likelihood:  -172.05130563801868
# finished epoch num:  221
# last direction:  backward
# log-likelihood:  -172.13450860993498
# finished epoch num:  222
# last direction:  forward
# log-likelihood:  -171.98042699680778
# finished epoch num:  223
# last direction:  backward
# log-likelihood:  -172.12979022012541
# finished epoch num:  224
# last direction:  forward
# log-likelihood:  -171.98058616990565
# finished epoch num:  225
# last direction:  backward
# log-likelihood:  -172.08140324739747
# finished epoch num:  226
# last direction:  forward
# log-likelihood:  -172.12962763225664
# finished epoch num:  227
# last direction:  backward
# log-likelihood:  -172.03459290130402
# finished epoch num:  228
# last direction:  forward
# log-likelihood:  -172.05491708687197
# finished epoch num:  229
# last direction:  backward
# log-likelihood:  -171.97106615582814
# finished epoch num:  230
# last direction:  forward
# log-likelihood:  -172.0780373422938
# finished epoch num:  231
# last direction:  backward
# log-likelihood:  -171.98859074329064
# finished epoch num:  232
# last direction:  forward
# log-likelihood:  -171.9857965232637
# finished epoch num:  233
# last direction:  backward
# log-likelihood:  -171.97336152789615
# finished epoch num:  234
# last direction:  forward
# log-likelihood:  -171.99341670104923
# finished epoch num:  235
# last direction:  backward
# log-likelihood:  -171.9479340736952
# finished epoch num:  236
# last direction:  forward
# log-likelihood:  -172.00487979811493
# finished epoch num:  237
# last direction:  backward
# log-likelihood:  -171.9727599592382
# finished epoch num:  238
# last direction:  forward
# log-likelihood:  -172.04889055522045
# finished epoch num:  239
# last direction:  backward
# log-likelihood:  -171.99434982340637
# finished epoch num:  240
# last direction:  forward
# log-likelihood:  -171.97131636326517
# finished epoch num:  241
# last direction:  backward
# log-likelihood:  -171.93265719801798
# finished epoch num:  242
# last direction:  forward
# log-likelihood:  -171.9390690113752
# finished epoch num:  243
# last direction:  backward
# log-likelihood:  -171.96531421404745
# finished epoch num:  244
# last direction:  forward
# log-likelihood:  -172.04726189981307
# finished epoch num:  245
# last direction:  backward
# log-likelihood:  -171.930984609412
# finished epoch num:  246
# last direction:  forward
# log-likelihood:  -171.92703459780753
# finished epoch num:  247
# last direction:  backward
# log-likelihood:  -171.91766048155
# finished epoch num:  248
# last direction:  forward
# log-likelihood:  -172.04613523059732
# finished epoch num:  249
# last direction:  backward
# log-likelihood:  -171.96920421229086

# %%
def plot_results(optim,iters=None):
    
    if iters is None:
        iters=len(optim.theta_trace)
    
    #plt.plot(optim.log_like_trace)
    #plt.title("Log-likelihood v iteration number")
    #plt.show()

    plt.plot([optim.theta_trace[i][0]['Y']['mu'][0] for i in range(iters)])
    plt.plot([optim.theta_trace[i][0]['Y']['mu'][1] for i in range(iters)])
    plt.plot([optim.theta_trace[i][0]['Y']['mu'][2] for i in range(iters)])
    plt.title("Means v iteration number")
    for hline in [-1,0,1]:
        plt.axhline(hline, c = 'k', linestyle = "--")
    #plt.axhline(optim.param_bounds['Y']['mu'][1], c = 'k', linestyle = "--")
    #plt.axhline(optim.param_bounds['Y']['mu'][0], c = 'k', linestyle = "--")
    #plt.axhline(optim.param_bounds['Y']['mu'][1], c = 'k', linestyle = "--")
    plt.show()
    
    #plt.plot([optim.theta_trace[i][0]['Y']['log_sig'][0] for i in range(len(optim.theta_trace))])
    #plt.plot([optim.theta_trace[i][0]['Y']['log_sig'][1] for i in range(len(optim.theta_trace))])
    #plt.plot([optim.theta_trace[i][0]['Y']['log_sig'][2] for i in range(len(optim.theta_trace))])
    #plt.axhline(optim.param_bounds['Y']['log_sig'][0], c = 'k', linestyle = "--")
    #plt.axhline(optim.param_bounds['Y']['log_sig'][1], c = 'k', linestyle = "--")
    #plt.title("Standard Deviations v iteration number")
    #plt.show()
    
    #plt.plot([optim.eta_trace[i][0][0,1] for i in range(len(optim.eta_trace))])
    #plt.plot([optim.eta_trace[i][0][0,2] for i in range(len(optim.eta_trace))])
    #plt.plot([optim.eta_trace[i][0][1,0] for i in range(len(optim.eta_trace))])
    #plt.plot([optim.eta_trace[i][0][1,2] for i in range(len(optim.eta_trace))])
    #plt.plot([optim.eta_trace[i][0][2,0] for i in range(len(optim.eta_trace))])
    #plt.plot([optim.eta_trace[i][0][2,1] for i in range(len(optim.eta_trace))])
    #plt.title("Eta v iteration number")
    #plt.show()

    plt.plot([optim.grad_theta_trace[i][0]['Y']['mu'][0] for i in range(iters)])#range(len(optim.theta_trace))])
    plt.plot([optim.grad_theta_trace[i][0]['Y']['mu'][1] for i in range(iters)])#range(len(optim.theta_trace))])
    plt.plot([optim.grad_theta_trace[i][0]['Y']['mu'][2] for i in range(iters)])#range(len(optim.theta_trace))])
    plt.title("Gradients of Means v iteration number")
    plt.show()
    
    #plt.plot([optim.grad_theta_trace[i][0]['Y']['log_sig'][0] for i in range(len(optim.theta_trace))])
    #plt.plot([optim.grad_theta_trace[i][0]['Y']['log_sig'][1] for i in range(len(optim.theta_trace))])
    #plt.plot([optim.grad_theta_trace[i][0]['Y']['log_sig'][2] for i in range(len(optim.theta_trace))])
    #plt.title("Gradients of Standard Deviations v iteration number")
    #plt.show()
    
plot_results(optim1)
plot_results(optim2)#,iters=1000)

# %% [markdown]
# # Make sure that the likelihoods agree

# %%
# using hhmm
print(hhmm.likelihood(data))
print("")
# do a forward pass and backwards pass
optim1.fwd_pass()
optim1.bwd_pass()

# print likelihood of evaluated at each time point
lls = [optim1.log_likelihood(t) for t in range(optim1.T)]
plt.plot(lls,"r--")
plt.axhline(hhmm.likelihood(data))
plt.legend(["Optimizor log-likelihood","HHMM log-likelihood"])
plt.xlabel("Time index (Optimizor only)")
plt.ylabel("Log Likelihood")
plt.show()
# Out:
# -200.83224308915388

# %% [markdown]
# # Test that the gradients wrt $\theta$ agree

# %%
# test gradient of mu_Y for state 0 using my hand-code (this is mu2)
optim.fwd_pass(data)
optim.bwd_pass(data)

autograds = np.zeros(optim.T)
finite_diffs = np.zeros(optim.T)

for t in range(optim.T):

    optim.grad_log_likelihood(t)
    autograds[t] = optim.d_log_like_d_theta[t][0]["Y"]["mu"][2]

    # test finte differences - optim
    eps = 0.0001
    
    # record current likelihood
    y1 = np.copy(optim.log_likelihood(t))
    
    # adjust parameters and record result
    optim.theta[0]['Y']['mu'][2] += eps
    optim.fwd_pass(data)
    optim.bwd_pass(data)
    y2 = np.copy(optim.log_likelihood(t))

    # record the finite difference
    finite_diffs[t] = (y2-y1)/eps

    # change the parameters back
    optim.theta[0]['Y']['mu'][2] += -eps
    optim.fwd_pass(data)
    optim.bwd_pass(data)
    
plt.plot(autograds)
plt.plot(finite_diffs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-848acf4b9294> in <module>
#       1 # test gradient of mu_Y for state 0 using my hand-code (this is mu2)
# ----> 2 optim.fwd_pass(data)
#       3 optim.bwd_pass(data)
#       4
#       5 autograds = np.zeros(optim.T)
#
# NameError: name 'optim' is not defined

# %% [markdown]
# # Test that the gradients wrt $\eta$ agree

# %%
# test gradient of mu_Y for state 0 using my hand-code (this is mu2)
optim.fwd_pass(data)
optim.bwd_pass(data)

autograds = np.zeros(optim.T)
finite_diffs = np.zeros(optim.T)

for t in range(optim.T):

    optim.grad_log_likelihood(t)
    autograds[t] = optim.d_log_like_d_eta[t][0,1]

    # test finte differences - optim
    eps = 0.0001
    
    # record current likelihood
    y1 = np.copy(optim.log_likelihood(t))
    
    # adjust parameters and record result
    optim.eta[0][0,1] += eps
    optim.Gamma = eta_2_Gamma(optim.eta)
    optim.fwd_pass(data)
    optim.bwd_pass(data)
    y2 = np.copy(optim.log_likelihood(t))

    # record the finite difference
    finite_diffs[t] = (y2-y1)/eps

    # change the parameters back
    optim.eta[0][0,1] += -eps
    optim.Gamma = eta_2_Gamma(optim.eta)
    optim.fwd_pass(data)
    optim.bwd_pass(data)
    
print(autograds)
print(finite_diffs)
plt.plot(autograds)
plt.plot(finite_diffs)

# %%
np.clip(np.array([-1,0,1]),-0.5,0.5)
