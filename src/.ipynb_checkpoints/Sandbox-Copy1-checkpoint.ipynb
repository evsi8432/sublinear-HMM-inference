# %%
import sys
#sys.path.remove('/Users/evsi8432/Documents/Research/CarHHMM-DFT/Repository/Code')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm

from scipy.stats import gamma
from scipy.stats import norm
from scipy.stats import vonmises
from scipy.stats import multivariate_normal
from scipy.stats import gaussian_kde
from scipy.stats import circstd
from scipy.special import iv
from scipy.special import expit
from scipy.special import logit
from scipy.special import logsumexp
from scipy.optimize import minimize
from scipy.optimize import minimize_scalar
from scipy.optimize import LinearConstraint
from scipy.signal import convolve
from scipy.interpolate import interp1d

from math import isclose

from copy import deepcopy

import importlib

import time
import pickle
import random

# %%
import Preprocessor
import Parameters
import HHMM
import Visualisor
import optimizor

from optimizor import eta_2_Gamma
from optimizor import Gamma_2_eta
from optimizor import logdotexp

np.random.seed(0)
random.seed(0)

# %% [markdown]
# # Initialize Parameters

# %%
# parameters for data
pars = Parameters.Parameters()
pars.features = [{'Y':{'corr':False,'f':'normal'}}, # coarse-scale
                 {}]
pars.K = [3,1]
T = 10000
experiment = 1


if experiment == 1:
    
    Gamma = np.array([[0.9,0.05,0.05],
                      [0.05,0.9,0.05],
                      [0.05,0.05,0.9]])
    delta = np.ones(pars.K[0])/pars.K[0]
    mus = np.array(range(pars.K[0])).astype("float64")
    sigs = np.exp(np.array([-1.0,1.0,0.0]))
    
elif experiment == 2:
    
    Gamma = np.array([[0.99,0.005,0.005],
                      [0.005,0.99,0.005],
                      [0.005,0.005,0.99]])
    delta = np.ones(pars.K[0])/pars.K[0]
    mus = np.array(range(pars.K[0])).astype("float64")
    sigs = np.exp(np.array([-1.0,1.0,0.0]))

    
# optimization parameters 
methods = ["SAGA","EM","BFGS","Nelder-Mead"]
# methods = ["EM","SGD","SAG","SVRG","SAGA","GD","BFGS","Nelder-Mead"]

# pick optimization settings
step_sizes = {"EM"  : [None,None],
              "Nelder-Mead": [None,None],
              "BFGS": [None,None],
              "SGD" : [0.01,0.01],
              "SAG" : [0.01,0.01],
              "SVRG": [0.01,0.01],
              "SAGA": [0.01,0.01]}

num_epochs = 50
tol = 1e-10
grad_tol = 1e-8

# %% [markdown]
# # Simulate Data

# %%
X = np.zeros(T,dtype=int)
data = []

for t in range(T):
    
    if t == 0:
        X[t] = np.random.choice(pars.K[0],p=delta)
    else:
        X[t] = np.random.choice(pars.K[0],p=Gamma[X[t-1]])

    data.append({'Y':mus[X[t]] + sigs[X[t]]*np.random.normal(),
                 'subdive_features':[]})

# %%
plt.plot(X)
plt.show()
plt.plot([x["Y"] for x in data],'.')
plt.show()

# %% [markdown]
# # Train the HMM

# %%
importlib.reload(optimizor)

# intialize HHMM
hhmm = HHMM.HHMM(pars,data)

hhmm.theta = [{'Y': {'mu': np.array([-1.0,  1.1,  2.1]),
                     'log_sig': np.array([0.0, 0.0, 0.0]),
                     'corr': np.zeros(pars.K[0])}},
               [{}, {}, {}]]

hhmm.Gamma = [Gamma,
             [np.array([[1.]]), np.array([[1.]]), np.array([[1.]])]]

hhmm.eta = Gamma_2_eta(hhmm.Gamma)

# initialize optims
optims = {}
times = {}

# get optimal value via EM:
optims["control"] = optimizor.optimizor(hhmm)
optims["control"].step_size = [None,None]
optims["control"].param_bounds["Y"]["mu"] = [-100,100]
optims["control"].param_bounds["Y"]["log_sig"] = [-5,5]

optims["control"].train_HHMM(num_epochs=num_epochs,
                                      method="EM",
                                      tol=1e-15)
optim_ll = optims["control"].log_like_trace[-1]
    
for method in methods:
    
    for partial_E in [0,0.5,1]:
        
        if partial_E > 0 and method in ["EM","BFGS","Nelder-Mead"]:
            continue
        
        print(method,partial_E)
        print("")

        optims[(method,partial_E)] = optimizor.optimizor(hhmm)
        optims[(method,partial_E)].step_size = step_sizes[method]
        optims[(method,partial_E)].param_bounds["Y"]["mu"] = [-100,100]
        optims[(method,partial_E)].param_bounds["Y"]["log_sig"] = [-5,5]
        
        if partial_E == 0:
            optims[(method,partial_E)].train_HHMM(num_epochs=num_epochs,
                                                  method=method,
                                                  max_iters=T,
                                                  partial_E=False,
                                                  alpha_theta=step_sizes[method][0],
                                                  alpha_eta=step_sizes[method][1],
                                                  tol=tol,
                                                  grad_tol=grad_tol,
                                                  record_like = True)
        elif partial_E == 0.5:
            if method in ["SGD","SAG","SVRG","SAGA"]:
                optims[(method,partial_E)].train_HHMM(num_epochs=num_epochs,
                                                      method=method,
                                                      max_iters=T,
                                                      partial_E=True,
                                                      alpha_theta=step_sizes[method][0],
                                                      alpha_eta=step_sizes[method][1],
                                                      tol=tol,
                                                      grad_tol=grad_tol,
                                                      record_like = True)
        elif partial_E == 1:
            if method in ["SGD","SAG","SVRG","SAGA"]:
                optims[(method,partial_E)].train_HHMM(num_epochs=num_epochs,
                                                      method=method,
                                                      max_iters=10*T,
                                                      partial_E=True,
                                                      alpha_theta=step_sizes[method][0],
                                                      alpha_eta=step_sizes[method][1],
                                                      tol=tol,
                                                      grad_tol=grad_tol,
                                                      record_like = True)
# Out:
# /Users/evsi8432/Documents/Research/sublinear-HMM-inference/src/optimizor.py:194: RuntimeWarning:
#
# divide by zero encountered in true_divide
#
# /Users/evsi8432/Documents/Research/sublinear-HMM-inference/src/optimizor.py:195: RuntimeWarning:
#
# divide by zero encountered in true_divide
#
# /Users/evsi8432/Documents/Research/sublinear-HMM-inference/src/optimizor.py:209: RuntimeWarning:
#
# divide by zero encountered in double_scalars
# starting epoch 0.0
#
# starting E-step...
# ...done
# -22575.497310531173
# starting M-step...
# ...done
#
# starting epoch 0.5
#
# starting E-step...
# /Users/evsi8432/Documents/Research/sublinear-HMM-inference/src/optimizor.py:916: RuntimeWarning:
#
# invalid value encountered in double_scalars
# ...done
# -20012.18614952764
# starting M-step...
# ...done
#
# starting epoch 1.0
#
# starting E-step...
# ...done
# -19561.540907585124
# starting M-step...
# ...done
#
# starting epoch 1.5
#
# starting E-step...
# ...done
# -18896.82617161652
# starting M-step...
# ...done
#
# starting epoch 2.0
#
# starting E-step...
# ...done
# -18154.590053196942
# starting M-step...
# ...done
#
# starting epoch 2.5
#
# starting E-step...
# ...done
# -17576.211356147905
# starting M-step...
# ...done
#
# starting epoch 3.0
#
# starting E-step...
# ...done
# -17324.32480193185
# starting M-step...
# ...done
#
# starting epoch 3.5
#
# starting E-step...
# ...done
# -17169.59153151109
# starting M-step...
# ...done
#
# starting epoch 4.0
#
# starting E-step...
# ...done
# -17048.637826702434
# starting M-step...
# ...done
#
# starting epoch 4.5
#
# starting E-step...
# ...done
# -16963.411034970482
# starting M-step...
# ...done
#
# starting epoch 5.0
#
# starting E-step...
# ...done
# -16908.515116478495
# starting M-step...
# ...done
#
# starting epoch 5.5
#
# starting E-step...
# ...done
# -16876.312282014787
# starting M-step...
# ...done
#
# starting epoch 6.0
#
# starting E-step...
# ...done
# -16858.682977594868
# starting M-step...
# ...done
#
# starting epoch 6.5
#
# starting E-step...
# ...done
# -16849.41818414418
# starting M-step...
# ...done
#
# starting epoch 7.0
#
# starting E-step...
# ...done
# -16844.6596473726
# starting M-step...
# ...done
#
# starting epoch 7.5
#
# starting E-step...
# ...done
# -16842.251104247513
# starting M-step...
# ...done
#
# starting epoch 8.0
#
# starting E-step...
# ...done
# -16841.046013965133
# starting M-step...
# ...done
#
# starting epoch 8.5
#
# starting E-step...
# ...done
# -16840.449203184588
# starting M-step...
# ...done
#
# starting epoch 9.0
#
# starting E-step...
# ...done
# -16840.156315014712
# starting M-step...
# ...done
#
# starting epoch 9.5
#
# starting E-step...
# ...done
# -16840.0136868957
# starting M-step...
# ...done
#
# starting epoch 10.0
#
# starting E-step...
# ...done
# -16839.94466566587
# starting M-step...
# ...done
#
# starting epoch 10.5
#
# starting E-step...
# ...done
# -16839.91142745925
# starting M-step...
# ...done
#
# starting epoch 11.0
#
# starting E-step...
# ...done
# -16839.895480044448
# starting M-step...
# ...done
#
# starting epoch 11.5
#
# starting E-step...
# ...done
# -16839.887849390543
# starting M-step...
# ...done
#
# starting epoch 12.0
#
# starting E-step...
# ...done
# -16839.884205396753
# starting M-step...
# ...done
#
# starting epoch 12.5
#
# starting E-step...
# ...done
# -16839.882467668132
# starting M-step...
# ...done
#
# starting epoch 13.0
#
# starting E-step...
# ...done
# -16839.88163981445
# starting M-step...
# ...done
#
# starting epoch 13.5
#
# starting E-step...
# ...done
# -16839.88124570043
# starting M-step...
# ...done
#
# starting epoch 14.0
#
# starting E-step...
# ...done
# -16839.881058167502
# starting M-step...
# ...done
#
# starting epoch 14.5
#
# starting E-step...
# ...done
# -16839.880968962727
# starting M-step...
# ...done
#
# starting epoch 15.0
#
# starting E-step...
# ...done
# -16839.88092654069
# starting M-step...
# ...done
#
# starting epoch 15.5
#
# starting E-step...
# ...done
# -16839.880906369013
# starting M-step...
# ...done
#
# starting epoch 16.0
#
# starting E-step...
# ...done
# -16839.880896778945
# starting M-step...
# ...done
#
# starting epoch 16.5
#
# starting E-step...
# ...done
# -16839.880892219702
# starting M-step...
# ...done
#
# starting epoch 17.0
#
# starting E-step...
# ...done
# -16839.880890052533
# starting M-step...
# ...done
#
# starting epoch 17.5
#
# starting E-step...
# ...done
# -16839.8808890226
# starting M-step...
# ...done
#
# starting epoch 18.0
#
# starting E-step...
# ...done
# -16839.880888532763
# starting M-step...
# ...done
#
# starting epoch 18.5
#
# starting E-step...
# ...done
# -16839.88088829985
# starting M-step...
# ...done
#
# starting epoch 19.0
#
# starting E-step...
# ...done
# -16839.88088818917
# starting M-step...
# ...done
#
# starting epoch 19.5
#
# starting E-step...
# ...done
# -16839.88088813659
# starting M-step...
# ...done
#
# starting epoch 20.0
#
# starting E-step...
# ...done
# -16839.88088811178
# starting M-step...
# ...done
#
# starting epoch 20.5
#
# starting E-step...
# ...done
# -16839.880888099644
# starting M-step...
# ...done
#
# starting epoch 21.0
#
# starting E-step...
# ...done
# -16839.88088809425
# starting M-step...
# ...done
#
# starting epoch 21.5
#
# starting E-step...
# ...done
# -16839.880888091302
# starting M-step...
# ...done
#
# starting epoch 22.0
#
# starting E-step...
# ...done
# -16839.880888090258
# starting M-step...
# ...done
#
# starting epoch 22.5
#
# starting E-step...
# ...done
# -16839.880888089443
# starting M-step...
# ...done
#
# starting epoch 23.0
#
# starting E-step...
# ...done
# -16839.880888089712
# relative change of log likelihood is less than 1.0E-15. returning...
# SAGA 0
#
# starting epoch 0.0
#
# starting E-step...
# ...done
# -22575.497310531173
# starting M-step...
# 0.25471654580595654
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# starting epoch 1.0
#
# starting E-step...
# ...done
# -19960.494803651927
# starting M-step...
# 0.04334768295798136
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# starting epoch 2.0
#
# starting E-step...
# ...done
# -19525.412477106285
# starting M-step...
# 0.06100497843941454
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# starting epoch 3.0
#
# starting E-step...
# ...done
# -18811.50488660802
# starting M-step...
# 0.07399292684304098
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# starting epoch 4.0
#
# starting E-step...
# ...done
# -17907.260160763333
# starting M-step...
# 0.06480455118064699
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# starting epoch 5.0
#
# starting E-step...
# ...done
# -17458.085123778466
# starting M-step...
# 0.03624187669715732
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# starting epoch 6.0
#
# starting E-step...
# ...done
# -17294.39710959628
# starting M-step...
# 0.030433791085317335
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# starting epoch 7.0
#
# starting E-step...
# ...done
# -17155.499400191264
# starting M-step...
# 0.028708357581097722
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# starting epoch 8.0
#
# starting E-step...
# ...done
# -17039.256540104925
# starting M-step...
# 0.02374477828813387
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# starting epoch 9.0
#
# starting E-step...
# ...done
# -16956.475858953734
# starting M-step...
# 0.01792755860053227
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# starting epoch 10.0
#
# starting E-step...
# ...done
# -16903.800377633983
# starting M-step...
# 0.012344559211046947
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# starting epoch 11.0
#
# starting E-step...
# ...done
# -16874.56220850666
# starting M-step...
# 0.008463026887567643
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# starting epoch 12.0
#
# starting E-step...
# ...done
# -16858.499653674153
# starting M-step...
# 0.005340531522662959
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# starting epoch 13.0
#
# starting E-step...
# ...done
# -16849.843161714733
# starting M-step...
# 0.003149114247474009
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# starting epoch 14.0
#
# starting E-step...
# ...done
# -16845.476215419858
# starting M-step...
# 0.0022500226237682783
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# starting epoch 15.0
#
# starting E-step...
# ...done
# -16843.030928785603
# starting M-step...
# 0.0015646485144170067
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# starting epoch 16.0
#
# starting E-step...
# ...done
# -16841.646935675308
# starting M-step...
# 0.0010368400856389406
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# starting epoch 17.0
#
# starting E-step...
# ...done
# -16840.887500603738
# starting M-step...
# 0.0007950632472623878
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# starting epoch 18.0
#
# starting E-step...
# ...done
# -16840.450483869845
# starting M-step...
# 0.0005256670143331166
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# starting epoch 19.0
#
# starting E-step...
# ...done
# -16840.204312350532
# starting M-step...
# 0.0003971000643573534
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# starting epoch 20.0
#
# starting E-step...
# ...done
# -16840.065054972154
# starting M-step...
# 0.0003109269711338541
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# starting epoch 21.0
#
# starting E-step...
# ...done
# -16839.986273221613
# starting M-step...
# 0.0002268165423453213
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# starting epoch 22.0
#
# starting E-step...
# ...done
# -16839.94091225303
# starting M-step...
# 0.00017298801335893825
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# starting epoch 23.0
#
# starting E-step...
# ...done
# -16839.914961434686
# starting M-step...
# 0.00012405654498952862
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# starting epoch 24.0
#
# starting E-step...
# ...done
# -16839.900462648748
# starting M-step...
# 9.672249248406651e-05
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# starting epoch 25.0
#
# starting E-step...
# ...done
# -16839.8920670808
# starting M-step...
# 7.383691122455405e-05
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# starting epoch 26.0
#
# starting E-step...
# ...done
# -16839.887254346253
# starting M-step...
# 5.435181743216924e-05
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# starting epoch 27.0
#
# starting E-step...
# ...done
# -16839.88453234459
# starting M-step...
# 4.195203442198485e-05
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# starting epoch 28.0
#
# starting E-step...
# ...done
# -16839.88296306729
# starting M-step...
# 3.090712855112507e-05
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# starting epoch 29.0
#
# starting E-step...
# ...done
# -16839.88206860044
# starting M-step...
# 2.338256925558449e-05
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# starting epoch 30.0
#
# starting E-step...
# ...done
# -16839.88156399042
# starting M-step...
# 1.7793735587838217e-05
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# starting epoch 31.0
#
# starting E-step...
# ...done
# -16839.881273822488
# starting M-step...
# 1.355767131811923e-05
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# starting epoch 32.0
#
# starting E-step...
# ...done
# -16839.881108226487
# starting M-step...
# 1.0362240456132602e-05
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# starting epoch 33.0
#
# starting E-step...
# ...done
# -16839.881014129704
# starting M-step...
# 7.761722124820455e-06
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# starting epoch 34.0
#
# starting E-step...
# ...done
# -16839.880959881848
# starting M-step...
# 5.768344242292195e-06
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# starting epoch 35.0
#
# starting E-step...
# ...done
# -16839.880928866452
# starting M-step...
# 4.358981687935112e-06
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# starting epoch 36.0
#
# starting E-step...
# ...done
# -16839.880911382654
# starting M-step...
# 3.290096784078924e-06
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# starting epoch 37.0
#
# starting E-step...
# ...done
# -16839.880901401313
# starting M-step...
# 2.458686991171517e-06
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# starting epoch 38.0
#
# starting E-step...
# ...done
# -16839.880895694794
# starting M-step...
# 1.8853829978966407e-06
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# starting epoch 39.0
#
# starting E-step...
# ...done
# -16839.880892439305
# starting M-step...
# 1.4343898574637727e-06
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# starting epoch 40.0
#
# starting E-step...
# ...done
# -16839.880890567114
# starting M-step...
# 1.052637983282884e-06
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# starting epoch 41.0
#
# starting E-step...
# ...done
# -16839.880889507538
# relative change of log likelihood is less than 1.0E-10. returning...
# SAGA 0.5
#
# starting epoch 0.0
#
# starting E-step...
# ...done
# -22575.497310531173
# starting M-step...
# 0.25147428479344114
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# starting epoch 1.5
#
# starting E-step...
# ...done
# -17280.377400861526
# starting M-step...
# 0.1206717483483506
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# starting epoch 3.0
#
# starting E-step...
# ...done
# -16873.511566147772
# starting M-step...
# 0.02711179030040072
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# starting epoch 4.5
#
# starting E-step...
# ...done
# -16846.668600902853
# starting M-step...
# 0.007915285333890536
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# starting epoch 6.0
#
# starting E-step...
# ...done
# -16841.69637241143
# starting M-step...
# 0.0017574386510214796
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# starting epoch 7.5
#
# starting E-step...
# ...done
# -16840.47121010226
# starting M-step...
# 0.0007353488151380006
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# starting epoch 9.0
#
# starting E-step...
# ...done
# -16840.083782032383
# starting M-step...
# 0.0004149901574131269
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# starting epoch 10.5
#
# starting E-step...
# ...done
# -16839.950976140168
# starting M-step...
# 0.00023964995014968182
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# starting epoch 12.0
#
# starting E-step...
# ...done
# -16839.905203097398
# starting M-step...
# 0.00014194377563422
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# starting epoch 13.5
#
# starting E-step...
# ...done
# -16839.889450607003
# starting M-step...
# 8.548254824916227e-05
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# starting epoch 15.0
#
# starting E-step...
# ...done
# -16839.883925099348
# starting M-step...
# 4.979494033372416e-05
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# starting epoch 16.5
#
# starting E-step...
# ...done
# -16839.88194622626
# starting M-step...
# 2.9624347712200012e-05
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# starting epoch 18.0
#
# starting E-step...
# ...done
# -16839.881263530362
# starting M-step...
# 1.72030029133135e-05
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# starting epoch 19.5
#
# starting E-step...
# ...done
# -16839.881019693315
# starting M-step...
# 1.0374024327028987e-05
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# starting epoch 21.0
#
# starting E-step...
# ...done
# -16839.8809350575
# starting M-step...
# 6.315016056429327e-06
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# starting epoch 22.5
#
# starting E-step...
# ...done
# -16839.88090485465
# starting M-step...
# 3.781162260202032e-06
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# starting epoch 24.0
#
# starting E-step...
# ...done
# -16839.880894153554
# starting M-step...
# 2.526120674623089e-06
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# starting epoch 25.5
#
# starting E-step...
# ...done
# -16839.880890210155
# starting M-step...
# 1.3656949045516017e-06
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# starting epoch 27.0
#
# starting E-step...
# ...done
# -16839.880888827418
# relative change of log likelihood is less than 1.0E-10. returning...
# SAGA 1
#
# starting epoch 0.0
#
# starting E-step...
# ...done
# -22575.497310531173
# starting M-step...
# 0.25191588990626185
# 0.09106101050169635
# 0.03332542020223457
# 0.012301743157169457
# 0.0038515237100370968
# 0.002444116959364597
# 0.0015002631916031938
# 0.001263241077491684
# 0.0008838261707278386
# 0.0007325631809248458
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# starting epoch 10.5
#
# starting E-step...
# ...done
# -16840.517350182552
# starting M-step...
# 0.0022733584152945276
# 0.0008567100645799237
# 0.00034172243536666056
# 0.00014766030801100053
# 7.287557166604714e-05
# 4.343353460804248e-05
# 2.6618462563756163e-05
# 2.017645295402851e-05
# 1.4335628587196211e-05
# 1.0280246859702007e-05
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# starting epoch 21.0
#
# starting E-step...
# ...done
# -16839.88171693802
# starting M-step...
# 7.586678644989187e-05
# 2.8947629751541793e-05
# 1.190572205425302e-05
# 5.097181265393737e-06
# 2.469739969874243e-06
# 1.6160432047051504e-06
# 1.0657999095528542e-06
# 6.591617650848964e-07
# 3.764640090839899e-07
# 3.4682448793746044e-07
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# starting epoch 31.5
#
# starting E-step...
# ...done
# -16839.880888673517
# starting M-step...
# 1.5630857535082094e-06
# 6.387675917597397e-07
# 2.8553887256772265e-07
# 1.414843497285442e-07
# 8.15936177956365e-08
# 5.092278153811206e-08
# 3.2354691012704784e-08
# 1.7378019997911285e-08
# 1.2777954295237735e-08
# 1.1269146524118737e-08
# M-step failed to converge: maximum number of iterations reached
# ...done
#
# starting epoch 42.0
#
# starting E-step...
# ...done
# -16839.880888089705
# relative change of log likelihood is less than 1.0E-10. returning...
# EM 0
#
# starting epoch 0.0
#
# starting E-step...
# ...done
# -22575.497310531173
# starting M-step...
# ...done
#
# starting epoch 0.5
#
# starting E-step...
# ...done
# -20012.18614952764
# starting M-step...
# ...done
#
# starting epoch 1.0
#
# starting E-step...
# ...done
# -19561.540907585124
# starting M-step...
# ...done
#
# starting epoch 1.5
#
# starting E-step...
# ...done
# -18896.82617161652
# starting M-step...
# ...done
#
# starting epoch 2.0
#
# starting E-step...
# ...done
# -18154.590053196942
# starting M-step...
# ...done
#
# starting epoch 2.5
#
# starting E-step...
# ...done
# -17576.211356147905
# starting M-step...
# ...done
#
# starting epoch 3.0
#
# starting E-step...
# ...done
# -17324.32480193185
# starting M-step...
# ...done
#
# starting epoch 3.5
#
# starting E-step...
# ...done
# -17169.59153151109
# starting M-step...
# ...done
#
# starting epoch 4.0
#
# starting E-step...
# ...done
# -17048.637826702434
# starting M-step...
# ...done
#
# starting epoch 4.5
#
# starting E-step...
# ...done
# -16963.411034970482
# starting M-step...
# ...done
#
# starting epoch 5.0
#
# starting E-step...
# ...done
# -16908.515116478495
# starting M-step...
# ...done
#
# starting epoch 5.5
#
# starting E-step...
# ...done
# -16876.312282014787
# starting M-step...
# ...done
#
# starting epoch 6.0
#
# starting E-step...
# ...done
# -16858.682977594868
# starting M-step...
# ...done
#
# starting epoch 6.5
#
# starting E-step...
# ...done
# -16849.41818414418
# starting M-step...
# ...done
#
# starting epoch 7.0
#
# starting E-step...
# ...done
# -16844.6596473726
# starting M-step...
# ...done
#
# starting epoch 7.5
#
# starting E-step...
# ...done
# -16842.251104247513
# starting M-step...
# ...done
#
# starting epoch 8.0
#
# starting E-step...
# ...done
# -16841.046013965133
# starting M-step...
# ...done
#
# starting epoch 8.5
#
# starting E-step...
# ...done
# -16840.449203184588
# starting M-step...
# ...done
#
# starting epoch 9.0
#
# starting E-step...
# ...done
# -16840.156315014712
# starting M-step...
# ...done
#
# starting epoch 9.5
#
# starting E-step...
# ...done
# -16840.0136868957
# starting M-step...
# ...done
#
# starting epoch 10.0
#
# starting E-step...
# ...done
# -16839.94466566587
# starting M-step...
# ...done
#
# starting epoch 10.5
#
# starting E-step...
# ...done
# -16839.91142745925
# starting M-step...
# ...done
#
# starting epoch 11.0
#
# starting E-step...
# ...done
# -16839.895480044448
# starting M-step...
# ...done
#
# starting epoch 11.5
#
# starting E-step...
# ...done
# -16839.887849390543
# starting M-step...
# ...done
#
# starting epoch 12.0
#
# starting E-step...
# ...done
# -16839.884205396753
# starting M-step...
# ...done
#
# starting epoch 12.5
#
# starting E-step...
# ...done
# -16839.882467668132
# starting M-step...
# ...done
#
# starting epoch 13.0
#
# starting E-step...
# ...done
# -16839.88163981445
# starting M-step...
# ...done
#
# starting epoch 13.5
#
# starting E-step...
# ...done
# -16839.88124570043
# starting M-step...
# ...done
#
# starting epoch 14.0
#
# starting E-step...
# ...done
# -16839.881058167502
# starting M-step...
# ...done
#
# starting epoch 14.5
#
# starting E-step...
# ...done
# -16839.880968962727
# starting M-step...
# ...done
#
# starting epoch 15.0
#
# starting E-step...
# ...done
# -16839.88092654069
# starting M-step...
# ...done
#
# starting epoch 15.5
#
# starting E-step...
# ...done
# -16839.880906369013
# starting M-step...
# ...done
#
# starting epoch 16.0
#
# starting E-step...
# ...done
# -16839.880896778945
# starting M-step...
# ...done
#
# starting epoch 16.5
#
# starting E-step...
# ...done
# -16839.880892219702
# starting M-step...
# ...done
#
# starting epoch 17.0
#
# starting E-step...
# ...done
# -16839.880890052533
# starting M-step...
# ...done
#
# starting epoch 17.5
#
# starting E-step...
# ...done
# -16839.8808890226
# relative change of log likelihood is less than 1.0E-10. returning...
# BFGS 0
#
# -22575.497310531173
# -22575.49729682962
# -22575.497325390814
# -22575.497292831325
# -22575.497270300275
# -22575.49729112441
# -22575.497223508177
# -22575.497309505005
# -22575.49730668937
# -22575.49730954373
# -22575.497309947026
# -22575.497307485337
# -22575.49731062792
# -20059.93267692406
# -20059.93267233383
# -20059.932678371206
# -20059.932680517904
# -20059.93267888841
# -20059.93267819561
# -20059.932675658958
# -20059.932676062348
# -20059.932676075114
# -20059.932678480247
# -20059.93267732831
# -20059.932677243043
# -20059.932676066765
# -42554.67129560189
# -42554.67129622692
# -42554.67129388597
# -42554.67129435313
# -42554.671295488144
# -42554.67129313709
# -42554.67143565929
# -42554.671295625914
# -42554.67129546049
# -42554.671295577406
# -42554.67129395315
# -42554.6712995579
# -42554.67131894094
# -19839.69649850454
# -19839.69649308838
# -19839.69649302097
# -19839.696501286882
# -19839.69650978441
# -19839.69649334344
# -19839.69650728198
# -19839.696498254245
# -19839.696498011795
# -19839.696499260936
# -19839.696497920515
# -19839.696499247162
# -19839.696498141344
# -19583.979304372107
# -19583.97931133163
# -19583.97928593479
# -19583.97930466565
# -19583.97932728079
# -19583.979287442467
# -19583.97932887294
# -19583.979305287226
# -19583.97930429825
# -19583.979304349337
# -19583.97930308029
# -19583.979304673794
# -19583.979304573924
# -18724.85112336805
# -18724.85112965665
# -18724.85109666723
# -18724.851122818127
# -18724.851137371563
# -18724.851094250527
# -18724.851136680536
# -18724.851124286917
# -18724.851125762754
# -18724.851122408098
# -18724.85112372127
# -18724.85112292112
# -18724.851122307093
# -26088.729759771773
# -26088.729760034807
# -26088.7297597733
# -26088.7297597717
# -26088.729759732967
# -26088.72988742962
# -26088.72975983563
# -26088.729759716498
# -26088.72975979741
# -26088.729759840648
# -26088.729761715284
# -26088.729759769914
# -26088.72975973566
# -18582.0785103169
# -18582.078504975732
# -18582.07848845615
# -18582.07850998427
# -18582.07851175322
# -18582.078487603354
# -18582.078519277642
# -18582.078511209485
# -18582.078513515844
# -18582.078508925497
# -18582.078511234333
# -18582.078509874253
# -18582.078509243085
# -29190.806140801797
# -29190.80611933912
# -29190.80614299729
# -29190.80614080114
# -29190.80613552933
# -29190.806273969512
# -29190.80614115484
# -29190.80614052573
# -29190.80614157761
# -29190.80613984781
# -29190.80614197007
# -29190.806140634926
# -29190.80614079923
# -18515.121191854025
# -18515.121181738115
# -18515.121173993863
# -18515.121191631606
# -18515.121187853136
# -18515.12117650375
# -18515.121198204943
# -18515.121192783667
# -18515.12119543712
# -18515.121190232396
# -18515.121193142648
# -18515.121191413255
# -18515.121190896938
# -19190.715108793214
# -19190.715121978104
# -19190.7151021772
# -19190.715108613513
# -19190.715085592907
# -19190.715069411603
# -19190.715126248735
# -19190.71510997384
# -19190.715113100618
# -19190.715106732972
# -19190.715107643548
# -19190.715108050306
# -19190.715107526823
# -18508.92382286164
# -18508.92381421876
# -18508.92380562039
# -18508.923822643177
# -18508.923817739273
# -18508.92380492288
# -18508.923829877327
# -18508.923823808243
# -18508.923826494392
# -18508.92382122177
# -18508.923823968362
# -18508.923822422028
# -18508.923821854012
# -18502.27044130699
# -18502.270438222575
# -18502.270424600454
# -18502.270441080705
# -18502.270437643856
# -18502.27042470766
# -18502.270448474384
# -18502.270442287434
# -18502.27044532955
# -18502.27043964518
# -18502.270442378467
# -18502.27044082391
# -18502.270440318513
# -18490.231581524826
# -18490.231580326963
# -18490.23156489445
# -18490.231581294393
# -18490.231577707196
# -18490.23156525131
# -18490.231588910035
# -18490.231582371685
# -18490.231585270827
# -18490.231579871714
# -18490.231582664554
# -18490.23158100721
# -18490.231580530864
# -18470.04317380086
# -18470.043171418492
# -18470.04315782068
# -18470.043173553033
# -18470.043171831152
# -18470.043158196408
# -18470.043182062924
# -18470.043174754403
# -18470.043177451407
# -18470.0431721804
# -18470.04317523129
# -18470.043173214057
# -18470.043172719725
# -18430.363795875037
# -18430.363794601595
# -18430.363779962736
# -18430.36379561545
# -18430.36379459558
# -18430.36378044068
# -18430.363804641063
# -18430.363797062462
# -18430.363799292514
# -18430.363794281282
# -18430.363797193815
# -18430.36379529212
# -18430.36379488396
# -18330.60038537187
# -18330.60038831093
# -18330.600369991662
# -18330.600385101476
# -18330.600386785045
# -18330.600367603223
# -18330.600394949546
# -18330.60038751781
# -18330.60038801811
# -18330.600383889112
# -18330.600386020353
# -18330.600384730096
# -18330.60038550563
# -18239.033702089208
# -18239.033699733325
# -18239.033689722917
# -18239.033701747925
# -18239.03370733705
# -18239.033680967554
# -18239.03371260522
# -18239.033702149005
# -18239.033705021422
# -18239.03370088226
# -18239.033702787718
# -18239.033701701686
# -18239.033702819423
# -18131.23952809579
# -18131.239527546426
# -18131.239517000697
# -18131.239527741247
# -18131.239533688742
# -18131.239508213977
# -18131.239537653757
# -18131.23952779075
# -18131.239530135175
# -18131.23952756412
# -18131.239528613634
# -18131.239529289487
# -18131.23952746597
# -18059.89975605716
# -18059.89974893757
# -18059.899749410495
# -18059.8997558196
# -18059.899765229224
# -18059.89973884841
# -18059.899763772526
# -18059.899755641356
# -18059.89975732212
# -18059.89975491107
# -18059.89975448827
# -18059.89975648485
# -18059.8997563293
# -17912.467937406615
# -17912.46792698672
# -17912.46793183274
# -17912.467937217974
# -17912.467942982148
# -17912.46792485078
# -17912.467943090956
# -17912.467936919318
# -17912.46793905326
# -17912.46793636581
# -17912.467936878762
# -17912.467937733254
# -17912.467937294536
# -18713.727720046638
# -18713.727702364533
# -18713.72771475788
# -18713.727719884915
# -18713.727714447366
# -18713.72772509554
# -18713.727724417593
# -18713.727718292423
# -18713.7277210338
# -18713.727736289064
# -18713.727719974548
# -18713.7277203653
# -18713.72771957006
# -17865.433581983943
# -17865.433570431545
# -17865.433576773466
# -17865.433581817477
# -17865.433585714385
# -17865.43357202087
# -17865.433586881984
# -17865.433581389632
# -17865.433583638707
# -17865.433581979032
# -17865.43358171583
# -17865.433582300022
# -17865.43358175341
# -17784.530971210464
# -17784.53096397162
# -17784.530967466104
# -17784.530971084805
# -17784.530974088266
# -17784.53096542747
# -17784.53097509911
# -17784.530970742417
# -17784.53097253692
# -17784.530971180244
# -17784.530971115888
# -17784.530971464712
# -17784.53097100352
# -17705.725621225916
# -17705.725623394283
# -17705.725620114452
# -17705.725621161055
# -17705.7256221992
# -17705.72562212876
# -17705.725623693073
# -17705.725622319696
# -17705.725621927766
# -17705.72562102668
# -17705.725621312078
# -17705.72562135209
# -17705.725621144036
# -17680.439403788405
# -17680.439405003417
# -17680.43940280202
# -17680.43940372536
# -17680.439405713933
# -17680.439405590972
# -17680.439406141646
# -17680.439403854674
# -17680.439404228444
# -17680.439403758475
# -17680.43940385795
# -17680.439403908204
# -17680.439403725097
# -17660.67692457596
# -17660.676926094588
# -17660.67692406207
# -17660.676924521485
# -17660.67692753979
# -17660.676924280047
# -17660.67692692282
# -17660.67692445653
# -17660.676924742416
# -17660.676924534808
# -17660.67692445757
# -17660.676924675918
# -17660.676924605224
# -17642.695519002013
# -17642.695520860176

# %% [markdown]
# # Plot Results

# %%
def plot_ll(optims,x_time=False):
    
    ll_star = optims["control"].log_like_trace[-1]
    legend = []
    
    for method in methods:#["EM","SGD","SAG","SVRG","SAGA"]:
        for partial_E in [0,0.5,1]:
            
            PE = (partial_E == 0.5) or (partial_E == 1)
            M = int(partial_E == 0) + int(partial_E == 0.5) + 10*(partial_E == 1)
            
            if (method,partial_E) in optims:
                
                optim = optims[(method,partial_E)]
                if x_time:
                    plt.plot(optim.time_trace,np.log10(ll_star-optim.log_like_trace))
                else:
                    plt.plot(np.log10(ll_star-optim.log_like_trace))    
                title = method 
                if partial_E:
                    title += ", partial E"
                else:
                    title += ", no partial E"
                title += ", M = %dT" % M
                
                legend.append(title)
                
    plt.ylabel(r"$\log_{10}\left[\log p(\mathbf{y} ; \theta, \eta) - \log p(\mathbf{y} ; \theta^*, \eta^*)\right]$")
    plt.legend(legend)
    if x_time:
        plt.xlabel("Seconds of Computation")
        plt.savefig("../plt/log-like_v_time_exp_%d.png" % experiment)
    else:
        plt.xlabel("Epoch")
        plt.savefig("../plt/log-like_v_epoch_exp_%d.png" % experiment)
    plt.show()
                
    return

def plot_results(optim,ll_star,method,partial_E,M,experiment=1,iters=None):
    
    title = method 
    if partial_E:
        title += ", partial E-step"
    title += ", M = %dT" % M
    
    if iters is None:
        iters=len(optim.theta_trace)
        
    if method.startswith("SAGA"):
        x = (np.arange(iters) / optim.T)
    else:
        x = np.arange(iters)
    
    # plot log of gradient of log-likelihood
    plt.plot(np.log10(optim.grad_norm_trace))
    plt.axhline(-3, c = 'k', linestyle = "--")
    plt.title(r"$\log_{10}$ of Gradient Norm v Epoch, %s" % title)
    plt.xlabel("Epoch (k)")
    plt.ylabel(r"$\log ||\widehat \nabla_\theta F^{(k,m)} + \widehat \nabla_\eta G^{(k,m)}||$")
    plt.savefig("../plt/grad-hat-ll-%s-%s-%d-%d.png"%(method,partial_E,M,experiment))
    plt.show()

    # plot means
    legend = []
    for k in range(optim.K[0]):
        plt.plot(x,[optim.theta_trace[i][0]['Y']['mu'][k] for i in range(iters)])
        legend.append(r"$\mu^{(%d)}$"%(k+1))
    for hline in range(optim.K[0]):
        plt.axhline(hline, c = 'k', linestyle = "--")
        
    plt.title("$\mu$ v Epoch, %s" % title)
    plt.xlabel("Epoch")
    plt.legend(legend)
    plt.savefig("../plt/mu-%s-%s-%d-%d.png"%(method,partial_E,M,experiment))
    plt.show()
    
    # plot log(sigma)
    legend = []
    for k in range(optim.K[0]):
        plt.plot(x,[optim.theta_trace[i][0]['Y']['log_sig'][k] for i in range(len(optim.theta_trace))])
        legend.append(r"$\log\left(\sigma^{(%d)}\right)$"%(k+1))
    for hline in range(optim.K[0]):
        plt.axhline(hline-1, c = 'k', linestyle = "--")
        
    plt.title(r"$\log\left(\sigma\right)$ v Epoch, %s" % title)
    plt.xlabel("Epoch")
    plt.legend(legend)
    plt.savefig("../plt/log-sig-%s-%s-%d-%d.png"%(method,partial_E,M,experiment))
    plt.show()
    
    # plot eta
    legend = []
    for k in range(optim.K[0]):
        for l in range(optim.K[0]):
            if k != l:
                plt.plot(x,[optim.eta_trace[i][0][k,l] for i in range(len(optim.eta_trace))])
                legend.append(r"$\eta^{(%d,%d)}$" % (k+1,l+1))
    plt.title(r"$\eta$ v Epoch, %s" % title)
    plt.xlabel("Epoch")
    plt.legend(legend)
    plt.savefig("../plt/eta-%s-%s-%d-%d.png"%(method,partial_E,M,experiment))
    plt.show()
    
    #plt.plot([optim.grad_theta_trace[i][0]['Y']['log_sig'][0] for i in range(len(optim.theta_trace))])
    #plt.plot([optim.grad_theta_trace[i][0]['Y']['log_sig'][1] for i in range(len(optim.theta_trace))])
    #plt.plot([optim.grad_theta_trace[i][0]['Y']['log_sig'][2] for i in range(len(optim.theta_trace))])
    #plt.title("Gradients of Standard Deviations v iteration number")
    #plt.show()

# %%
#plot_ll(optims,x_time=True)
plot_ll(optims,x_time=False)

for method in methods:#["EM","SGD","SAG","SVRG","SAGA"]:
    for partial_E in [0,0.5,1]:
        PE = (partial_E == 0.5) or (partial_E == 1)
        M = int(partial_E == 0) + int(partial_E == 0.5) + 10*(partial_E == 1)
        if (method,partial_E) in optims:
            plot_results(optims[(method,partial_E)],optim_ll,method,PE,M)
