# %%
import sys
#sys.path.remove('/Users/evsi8432/Documents/Research/CarHHMM-DFT/Repository/Code')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm

from scipy.stats import gamma
from scipy.stats import norm
from scipy.stats import truncnorm
from scipy.stats import vonmises
from scipy.stats import multivariate_normal
from scipy.stats import gaussian_kde
from scipy.stats import circstd
from scipy.special import iv
from scipy.special import expit
from scipy.special import logit
from scipy.special import logsumexp
from scipy.optimize import minimize
from scipy.optimize import minimize_scalar
from scipy.optimize import LinearConstraint
from scipy.signal import convolve
from scipy.interpolate import interp1d
from scipy.linalg import block_diag

from datetime import datetime
from time import gmtime, strftime

from math import isclose

from copy import deepcopy

import importlib

import time
import pickle
import random

# %%
import main

from main import delta_2_eta0
from main import Gamma_2_eta
from main import eta0_2_delta
from main import eta_2_Gamma

np.random.seed(0)
random.seed(0)

# %% [markdown]
# # Initialize Parameters

# %%
# parameters for model
K = [2,3]
jump_every = 1

features = [{},
            {'diveDuration'     : {'f'           : 'normal',
                                   'lower_bound' : None,
                                   'upper_bound' : None},
             'maxDepth'         : {'f'           : 'normal',
                                   'lower_bound' : np.array([-np.infty,np.log(5),np.log(5)]),
                                   'upper_bound' : np.array([np.log(20),np.infty,np.infty])},
             'avg_bot_htv'      : {'f'           : 'normal',
                                   'lower_bound' : None,
                                   'upper_bound' : None}}]
             #'avg_bot_abs_roll' : {'f':'normal'},
             #'max_bot_jp'       : {'f':'normal'},
             #'broadDiveType'    : {'f':'bern'}}],
             #'foraging'         : {'f':'bern'},
             #'scales'           : {'f':'bern'},
             #'click.train'      : {'f':'bern'},
             #'whales'           : {'f':'bern'}}]

# optimization parameters 
methods = ["BFGS","CG"]#,"Nelder-Mead","L-BFGS-B"]
num_epochs = 100
tol = 1e-8
grad_tol = 1e-8

# %% [markdown]
# # Load in Whale Data

# %%
# load in data
df = pd.read_csv("../dat/Final_Data.csv")

# only take whale I107
whales = ["I107"]#,"I145"]
df = df[df["ID"].isin(whales)]

# convert times
df["stime"] = pd.to_datetime(df["stime"])
df["etime"] = pd.to_datetime(df["etime"])

# force dives to be at least 2 seconds long
df = df[df["diveDuration"] > np.log(2.1)]

# replace -inf 
df["max_bot_jp"][df["max_bot_jp"] == -np.infty] = np.NAN

df["broadDiveType"] = np.NAN #3  # unknown
df.loc[df["maxDepth"] > np.log(20),"broadDiveType"] = 1  # deep
df.loc[df["maxDepth"] < np.log(5),"broadDiveType"] = 0  # shallow
# populate a data object
data = []
for row in df.iterrows():
    data.append({"diveDuration"     : row[1]["diveDuration"],
                 "maxDepth"         : row[1]["maxDepth"],
                 "avg_bot_htv"      : row[1]["avg_bot_htv"]})#,
                 #"broadDiveType"    : row[1]["broadDiveType"]})#,
                 #"avg_bot_abs_roll" : row[1]["avg_bot_abs_roll"],
                 #"max_bot_jp"       : row[1]["max_bot_jp"]})#,
                 #"foraging"         : row[1]["foraging"],
                 #"scales"           : row[1]["scales"],
                 #"click.train"      : row[1]["click.train"],
                 #"whales"           : row[1]["whales"]})

# %%
raw_df = pd.read_csv("../dat/Final_rawData.csv", 
                      usecols = ["Time","p","head","pitch","roll","divenum"],
                      low_memory = True)

# %%
raw_df["Elevation"] = -raw_df["p"]
raw_df["Time"] = pd.to_datetime(raw_df["Time"])

#dive_inds = raw_df["divenum"].isin(df["divenum"].unique())
#raw_df = raw_df[dive_inds]

raw_df
raw_df = raw_df[raw_df["Time"] > min(df["stime"])]
raw_df = raw_df[raw_df["Time"] < max(df["etime"])]

raw_df = raw_df.reset_index(drop=True)

# %%
plt.figure(figsize=(30,8))
plt.plot(raw_df.iloc[::50]["Time"],
         raw_df.iloc[::50]["Elevation"])
plt.xticks([])
plt.axhline(0,color='k')
plt.show()

# %% [markdown]
# # Train the HMM

# %%
# initialize optims
optims = {}
times = {}

# %%
df[["diveDuration"]].hist()
df[["maxDepth"]].hist()
df[["avg_bot_htv"]].hist()
df[["avg_bot_abs_roll"]].hist()
df[["max_bot_jp"]].hist()
# Out:
# array([[<AxesSubplot:title={'center':'max_bot_jp'}>]], dtype=object)

# %%
importlib.reload(main)
from numpy import array

for exp in range(1):
    for method in methods:
        print(method,exp)
        optims[(method,exp)] = main.optimizor(data[:10],features,K)
        optims[(method,exp)].jump_every = jump_every


        # initize parameters
        if exp == 0:
            optims[(method,exp)].theta = [{},
                                          # travelling
                                         [{'diveDuration': {'mu': array([2.5, 4.96]),
                                            'log_sig': np.log(array([2.0, 2.0]))},
                                           'maxDepth': {'mu': array([0.5, 2.69]),
                                            'log_sig': np.log(array([2.0, 2.0]))}},
                                           #'avg_bot_htv': {'mu': array([-1.0, -1.49]),
                                           # 'log_sig': np.log(array([2.0, 2.0]))},
                                           #'avg_bot_abs_roll': {'mu': array([-2.5, -2.0]),
                                           # 'log_sig': np.log(array([2.0, 2.0]))},
                                           #'max_bot_jp': {'mu': array([-2.0, -2.5]),
                                           # 'log_sig': np.log(array([1.0, 1.0]))},
                                           #'broadDiveType': {'logit_p': array([-10.,10.])}},
                                           #'foraging': {'logit_p': array([-3.0,-3.0])},
                                           #'scales': {'logit_p': array([-3.0,-3.0])},
                                           #'click.train': {'logit_p': array([-3.0,-3.0])},
                                           #'whales':{'logit_p': array([-1.0,1.0])}},
                                          # foraging
                                          {'diveDuration': {'mu': array([2.5, 4.98]),
                                            'log_sig': np.log(array([2.0, 2.0]))},
                                           'maxDepth': {'mu': array([0.5, 3.54]),
                                            'log_sig': np.log(array([2.0, 2.0]))}}]]#,
                                           #'avg_bot_htv': {'mu': array([-1.0, -0.35]),
                                           # 'log_sig': np.log(array([2.0, 2.0]))},
                                           #'avg_bot_abs_roll': {'mu': array([-2.5, -1.0]),
                                           # 'log_sig': np.log(array([2.0, 2.0]))},
                                           #'max_bot_jp': {'mu': array([-2.0, -0.75]),
                                           # 'log_sig': np.log(array([2.0, 2.0]))},
                                           #'broadDiveType': {'logit_p': array([-10.,10.])}}]]#,
                                           #'foraging': {'logit_p': array([-1.0,0.0])},
                                           #'scales': {'logit_p': array([-1.0,0.0])},
                                           #'click.train': {'logit_p': array([-1.0,0.0])},
                                           #'whales':{'logit_p': array([-1.0,-1.0])}}]]

            optims[(method,exp)].theta = [{},
                                          [{'diveDuration': {'mu': array([2.44664673, 4.59732218, 5.7132845 ]),
                                            'log_sig': array([-0.48804826, -0.66160109, -1.08111493])},
                                           'maxDepth': {'mu': array([0.83775589, 2.99611277, 4.73163697]),
                                            'log_sig': array([-1.06991028, -0.49912994, -1.13620343])},
                                           'avg_bot_htv': {'mu': array([-1.78768617, -1.73621666, -0.91032972]),
                                            'log_sig': array([0.0, 0.0, 0.0])}},
                                           #'avg_bot_abs_roll': {'mu': array([-2.10086378, -1.57589996, -0.67009179]),
                                           # 'log_sig': array([0.29613075, 0.09076756, 0.26332979])},
                                           #'max_bot_jp': {'mu': array([1.96233616, 1.92165666, 3.57603349]),
                                           # 'log_sig': array([0.11742883, 0.20457382, 0.12237257])},
                                           #'broadDiveType': {'logit_p': array([-10.,  10.,  10.])}},
                                          {'diveDuration': {'mu': array([2.44664673, 4.59732218, 5.7132845 ]),
                                            'log_sig': array([-0.48804826, -0.66160109, -1.08111493])},
                                           'maxDepth': {'mu': array([0.83775589, 2.99611277, 4.73163697]),
                                            'log_sig': array([-1.06991028, -0.49912994, -1.13620343])},
                                           'avg_bot_htv': {'mu': array([-1.78768617, -1.73621666, -0.91032972]),
                                            'log_sig': array([0.0, 0.0, 0.0])}}]]
                                           #'avg_bot_abs_roll': {'mu': array([-2.10086378, -1.57589996, -0.67009179]),
                                           # 'log_sig': array([0.29613075, 0.09076756, 0.26332979])},
                                           #'max_bot_jp': {'mu': array([1.96233616, 1.92165666, 3.57603349]),
                                           # 'log_sig': array([0.11742883, 0.20457382, 0.12237257])},
                                           #'broadDiveType': {'logit_p': array([-10.,  10.,  10.])}}]]
                            
            Gamma = [np.array([[0.99,0.01],
                               [0.01,0.99]]),
                     [np.array([[0.8, 0.15, 0.05],
                                [0.9, 0.05, 0.05],
                                [0.9, 0.05, 0.05]]),
                      np.array([[0.8, 0.05, 0.15],
                                [0.9, 0.05, 0.05],
                                [0.9, 0.05, 0.05]])]]

            delta = [array([0.5, 0.5]),
                     [array([0.05, 0.9, 0.05]),
                      array([0.05, 0.05, 0.9])]]
        
            optims[(method,exp)].eta0 = delta_2_eta0(delta)
            optims[(method,exp)].eta = Gamma_2_eta(Gamma)
            
            print(optims[(method,exp)].theta)
        
        
        #optims[(method,exp)].theta[1][0]['broadDiveType']['logit_p'][0] = -10.0
        #optims[(method,exp)].theta[1][0]['broadDiveType']['logit_p'][1] = 10.0
        #optims[(method,exp)].theta[1][0]['broadDiveType']['logit_p'][2] = 10.0
        #optims[(method,exp)].theta[1][1]['broadDiveType']['logit_p'][0] = -10.0
        #optims[(method,exp)].theta[1][1]['broadDiveType']['logit_p'][1] = 10.0
        #optims[(method,exp)].theta[1][1]['broadDiveType']['logit_p'][2] = 10.0
        
        optims[(method,exp)].train_HHMM(num_epochs=num_epochs,
                                        method=method)
# Out:
# BFGS 0
# [{}, [{'diveDuration': {'mu': array([2.44664673, 4.59732218, 5.7132845 ]), 'log_sig': array([-0.48804826, -0.66160109, -1.08111493])}, 'maxDepth': {'mu': array([0.83775589, 2.99611277, 4.73163697]), 'log_sig': array([-1.06991028, -0.49912994, -1.13620343])}, 'avg_bot_htv': {'mu': array([-1.78768617, -1.73621666, -0.91032972]), 'log_sig': array([0., 0., 0.])}}, {'diveDuration': {'mu': array([2.44664673, 4.59732218, 5.7132845 ]), 'log_sig': array([-0.48804826, -0.66160109, -1.08111493])}, 'maxDepth': {'mu': array([0.83775589, 2.99611277, 4.73163697]), 'log_sig': array([-1.06991028, -0.49912994, -1.13620343])}, 'avg_bot_htv': {'mu': array([-1.78768617, -1.73621666, -0.91032972]), 'log_sig': array([0., 0., 0.])}}]]
# ...

# %%
theta = [{},
                                          [{'diveDuration': {'mu': array([2.44664673, 4.59732218, 5.7132845 ]),
                                            'log_sig': array([-0.48804826, -0.66160109, -1.08111493])},
                                           'maxDepth': {'mu': array([0.83775589, 2.99611277, 4.73163697]),
                                            'log_sig': array([-1.06991028, -0.49912994, -1.13620343])},
                                           'avg_bot_htv': {'mu': array([-1.78768617, -1.73621666, -0.91032972]),
                                            'log_sig': array([0.0, 0.0, 0.0])}},
                                           #'avg_bot_abs_roll': {'mu': array([-2.10086378, -1.57589996, -0.67009179]),
                                           # 'log_sig': array([0.29613075, 0.09076756, 0.26332979])},
                                           #'max_bot_jp': {'mu': array([1.96233616, 1.92165666, 3.57603349]),
                                           # 'log_sig': array([0.11742883, 0.20457382, 0.12237257])},
                                           #'broadDiveType': {'logit_p': array([-10.,  10.,  10.])}},
                                          {'diveDuration': {'mu': array([2.44664673, 4.59732218, 5.7132845 ]),
                                            'log_sig': array([-0.48804826, -0.66160109, -1.08111493])},
                                           'maxDepth': {'mu': array([0.83775589, 2.99611277, 4.73163697]),
                                            'log_sig': array([-1.06991028, -0.49912994, -1.13620343])},
                                           'avg_bot_htv': {'mu': array([-1.78768617, -1.73621666, -0.91032972]),
                                            'log_sig': array([0.0, 0.0, 0.0])}}]]
                                           #'avg_bot_abs_roll': {'mu': array([-2.10086378, -1.57589996, -0.67009179]),
                                           # 'log_sig': array([0.29613075, 0.09076756, 0.26332979])},
                                           #'max_bot_jp': {'mu': array([1.96233616, 1.92165666, 3.57603349]),
                                           # 'log_sig': array([0.11742883, 0.20457382, 0.12237257])},
                                           #'broadDiveType': {'logit_p': array([-10.,  10.,  10.])}}]]

# %%
theta
# Out:
# ([{},
#   [{'diveDuration': {'mu': array([2.44664673, 4.59732218, 5.7132845 ]),
#      'log_sig': array([-0.48804826, -0.66160109, -1.08111493])},
#     'maxDepth': {'mu': array([0.83775589, 2.99611277, 4.73163697]),
#      'log_sig': array([-1.06991028, -0.49912994, -1.13620343])},
#     'avg_bot_htv': {'mu': array([-1.78768617, -1.73621666, -0.91032972]),
#      'log_sig': array([0., 0., 0.])}},
#    {'diveDuration': {'mu': array([2.44664673, 4.59732218, 5.7132845 ]),
#      'log_sig': array([-0.48804826, -0.66160109, -1.08111493])},
#     'maxDepth': {'mu': array([0.83775589, 2.99611277, 4.73163697]),
#      'log_sig': array([-1.06991028, -0.49912994, -1.13620343])},
#     'avg_bot_htv': {'mu': array([-1.78768617, -1.73621666, -0.91032972]),
#      'log_sig': array([0., 0., 0.])}}]],)

# %%
model0 = "None"
ll0 = -np.infty
for model,optim in optims.items():
    
    print(model)
    print(logsumexp(optim.log_alphas[-1]))
    
    if logsumexp(optim.log_alphas[-1]) > ll0:
        model0 = model
        ll0 = logsumexp(optim.log_alphas[-1])

#model0 = ('BFGS', 0)
print(model0)
# Out:
# ('BFGS', 0)
# 1.791759469228055
# ('BFGS', 0)

# %%
for key,optim in optims.items():
    print(key)
    display(eta_2_Gamma(optim.eta))
    display(optim.theta)

# %%
optims[model0].theta

# %%
eta_2_Gamma(optims[model0].eta)

# %%
eta0_2_delta(optims[model0].eta0)

# %%
np.exp(optims[model0].get_log_Gamma()[0])

# %%
with open("optims_"+datetime.now().strftime('%Y-%m-%d_%H:%M:%S'), 'wb') as f:
    pickle.dump(optims, f)

# %% [markdown]
# # Plot Results

# %%
df

# %%
ind = 0

# get the dive types
df["ML_divetype"] = -1
df["ML_divetype"] = np.argmax(optims[model0].p_Xt,1)

df["p_coarse_1"] = optim.p_Xt[:,0] + optim.p_Xt[:,1] + optim.p_Xt[:,2]
df["p_fine_1"] = optim.p_Xt[:,1] + optim.p_Xt[:,4]
df["p_fine_2"] = optim.p_Xt[:,2] + optim.p_Xt[:,5] 

# define colors
colors = [cm.get_cmap('tab10')(i) for i in range(K[0]*K[1])]

fig,ax = plt.subplots(4,1,figsize=(30,20))

# plot dashed line
for divenum in range(ind,ind+1200):
    print(divenum)
    dive_df = raw_df[raw_df["Time"] <= df["stime"].iloc[divenum+1]]
    dive_df = dive_df[dive_df["Time"] >= df["etime"].iloc[divenum-1]]
    dive_df = dive_df.iloc[::50]

    ax[0].plot(pd.to_datetime(dive_df["Time"]),
               dive_df["Elevation"],
             "k--")
    ax[0].set_xticks([])
    
    ax[1].plot(pd.to_datetime(dive_df["Time"]),
               dive_df["head"],
             "k--")
    ax[1].set_xticks([])
    
    ax[2].plot(pd.to_datetime([df.iloc[divenum]["stime"],df.iloc[divenum]["etime"]]),
               [df.iloc[divenum]["p_coarse_1"],df.iloc[divenum]["p_coarse_1"]],
               "k--")
    ax[2].set_xticks([])
    
    ax[3].plot(pd.to_datetime([df.iloc[divenum]["stime"],df.iloc[divenum]["etime"]]),
               [df.iloc[divenum]["p_fine_1"],df.iloc[divenum]["p_fine_1"]],
               "k--")
    ax[3].set_xticks([])
    
    
# plot colors of real dives
for divenum in range(ind,ind+1200):
    print(divenum)
    dive_df = raw_df[raw_df["divenum"] == df["divenum"].iloc[divenum]]
    dive_df = dive_df.iloc[::50]
    
    ax[0].plot(pd.to_datetime(dive_df["Time"]),
             dive_df["Elevation"],
             color=colors[df["ML_divetype"].iloc[divenum]])
    ax[0].set_xticks([])
    
    ax[1].plot(pd.to_datetime(dive_df["Time"]),
             dive_df["head"],
             color=colors[df["ML_divetype"].iloc[divenum]])
    ax[1].set_xticks([])
    
    ax[2].plot(pd.to_datetime([df.iloc[divenum]["stime"],df.iloc[divenum]["etime"]]),
               [df.iloc[divenum]["p_coarse_1"],df.iloc[divenum]["p_coarse_1"]],
               color=colors[df["ML_divetype"].iloc[divenum]])
    ax[2].set_xticks([])
    
    ax[3].plot(pd.to_datetime([df.iloc[divenum]["stime"],df.iloc[divenum]["etime"]]),
               [df.iloc[divenum]["p_fine_1"],df.iloc[divenum]["p_fine_1"]],
               color=colors[df["ML_divetype"].iloc[divenum]])
    ax[3].set_xticks([])
    
    
plt.show()

# %%
# plot the emission distributions
K_total = 6
optim = optims[model0]

for feature in features[1]:
    
    if features[1][feature]["f"] == "bern":
        continue
        
    print(feature)
    
    mu = np.concatenate([theta_fine[feature]['mu'] for theta_fine in optim.theta[1]])
    sig = np.exp(np.concatenate([theta_fine[feature]['log_sig'] for theta_fine in optim.theta[1]]))
    
    print(mu)
    print(sig)
    
    colors = [cm.get_cmap('tab10')(i) for i in range(K_total)]
    legend = ['Dive type %d'%(x+1) for x in range(K_total)]
    
    for state in range(K_total):
        x = np.linspace(min(mu)-3*max(sig),max(mu)+3*max(sig),10000)
        if features[1][feature]["f"]["upper"] == "bern":
        y = norm.pdf(x,mu[state],sig[state])
        plt.plot(x,y,color=colors[state])
        
        # do the histogram
        feature_data = [datum[feature] for datum in data] 
        
        plt.hist(feature_data,weights=optim.p_Xt[:,state],
                 density=True,color=colors[state],alpha=0.25)
        
        
    plt.show()

# %%
np.log(5)

# %%
plt.plot(optim.p_Xt[:,0] + optim.p_Xt[:,1] + optim.p_Xt[:,2])

# %%
norm.logcdf([1,2,3],loc=[3,3,4],scale=[1,2,3])

# %%
norm.logcdf((-10-1)/5)

# %%
A = np.array([1.0,1.0,1.0])
inds = np.array([1,2,3]) < np.array([2,3,2])
A[inds] = -np.infty
A

# %%
np.nan_to_num(-np.infty*(np.array([1,2,3]) < np.array([2,3,2])))

# %%
norm.logcdf(-100)

# %%
from scipy.stats import truncnorm

truncnorm.pdf(-2,[-np.infty,-2.1],[3,np.infty],loc=2,scale=3)
# Out:
# array([0.05474392, 0.05566444])

# %%
for x0 in np.linspace(-10,10,101):
    print(x0)
    print(truncnorm.pdf(x0,a = -np.inf, b = 2.99573227, loc = 6, scale = 5))
    print("")
# Out:
# -10.0
# 0.00047747126670707074
#
# -9.8
# 0.0005422374383645382
#
# -9.6
# 0.0006148042864068975
#
# -9.4
# 0.0006959682097709308
#
# -9.2
# 0.000786587511783516
#
# -9.0
# 0.0008875847268576684
#
# -8.8
# 0.000999948706008223
#
# -8.6
# 0.0011247364085508157
#
# -8.4
# 0.0012630743440405477
#
# -8.2
# 0.0014161596055346508
#
# -8.0
# 0.0015852604327146035
#
# -7.8
# 0.0017717162413695016
#
# -7.6
# 0.0019769370543188127
#
# -7.4
# 0.0022024022681348347
#
# -7.199999999999999
# 0.002449658690109392
#
# -7.0
# 0.0027203177808883955
#
# -6.8
# 0.003016052040162508
#
# -6.6
# 0.003338590475834087
#
# -6.4
# 0.003689713101256172
#
# -6.199999999999999
# 0.004071244410520937
#
# -6.0
# 0.00448504578841447
#
# -5.8
# 0.00493300681958636
#
# -5.6
# 0.005417035470723567
#
# -5.3999999999999995
# 0.005939047130065318
#
# -5.199999999999999
# 0.006500952500424014
#
# -5.0
# 0.007104644354936423
#
# -4.8
# 0.007751983178985819
#
# -4.6
# 0.008444781737006227
#
# -4.3999999999999995
# ...

# %%
x = np.linspace(-10,10,100)
