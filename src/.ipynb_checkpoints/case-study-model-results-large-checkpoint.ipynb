# %%
import sys

import pandas as pd
import numpy as np
import numdifftools as ndt
import statsmodels.api as sm

import matplotlib.pyplot as plt
import matplotlib.cm as cm
from matplotlib.patches import Patch
from matplotlib.patches import Rectangle
from matplotlib.lines import Line2D
from matplotlib.dates import DateFormatter

from scipy.stats import gamma
from scipy.stats import norm
from scipy.stats import truncnorm
from scipy.stats import vonmises
from scipy.stats import multivariate_normal
from scipy.stats import gaussian_kde
from scipy.stats import circstd
from scipy.special import iv
from scipy.special import expit
from scipy.special import logit
from scipy.special import logsumexp
from scipy.optimize import minimize
from scipy.optimize import minimize_scalar
from scipy.optimize import LinearConstraint
from scipy.signal import convolve
from scipy.interpolate import interp1d
from scipy.linalg import block_diag

from datetime import datetime
from time import gmtime, strftime

from math import isclose
from copy import deepcopy
from itertools import product
import importlib
import time
import pickle
import random

import helper_funcs
import HHMM
import optimizor
import stoch_optimizor

from helper_funcs import eta_2_log_Gamma
from helper_funcs import log_Gamma_2_eta
from helper_funcs import eta0_2_log_delta
from helper_funcs import log_delta_2_eta0
from helper_funcs import logdotexp

# %% [markdown]
# # Initialize Parameters

# %%
### features of data ###
features = {'w_low'             : {'f'           : 'normal',
                                   'lower_bound' : None,
                                   'upper_bound' : None,
                                   'share_coarse': True,
                                   'share_fine'  : False},
            'w_high'            : {'f'           : 'normal',
                                   'lower_bound' : None,
                                   'upper_bound' : None,
                                   'share_coarse': True,
                                   'share_fine'  : False}}



### load in data ###
df = pd.read_csv("../../dat/Final_Data_Beth_fine.csv")
df["w_low"] = np.log(df["w_low"])
df["w_high"] = np.log(df["w_high"])

whales = pd.unique(df.ID)

# only take whale I107
#whales = ["I145"]
#df = df[df["ID"].isin(whales)]

# convert times
df["stime"] = pd.to_datetime(df["stime"])
df["etime"] = pd.to_datetime(df["etime"])

# populate a data object
data = []

initial_ts = [0]
final_ts = []

for t,row in enumerate(df.iterrows()):

    if t != 0 and df.iloc[t]["ID"] != df.iloc[t-1]["ID"]:
        final_ts.append(t-1)
        initial_ts.append(t)

    data.append({"w_low"     : row[1]["w_low"],
                 "w_high"    : row[1]["w_high"]})

final_ts.append(t)

initial_ts = np.array(initial_ts)
final_ts = np.array(final_ts)

T = len(data)
K = [3,3]
# Out:
# /var/folders/1p/g1nbxjc540sd1x_r8wk3ljm00000gn/T/ipykernel_5693/2000939177.py:16: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../../dat/Final_Data_Beth_fine.csv")

# %% [markdown]
# # Load in Whale Data

# %%
pd.read_csv("../../dat/Final_rawData_Beth.csv",nrows=100).ID
# Out:
# 0     A100
# 1     A100
# 2     A100
# 3     A100
# 4     A100
#       ...
# 95    A100
# 96    A100
# 97    A100
# 98    A100
# 99    A100
# Name: ID, Length: 100, dtype: object

# %%
raw_df = pd.read_csv("../../dat/Final_rawData_Beth.csv", 
                      usecols = ["Time","p","head","pitch","roll","divenum","w_low","w_high","ID"],
                      low_memory = True)

# %%
raw_df["Elevation"] = -raw_df["p"]
raw_df["Time"] = pd.to_datetime(raw_df["Time"])
raw_df = raw_df.reset_index(drop=True)

# %%
for whale in whales:
    print(whale)
    stime = df.loc[df["ID"].isin([whale]),"stime"].min()
    etime = df.loc[df["ID"].isin([whale]),"etime"].max()
    plt.figure(figsize=(30,8))
    inds = (raw_df["Time"] > stime) & (raw_df["Time"] < etime) & (raw_df["ID"] == whale)
    plt.plot(raw_df[inds].iloc[::50]["Time"],
             raw_df[inds].iloc[::50]["Elevation"])
    plt.locator_params(axis='x', nbins=10)
    plt.axhline(0,color='k')
    plt.gca().xaxis.set_major_formatter(DateFormatter('%Y-%m-%d %H:%M:%S'))
    plt.show()
# Out:
# A100
# /var/folders/1p/g1nbxjc540sd1x_r8wk3ljm00000gn/T/ipykernel_5693/1254500412.py:8: UserWarning: 'set_params()' not defined for locator of type <class 'matplotlib.dates.AutoDateLocator'>
#   plt.locator_params(axis='x', nbins=10)
# A113
# /var/folders/1p/g1nbxjc540sd1x_r8wk3ljm00000gn/T/ipykernel_5693/1254500412.py:8: UserWarning: 'set_params()' not defined for locator of type <class 'matplotlib.dates.AutoDateLocator'>
#   plt.locator_params(axis='x', nbins=10)
# D21
# /var/folders/1p/g1nbxjc540sd1x_r8wk3ljm00000gn/T/ipykernel_5693/1254500412.py:8: UserWarning: 'set_params()' not defined for locator of type <class 'matplotlib.dates.AutoDateLocator'>
#   plt.locator_params(axis='x', nbins=10)
# D26
# /var/folders/1p/g1nbxjc540sd1x_r8wk3ljm00000gn/T/ipykernel_5693/1254500412.py:8: UserWarning: 'set_params()' not defined for locator of type <class 'matplotlib.dates.AutoDateLocator'>
#   plt.locator_params(axis='x', nbins=10)
# I107
# /var/folders/1p/g1nbxjc540sd1x_r8wk3ljm00000gn/T/ipykernel_5693/1254500412.py:8: UserWarning: 'set_params()' not defined for locator of type <class 'matplotlib.dates.AutoDateLocator'>
#   plt.locator_params(axis='x', nbins=10)
# I145
# /var/folders/1p/g1nbxjc540sd1x_r8wk3ljm00000gn/T/ipykernel_5693/1254500412.py:8: UserWarning: 'set_params()' not defined for locator of type <class 'matplotlib.dates.AutoDateLocator'>
#   plt.locator_params(axis='x', nbins=10)
# R48
# /var/folders/1p/g1nbxjc540sd1x_r8wk3ljm00000gn/T/ipykernel_5693/1254500412.py:8: UserWarning: 'set_params()' not defined for locator of type <class 'matplotlib.dates.AutoDateLocator'>
#   plt.locator_params(axis='x', nbins=10)
# R58
# /var/folders/1p/g1nbxjc540sd1x_r8wk3ljm00000gn/T/ipykernel_5693/1254500412.py:8: UserWarning: 'set_params()' not defined for locator of type <class 'matplotlib.dates.AutoDateLocator'>
#   plt.locator_params(axis='x', nbins=10)

# %% [markdown]
# # Train the HMM

# %%
len(data)
# Out:
# 89462

# %%
#date = "Sep-25-2022" # both buffers
#date = "Sept-21-2022_large"
#date = "Sep-21-2022" # Beth's case study
#date = "Sep-19-2022" # No buffer for mini-batches, no buffer for weights
#date = "Sep-15-2022" # Make a buffer for mini-batches, but not for weights
#date = "Sep-16-2022" # Make a buffer for weights, but not for mini-batches
#date = "normal/Oct-31-2022" # no buffers, step size = 1/L
#date = "large/Nov-01-2022" # no buffers, step size = 1/L
#date = "normal/Nov-14-2022" # no buffers, step size = 1/3L
date = "large/Nov-14-2022" # no buffers, step size = 1/3L

param_folder = "/Volumes/One Touch/sublinear-HMM-inference/case_study/" + date
plot_folder = "/Users/evsi8432/Documents/Research/sublinear-HMM-inference/plt/case_study/" + date

methods = ["control","BFGS","SAGA","SVRG","GD","CG"]

K = [3,3]

partial_Es = [0.0,0.5,1.0]

tol = 1e-3

optims = {}
times_to_converge = {}
epochs_to_converge = {}
lls = {}

#"experiment_1_2022-08-05_20-27-39"
#"experiment_1_2022-08-05_20-26-58"
#"experiment_1_2022-08-05_20-26-22"
#"experiment_1_2022-08-05_20-25-49"
#"experiment_1_2022-08-05_20-25-36"
#"experiment_1_2022-08-05_20-27-53"
#"experiment_1_2022-08-05_20-25-18"
#"experiment_1_2022-08-05_20-25-12"

#with open("../params/experiment_1_2022-08-05_20-25-49","rb") as f:
#    optims = pickle.load(f)

# %%
for method in methods:
    for partial_E in partial_Es:
        if method in ["BFGS","CG","GD","control"] and partial_E > 0.0:
            pass
        else:
            
            # get best ll
            best_ll = -np.infty
            #best_fname = param_folder + "/case_study_large_K-%d-%d_%s_%.1f_%03d" % (K[0],K[1],method,partial_E,0)
            best_fname = param_folder + "/K-%d-%d_%s_%.1f_%03d" % (K[0],K[1],method,partial_E,0)
            
            # initialize lls
            lls[(method,partial_E)] = []
            
            # initialize epochs
            epochs_to_converge[(method,partial_E)] = []
            
            # initialize times
            times_to_converge[(method,partial_E)] = []
            
            for rand_seed in range(50):
                
                fname = param_folder + "/case_study_large_K-%d-%d_%s_%.1f_%03d" % (K[0],K[1],method,partial_E,rand_seed)
                #fname = param_folder + "/K-%d-%d_%s_%.1f_%03d" % (K[0],K[1],method,partial_E,rand_seed)
                
                try:
                    with open(fname, 'rb') as f:
                        optim = pickle.load(f)
                    print("loaded file %s" % fname)
                except:
                    print("file %s does not exist" % fname)
                    continue
                
                # check for some issue (likely nan in theta)
                if len(optim.time_trace) == 0:
                    print("file %s didn't optimize." % fname)
                    continue
                    
                
                # get convergence ind
                converge_ind = min(np.where(np.array(optim.grad_norm_trace) < tol)[0],
                                   default=len(optim.grad_norm_trace)-1)
                
                epochs_to_converge[(method,partial_E)].append(optim.epoch_trace[converge_ind])
                times_to_converge[(method,partial_E)].append(optim.time_trace[converge_ind])
                lls[(method,partial_E)].append(optim.log_like_trace[converge_ind])
                
                if optim.log_like_trace[-1] > best_ll:    
                    optims[(method,partial_E)] = optim
                    best_fname = fname
                    best_ll = optim.log_like_trace[-1]
                    
            print(best_fname)
# Out:
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_control_0.0_000 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_control_0.0_001 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_control_0.0_002 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_control_0.0_003 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_control_0.0_004 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_control_0.0_005 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_control_0.0_006 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_control_0.0_007 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_control_0.0_008 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_control_0.0_009 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_control_0.0_010 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_control_0.0_011 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_control_0.0_012 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_control_0.0_013 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_control_0.0_014 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_control_0.0_015 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_control_0.0_016 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_control_0.0_017 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_control_0.0_018 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_control_0.0_019 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_control_0.0_020 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_control_0.0_021 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_control_0.0_022 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_control_0.0_023 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_control_0.0_024 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_control_0.0_025 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_control_0.0_026 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_control_0.0_027 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_control_0.0_028 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_control_0.0_029 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_control_0.0_030 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_control_0.0_031 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_control_0.0_032 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_control_0.0_033 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_control_0.0_034 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_control_0.0_035 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_control_0.0_036 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_control_0.0_037 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_control_0.0_038 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_control_0.0_039 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_control_0.0_040 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_control_0.0_041 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_control_0.0_042 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_control_0.0_043 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_control_0.0_044 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_control_0.0_045 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_control_0.0_046 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_control_0.0_047 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_control_0.0_048 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_control_0.0_049 does not exist
# /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/K-3-3_control_0.0_000
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_BFGS_0.0_000 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_BFGS_0.0_001 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_BFGS_0.0_002 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_BFGS_0.0_003 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_BFGS_0.0_004 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_BFGS_0.0_005 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_BFGS_0.0_006 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_BFGS_0.0_007 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_BFGS_0.0_008 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_BFGS_0.0_009 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_BFGS_0.0_010 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_BFGS_0.0_011 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_BFGS_0.0_012 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_BFGS_0.0_013 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_BFGS_0.0_014 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_BFGS_0.0_015 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_BFGS_0.0_016 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_BFGS_0.0_017 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_BFGS_0.0_018 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_BFGS_0.0_019 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_BFGS_0.0_020 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_BFGS_0.0_021 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_BFGS_0.0_022 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_BFGS_0.0_023 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_BFGS_0.0_024 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_BFGS_0.0_025 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_BFGS_0.0_026 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_BFGS_0.0_027 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_BFGS_0.0_028 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_BFGS_0.0_029 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_BFGS_0.0_030 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_BFGS_0.0_031 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_BFGS_0.0_032 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_BFGS_0.0_033 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_BFGS_0.0_034 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_BFGS_0.0_035 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_BFGS_0.0_036 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_BFGS_0.0_037 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_BFGS_0.0_038 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_BFGS_0.0_039 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_BFGS_0.0_040 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_BFGS_0.0_041 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_BFGS_0.0_042 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_BFGS_0.0_043 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_BFGS_0.0_044 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_BFGS_0.0_045 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_BFGS_0.0_046 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_BFGS_0.0_047 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_BFGS_0.0_048 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_BFGS_0.0_049 does not exist
# /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/K-3-3_BFGS_0.0_000
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.0_000 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.0_001 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.0_002 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.0_003 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.0_004 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.0_005 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.0_006 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.0_007 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.0_008 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.0_009 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.0_010 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.0_011 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.0_012 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.0_013 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.0_014 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.0_015 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.0_016 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.0_017 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.0_018 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.0_019 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.0_020 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.0_021 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.0_022 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.0_023 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.0_024 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.0_025 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.0_026 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.0_027 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.0_028 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.0_029 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.0_030 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.0_031 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.0_032 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.0_033 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.0_034 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.0_035 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.0_036 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.0_037 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.0_038 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.0_039 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.0_040 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.0_041 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.0_042 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.0_043 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.0_044 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.0_045 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.0_046 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.0_047 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.0_048 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.0_049 does not exist
# /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/K-3-3_SAGA_0.0_000
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.5_000 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.5_001 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.5_002 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.5_003 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.5_004 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.5_005 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.5_006 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.5_007 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.5_008 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.5_009 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.5_010 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.5_011 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.5_012 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.5_013 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.5_014 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.5_015 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.5_016 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.5_017 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.5_018 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.5_019 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.5_020 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.5_021 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.5_022 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.5_023 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.5_024 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.5_025 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.5_026 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.5_027 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.5_028 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.5_029 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.5_030 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.5_031 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.5_032 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.5_033 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.5_034 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.5_035 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.5_036 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.5_037 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.5_038 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.5_039 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.5_040 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.5_041 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.5_042 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.5_043 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.5_044 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.5_045 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.5_046 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.5_047 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.5_048 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_0.5_049 does not exist
# /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/K-3-3_SAGA_0.5_000
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_1.0_000 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_1.0_001 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_1.0_002 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_1.0_003 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_1.0_004 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_1.0_005 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_1.0_006 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_1.0_007 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_1.0_008 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_1.0_009 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_1.0_010 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_1.0_011 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_1.0_012 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_1.0_013 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_1.0_014 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_1.0_015 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_1.0_016 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_1.0_017 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_1.0_018 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_1.0_019 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_1.0_020 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_1.0_021 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_1.0_022 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_1.0_023 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_1.0_024 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_1.0_025 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_1.0_026 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_1.0_027 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_1.0_028 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_1.0_029 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_1.0_030 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_1.0_031 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_1.0_032 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_1.0_033 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_1.0_034 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_1.0_035 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_1.0_036 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_1.0_037 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_1.0_038 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_1.0_039 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_1.0_040 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_1.0_041 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_1.0_042 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_1.0_043 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_1.0_044 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_1.0_045 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_1.0_046 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_1.0_047 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_1.0_048 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SAGA_1.0_049 does not exist
# /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/K-3-3_SAGA_1.0_000
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.0_000 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.0_001 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.0_002 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.0_003 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.0_004 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.0_005 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.0_006 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.0_007 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.0_008 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.0_009 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.0_010 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.0_011 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.0_012 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.0_013 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.0_014 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.0_015 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.0_016 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.0_017 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.0_018 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.0_019 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.0_020 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.0_021 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.0_022 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.0_023 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.0_024 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.0_025 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.0_026 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.0_027 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.0_028 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.0_029 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.0_030 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.0_031 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.0_032 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.0_033 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.0_034 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.0_035 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.0_036 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.0_037 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.0_038 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.0_039 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.0_040 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.0_041 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.0_042 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.0_043 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.0_044 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.0_045 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.0_046 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.0_047 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.0_048 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.0_049 does not exist
# /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/K-3-3_SVRG_0.0_000
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.5_000 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.5_001 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.5_002 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.5_003 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.5_004 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.5_005 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.5_006 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.5_007 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.5_008 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.5_009 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.5_010 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.5_011 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.5_012 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.5_013 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.5_014 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.5_015 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.5_016 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.5_017 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.5_018 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.5_019 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.5_020 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.5_021 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.5_022 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.5_023 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.5_024 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.5_025 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.5_026 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.5_027 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.5_028 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.5_029 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.5_030 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.5_031 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.5_032 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.5_033 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.5_034 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.5_035 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.5_036 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.5_037 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.5_038 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.5_039 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.5_040 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.5_041 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.5_042 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.5_043 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.5_044 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.5_045 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.5_046 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.5_047 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.5_048 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_0.5_049 does not exist
# /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/K-3-3_SVRG_0.5_000
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_1.0_000 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_1.0_001 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_1.0_002 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_1.0_003 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_1.0_004 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_1.0_005 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_1.0_006 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_1.0_007 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_1.0_008 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_1.0_009 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_1.0_010 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_1.0_011 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_1.0_012 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_1.0_013 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_1.0_014 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_1.0_015 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_1.0_016 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_1.0_017 does not exist
# ...
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_1.0_026 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_1.0_027 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_1.0_028 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_1.0_029 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_1.0_030 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_1.0_031 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_1.0_032 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_1.0_033 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_1.0_034 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_1.0_035 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_1.0_036 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_1.0_037 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_1.0_038 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_1.0_039 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_1.0_040 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_1.0_041 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_1.0_042 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_1.0_043 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_1.0_044 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_1.0_045 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_1.0_046 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_1.0_047 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_1.0_048 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_SVRG_1.0_049 does not exist
# /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/K-3-3_SVRG_1.0_000
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_GD_0.0_000 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_GD_0.0_001 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_GD_0.0_002 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_GD_0.0_003 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_GD_0.0_004 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_GD_0.0_005 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_GD_0.0_006 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_GD_0.0_007 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_GD_0.0_008 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_GD_0.0_009 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_GD_0.0_010 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_GD_0.0_011 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_GD_0.0_012 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_GD_0.0_013 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_GD_0.0_014 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_GD_0.0_015 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_GD_0.0_016 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_GD_0.0_017 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_GD_0.0_018 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_GD_0.0_019 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_GD_0.0_020 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_GD_0.0_021 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_GD_0.0_022 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_GD_0.0_023 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_GD_0.0_024 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_GD_0.0_025 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_GD_0.0_026 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_GD_0.0_027 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_GD_0.0_028 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_GD_0.0_029 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_GD_0.0_030 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_GD_0.0_031 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_GD_0.0_032 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_GD_0.0_033 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_GD_0.0_034 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_GD_0.0_035 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_GD_0.0_036 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_GD_0.0_037 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_GD_0.0_038 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_GD_0.0_039 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_GD_0.0_040 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_GD_0.0_041 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_GD_0.0_042 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_GD_0.0_043 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_GD_0.0_044 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_GD_0.0_045 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_GD_0.0_046 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_GD_0.0_047 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_GD_0.0_048 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_GD_0.0_049 does not exist
# /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/K-3-3_GD_0.0_000
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_CG_0.0_000 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_CG_0.0_001 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_CG_0.0_002 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_CG_0.0_003 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_CG_0.0_004 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_CG_0.0_005 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_CG_0.0_006 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_CG_0.0_007 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_CG_0.0_008 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_CG_0.0_009 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_CG_0.0_010 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_CG_0.0_011 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_CG_0.0_012 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_CG_0.0_013 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_CG_0.0_014 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_CG_0.0_015 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_CG_0.0_016 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_CG_0.0_017 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_CG_0.0_018 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_CG_0.0_019 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_CG_0.0_020 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_CG_0.0_021 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_CG_0.0_022 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_CG_0.0_023 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_CG_0.0_024 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_CG_0.0_025 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_CG_0.0_026 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_CG_0.0_027 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_CG_0.0_028 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_CG_0.0_029 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_CG_0.0_030 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_CG_0.0_031 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_CG_0.0_032 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_CG_0.0_033 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_CG_0.0_034 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_CG_0.0_035 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_CG_0.0_036 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_CG_0.0_037 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_CG_0.0_038 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_CG_0.0_039 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_CG_0.0_040 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_CG_0.0_041 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_CG_0.0_042 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_CG_0.0_043 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_CG_0.0_044 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_CG_0.0_045 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_CG_0.0_046 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_CG_0.0_047 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_CG_0.0_048 does not exist
# file /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/case_study_large_K-3-3_CG_0.0_049 does not exist
# /Volumes/One Touch/sublinear-HMM-inference/case_study/large/Nov-14-2022/K-3-3_CG_0.0_000

# %%
max_ll = -np.infty
for _,optim in optims.items():
    print(optim.log_like_trace[-1])
    if optim.log_like_trace[-1] > max_ll:
        self = optim
        max_ll = optim.log_like_trace[-1]

# %% [markdown]
# # Repopulate the parameters

# %%
self.data = data

self.log_alphas = np.zeros((self.T,self.K_total))
self.log_betas = np.zeros((self.T,self.K_total))

# p_Xt and p_Xtm1_Xt
self.p_Xt = np.zeros((self.T,self.K_total))
self.p_Xtm1_Xt = np.zeros((self.T,self.K_total,self.K_total))

# gradients wrt theta
self.grad_theta_t = [deepcopy(self.theta) for _ in range(self.T)]
self.grad_theta = deepcopy(self.theta)

# gradients wrt eta
self.grad_eta_t = [deepcopy(self.eta) for _ in range(self.T)]
self.grad_eta = deepcopy(self.eta)

# gradients wrt eta0
self.grad_eta0_t = [deepcopy(self.eta0) for _ in range(self.T)]
self.grad_eta0 = deepcopy(self.eta0)

self.E_step()
self.get_log_Gamma(jump=False)
self.get_log_Gamma(jump=True)
self.get_log_delta()
# Out:
# array([ -4.99244944,  -8.48552527, -14.11187866,  -0.54805415,
#         -0.91669544,  -8.76662409,  -4.20803873, -10.01822322,
#        -11.03348978])

# %%
display(self.theta)
#display(self.theta_SE)

display(np.exp(helper_funcs.eta_2_log_Gamma(self.eta)[0]))
display(np.exp(helper_funcs.eta_2_log_Gamma(self.eta)[1][0]))
display(np.exp(helper_funcs.eta_2_log_Gamma(self.eta)[1][1]))
display(np.exp(helper_funcs.eta_2_log_Gamma(self.eta)[1][2]))
#display(self.Gamma_SE)

display(np.exp(helper_funcs.eta0_2_log_delta(self.eta0)[0]))
display(np.exp(helper_funcs.eta0_2_log_delta(self.eta0)[1][0]))
display(np.exp(helper_funcs.eta0_2_log_delta(self.eta0)[1][1]))
display(np.exp(helper_funcs.eta0_2_log_delta(self.eta0)[1][2]))
#display(self.delta_SE)
# Out:
# [{'w_low': {'mu': array([2.97495766, 4.01605959, 1.251454  ]),
#    'log_sig': array([0.25589094, 0.18695982, 0.28880355])},
#   'w_high': {'mu': array([ 1.32201815,  3.56996276, -0.87608268]),
#    'log_sig': array([-0.30392055,  0.14127822, -0.21215301])}},
#  {'w_low': {'mu': array([2.97495766, 4.01605959, 1.251454  ]),
#    'log_sig': array([0.25589094, 0.18695982, 0.28880355])},
#   'w_high': {'mu': array([ 1.32201815,  3.56996276, -0.87608268]),
#    'log_sig': array([-0.30392055,  0.14127822, -0.21215301])}},
#  {'w_low': {'mu': array([2.97495766, 4.01605959, 1.251454  ]),
#    'log_sig': array([0.25589094, 0.18695982, 0.28880355])},
#   'w_high': {'mu': array([ 1.32201815,  3.56996276, -0.87608268]),
#    'log_sig': array([-0.30392055,  0.14127822, -0.21215301])}}]
# array([[9.85601224e-01, 1.33688971e-02, 1.02987929e-03],
#        [1.09929051e-02, 9.87776670e-01, 1.23042476e-03],
#        [1.35570124e-03, 5.28724077e-04, 9.98115575e-01]])
# array([[8.78808766e-01, 1.18925581e-01, 2.26565306e-03],
#        [1.12702583e-01, 8.87293768e-01, 3.64866799e-06],
#        [1.56357922e-01, 4.70390690e-03, 8.38938171e-01]])
# array([[9.65083095e-01, 1.94576958e-04, 3.47223285e-02],
#        [2.55327673e-04, 9.99740561e-01, 4.11106390e-06],
#        [1.72702060e-01, 3.64056630e-05, 8.27261534e-01]])
# array([[0.80519821, 0.01472994, 0.18007185],
#        [0.25520305, 0.70144312, 0.04335383],
#        [0.04702669, 0.00170506, 0.95126824]])
# array([0.00699619, 0.97806756, 0.01493625])
# array([9.70386974e-01, 2.95067517e-02, 1.06274035e-04])
# array([5.91036434e-01, 4.08804222e-01, 1.59343620e-04])
# array([0.99593394, 0.00298469, 0.00108137])

# %% [markdown]
# # Plot emission distributions with error bounds

# %%
CB_color_cycle = ['#377eb8', '#ff7f00', '#4daf4a',
                  '#f781bf', '#a65628', '#984ea3',
                  '#999999', '#e41a1c', '#dede00']

# define colors
coarse_colors = [CB_color_cycle[i+self.K[1]] for i in range(self.K[0])]
fine_colors = [CB_color_cycle[i] for i in range(self.K[1])]

K_total = self.K[1]
perc = 0.95

fig,ax = plt.subplots(1,len(self.features),figsize=(10,3))

x_labels = {"diveDuration" : "Dive Duration (s)",
            "maxDepth"     : "Maximum Depth (m)",
            "avg_bot_htv"  : "Average Bottom RHTV (rad/s)",
            "postDiveInt"  : "Post Dive Interval (seconds)",
            "w_low"        : "Wiggliness (low feq)",
            "w_high"       : "Wiggliness (high freq)"}

for fignum,feature in enumerate(self.features):
    
    # get bounds
    min_mu = np.min([theta_fine[feature]['mu'] for theta_fine in self.theta])
    max_mu = np.max([theta_fine[feature]['mu'] for theta_fine in self.theta])
    max_sig = np.exp(np.max([theta_fine[feature]['log_sig'] for theta_fine in self.theta]))
    
    x = np.linspace(min_mu-3*max_sig,max_mu+3*max_sig,1000)
    
    # see if we are using a truncnorm
    a = self.features[feature]["lower_bound"]
    b = self.features[feature]["upper_bound"]
    if not a is None:
        a = np.concatenate([self.features[feature]["lower_bound"] for _ in self.theta])
    if not b is None:
        b = np.concatenate([self.features[feature]["upper_bound"] for _ in self.theta])

    # now get the y values for each x
    y0 = np.zeros((1000,K_total))

    # true ys
    mu = np.concatenate([theta_fine[feature]['mu'] for theta_fine in self.theta])
    sig = np.exp(np.concatenate([theta_fine[feature]['log_sig'] for theta_fine in self.theta]))

    for state in range(K_total):
        if (not a is None) and (not b is None):
            y0[:,state] = truncnorm.pdf(x,a=(a[state]-mu[state])/sig[state],
                                          b=(b[state]-mu[state])/sig[state],
                                          loc=mu[state],scale=sig[state])
        else:
            y0[:,state] = norm.pdf(x,mu[state],sig[state])
    
    if feature == "maxDepth":
        ax[fignum].axvline(np.log(20),color='k',linestyle='--')
        ax[fignum].axvline(np.log(5),color='k',linestyle='--')
    
    for state in range(self.K[1]):
        
        # plot distribution
        ax[fignum].plot(x,y0[:,state],
                        color=CB_color_cycle[state])
        
    # add labels
    if fignum == 0:
        ax[fignum].set_ylabel("Probability Density")

    ax[fignum].set_xlabel(x_labels[feature])
    #ax[fignum].set_xscale('log')
        
leg_labels = ['Production State %d'%(i+1) for i in range(self.K[1])]

legend_elements = [Line2D([0], [0], marker='o', color='w', label=leg_labels[i],
                   markerfacecolor=fine_colors[i], markersize=12) for i in range(self.K[1])]

fig.legend(handles=legend_elements,prop={'size': 10}, ncol=self.K[1], mode="expand", borderaxespad=0.,
             bbox_to_anchor=(0.1, 0.9, 0.8, .1), loc='lower left')

#fig.tight_layout()

fig.savefig(plot_folder+'/emission_dists_K_%d_%d_nWhales_%d.png' % (self.K[0],self.K[1],len(whales)),
            dpi=300,
            bbox_inches='tight')

# %% [markdown]
# # Plot Dive Profiles

# %%
self.p_fine = np.zeros((self.T,self.K[1]))
self.p_coarse = np.zeros((self.T,self.K[0]))

# get p_coarse, p_fine, and CIs
for k0 in range(self.K[0]):
    self.p_coarse[:,k0] = np.sum(self.p_Xt[:,(k0*self.K[1]):((k0+1)*self.K[1])],1)

for k1 in range(self.K[1]):
    self.p_fine[:,k1] = np.sum(self.p_Xt[:,k1::self.K[1]],1)

# %%
whale = "I145"
df0 = df.reset_index().drop("index",axis=1).reset_index()
ind = min(df0[df0.ID == whale]["index"])
span = len(df0[df0.ID == whale]) - 2

print(ind)
print(span)
# Out:
# 72217
# 7677

# %%
for whale in ["I145"]:#whales:
    
    print(whale)

    df0 = df.reset_index().drop("index",axis=1).reset_index()
    ind = min(df0[df0.ID == whale]["index"])
    span = len(df0[df0.ID == whale]) - 2
    
    print(span)

    # get the dive types
    ML_divetype = np.argmax(self.p_fine,1)
    ML_bouttype = np.argmax(self.p_coarse,1)

    # define colors
    coarse_colors = [CB_color_cycle[i+self.K[1]] for i in range(self.K[0])]
    fine_colors = [CB_color_cycle[i] for i in range(self.K[1])]

    fig,ax = plt.subplots(6,1,figsize=(15,15))

    # get legend
    labels = ['Production State 1','Production State 2','Production State 3',
              'Internal State 1','Internal State 2']
    legend_elements = [Line2D([0], [0], marker='o', color='w', label=labels[0],
                                      markerfacecolor=fine_colors[0], markersize=12),
                       Line2D([0], [0], marker='o', color='w', label=labels[1],
                                      markerfacecolor=fine_colors[1], markersize=12),
                       Line2D([0], [0], marker='o', color='w', label=labels[2],
                                      markerfacecolor=fine_colors[2], markersize=12),
                       Line2D([0], [0], marker='o', color='w', label=labels[3],
                                      markerfacecolor=coarse_colors[0], markersize=12),
                       Line2D([0], [0], marker='o', color='w', label=labels[4],
                                      markerfacecolor=coarse_colors[1], markersize=12)]
                       #Patch(facecolor=coarse_colors[0], alpha=0.5, label=labels[4]),
                       #Patch(facecolor=coarse_colors[1], alpha=0.5, label=labels[5])]

    leg_labels = ['Production State %d'%(i+1) for i in range(self.K[1])] + \
                 ['Internal State %d'%(i+1) for i in range(self.K[0])]

    legend_elements = [Line2D([0], [0], marker='o', color='w', label=leg_labels[i],
                       markerfacecolor=fine_colors[i], markersize=12) for i in range(self.K[1])] + \
                      [Line2D([0], [0], marker='o', color='w', label=leg_labels[i+self.K[1]],
                       markerfacecolor=coarse_colors[i], markersize=12) for i in range(self.K[0])]


    s_bout = df["stime"].iloc[ind]
    bouttype = ML_bouttype[ind]

    for divenum in range(ind,ind+span):

        print(divenum)

        # plot dashed line
        dive_df = raw_df[raw_df["Time"] <= df["stime"].iloc[divenum+1]]
        dive_df = dive_df[dive_df["Time"] >= df["stime"].iloc[divenum]]
        dive_df = dive_df

        # plot dive profiles
        ax[0].plot(pd.to_datetime(dive_df["Time"]),
                   dive_df["Elevation"],
                   "k--")

        ax[3].plot(pd.to_datetime(dive_df["Time"]),
                   dive_df["Elevation"],
                   "k--")

        # show color of bout / dive type
        # dive_df = raw_df[raw_df["divenum"] == df["divenum"].iloc[divenum]]

        # plot dive profiles with color
        ax[0].plot(pd.to_datetime(dive_df["Time"]),
                   dive_df["Elevation"],
                   color=fine_colors[ML_divetype[divenum]])

        ax[3].plot(pd.to_datetime(dive_df["Time"]),
                   dive_df["Elevation"],
                   color=coarse_colors[ML_bouttype[divenum]])

        # show probs of fine-scale states
        ax[1].plot(pd.to_datetime(dive_df["Time"]),
                   np.log(dive_df["w_low"]),
                   color=fine_colors[ML_divetype[divenum]])

        ax[4].plot(pd.to_datetime(dive_df["Time"]),
                   np.log(dive_df["w_low"]),
                   color=coarse_colors[ML_bouttype[divenum]])
        
        ax[2].plot(pd.to_datetime(dive_df["Time"]),
                   np.log(dive_df["w_high"]),
                   color=fine_colors[ML_divetype[divenum]])

        ax[5].plot(pd.to_datetime(dive_df["Time"]),
                   np.log(dive_df["w_high"]),
                   color=coarse_colors[ML_bouttype[divenum]])
        
        #ax[1].plot(pd.to_datetime([df.iloc[divenum]["stime"],df.iloc[divenum+1]["stime"]]),
        #           [self.p_fine[divenum,(self.K[1]-1)],self.p_fine[divenum,(self.K[1]-1)]],
        #           color=fine_colors[ML_divetype[divenum]])

        # show probs of coarse-scale states
        #ax[3].plot(pd.to_datetime([df.iloc[divenum]["stime"],df.iloc[divenum+1]["stime"]]),
        #           [self.p_coarse[divenum,(self.K[0]-1)],self.p_coarse[divenum,(self.K[0]-1)]],
        #            color=coarse_colors[ML_bouttype[divenum]])

    # draw lines for probabilites
    #ax[3].plot([df["stime"].iloc[ind],df["stime"].iloc[ind+span]],[0.5,0.5],'k--')
    #ax[1].plot([df["stime"].iloc[ind],df["stime"].iloc[ind+span]],[0.5,0.5],'k--')

    # position legend
    ax[0].legend(handles=legend_elements,prop={'size': 14}, ncol=3, mode="expand", borderaxespad=0.,
                 bbox_to_anchor=(0., 1.01, 1., .102), loc='lower left')

    for ax0 in ax:
        ax0.set_xticks([])

    ax[0].set_ylabel('Depth (m)',fontsize=16)
    #ax[1].set_ylabel(r'$P(S_t = %d)$'%self.K[1],fontsize=16)
    ax[1].set_ylabel('low freq',fontsize=16)
    ax[2].set_ylabel('high freq',fontsize=16)

    ax[3].set_ylabel('Depth (m)',fontsize=16)
    #ax[3].set_ylabel(r'$P(H_t = %d)$'%self.K[0],fontsize=16)
    ax[4].set_ylabel('low freq',fontsize=16)
    ax[5].set_ylabel('high freq',fontsize=16)

    #ax[1].set_ylim([-0.1,1.1])
    #ax[3].set_ylim([-0.1,1.1])

    ax[0].yaxis.set_major_locator(plt.MaxNLocator(5))
    ax[1].yaxis.set_major_locator(plt.MaxNLocator(5))
    ax[2].yaxis.set_major_locator(plt.MaxNLocator(5))
    ax[3].yaxis.set_major_locator(plt.MaxNLocator(5))
    ax[4].yaxis.set_major_locator(plt.MaxNLocator(5))
    ax[5].yaxis.set_major_locator(plt.MaxNLocator(5))

    ax[-1].set_xlabel("Time on August 30, 2020",fontsize=16)
    ax[-1].xaxis.set_major_locator(plt.MaxNLocator(10))
    ax[-1].xaxis.set_major_formatter(DateFormatter('%H:%M'))

    for ax0 in ax:
        ax0.yaxis.tick_right()
        for item in ax0.get_yticklabels():
            item.set_fontsize(14)
        for item in ax0.get_xticklabels():
            item.set_fontsize(14)

    plt.tight_layout()
    plt.savefig(plot_folder+'/decoded_dives_kw_%s_K_%d_%d_nWhales_%d.png'%(whale,self.K[0],self.K[1],len(whales)),dpi=300)
    plt.show()
# Out:
# I145
# 7677
# 72217
# 72218
# 72219
# 72220
# 72221
# 72222
# 72223
# 72224
# 72225
# 72226
# 72227
# 72228
# 72229
# 72230
# 72231
# 72232
# 72233
# 72234
# 72235
# 72236
# 72237
# 72238
# 72239
# 72240
# 72241
# 72242
# 72243
# 72244
# 72245
# 72246
# 72247
# 72248
# 72249
# 72250
# 72251
# 72252
# 72253
# 72254
# 72255
# 72256
# 72257
# 72258
# 72259
# 72260
# 72261
# 72262
# 72263
# 72264
# 72265
# 72266
# 72267
# 72268
# 72269
# 72270
# 72271
# 72272
# 72273
# 72274
# 72275
# 72276
# 72277
# 72278
# 72279
# 72280
# 72281
# 72282
# 72283
# 72284
# 72285
# 72286
# 72287
# 72288
# 72289
# 72290
# 72291
# 72292
# 72293
# 72294
# 72295
# 72296
# 72297
# 72298
# 72299
# 72300
# 72301
# 72302
# 72303
# 72304
# 72305
# 72306
# 72307
# 72308
# 72309
# 72310
# 72311
# 72312
# 72313
# 72314
# 72315
# 72316
# 72317
# 72318
# 72319
# 72320
# 72321
# 72322
# 72323
# 72324
# 72325
# 72326
# 72327
# 72328
# 72329
# 72330
# 72331
# 72332
# 72333
# 72334
# 72335
# 72336
# 72337
# 72338
# 72339
# 72340
# 72341
# 72342
# 72343
# 72344
# 72345
# 72346
# 72347
# 72348
# 72349
# 72350
# 72351
# 72352
# 72353
# 72354
# 72355
# 72356
# 72357
# 72358
# 72359
# 72360
# 72361
# 72362
# 72363
# 72364
# 72365
# 72366
# 72367
# 72368
# 72369
# 72370
# 72371
# 72372
# 72373
# 72374
# 72375
# 72376
# 72377
# 72378
# 72379
# 72380
# 72381
# 72382
# 72383
# 72384
# 72385
# 72386
# 72387
# 72388
# 72389
# 72390
# 72391
# 72392
# 72393
# 72394
# 72395
# 72396
# 72397
# 72398
# 72399
# 72400
# 72401
# 72402
# 72403
# 72404
# 72405
# 72406
# 72407
# 72408
# 72409
# 72410
# 72411
# 72412
# 72413
# 72414
# 72415
# 72416
# 72417
# 72418
# 72419
# 72420
# 72421
# 72422
# 72423
# 72424
# 72425
# 72426
# 72427
# 72428
# 72429
# 72430
# 72431
# 72432
# 72433
# 72434
# 72435
# 72436
# 72437
# 72438
# 72439
# 72440
# 72441
# 72442
# 72443
# 72444
# 72445
# 72446
# 72447
# 72448
# 72449
# 72450
# 72451
# 72452
# 72453
# 72454
# 72455
# 72456
# 72457
# 72458
# 72459
# 72460
# 72461
# 72462
# 72463
# 72464
# 72465
# 72466
# 72467
# 72468
# 72469
# 72470
# 72471
# 72472
# 72473
# 72474
# 72475
# 72476
# 72477
# 72478
# 72479
# 72480
# 72481
# 72482
# 72483
# 72484
# 72485
# 72486
# 72487
# 72488
# 72489
# 72490
# 72491
# 72492
# 72493
# 72494
# 72495
# 72496
# 72497
# 72498
# 72499
# 72500
# 72501
# 72502
# 72503
# 72504
# 72505
# 72506
# 72507
# 72508
# 72509
# 72510
# 72511
# 72512
# 72513
# 72514
# 72515
# 72516
# 72517
# 72518
# 72519
# 72520
# 72521
# 72522
# 72523
# 72524
# 72525
# 72526
# 72527
# 72528
# 72529
# 72530
# 72531
# 72532
# 72533
# 72534
# 72535
# 72536
# 72537
# 72538
# 72539
# 72540
# 72541
# 72542
# 72543
# 72544
# 72545
# 72546
# 72547
# 72548
# 72549
# 72550
# 72551
# 72552
# 72553
# 72554
# 72555
# 72556
# 72557
# 72558
# 72559
# 72560
# 72561
# 72562
# 72563
# 72564
# 72565
# 72566
# 72567
# 72568
# 72569
# 72570
# 72571
# 72572
# 72573
# 72574
# 72575
# 72576
# 72577
# 72578
# 72579
# 72580
# 72581
# 72582
# 72583
# 72584
# 72585
# 72586
# 72587
# 72588
# 72589
# 72590
# 72591
# 72592
# 72593
# 72594
# 72595
# 72596
# 72597
# 72598
# 72599
# 72600
# 72601
# 72602
# 72603
# 72604
# 72605
# 72606
# 72607
# 72608
# 72609
# 72610
# 72611
# 72612
# 72613
# 72614
# 72615
# 72616
# 72617
# 72618
# 72619
# 72620
# 72621
# 72622
# 72623
# 72624
# 72625
# 72626
# 72627
# 72628
# 72629
# 72630
# 72631
# 72632
# 72633
# 72634
# 72635
# 72636
# 72637
# 72638
# 72639
# 72640
# 72641
# 72642
# 72643
# 72644
# 72645
# 72646
# 72647
# 72648
# 72649
# 72650
# 72651
# 72652
# 72653
# 72654
# 72655
# 72656
# 72657
# 72658
# 72659
# 72660
# 72661
# 72662
# 72663
# 72664
# 72665
# 72666
# 72667
# 72668
# 72669
# 72670
# 72671
# 72672
# 72673
# 72674
# 72675
# 72676
# 72677
# 72678
# 72679
# 72680
# 72681
# 72682
# 72683
# 72684
# 72685
# 72686
# 72687
# 72688
# 72689
# 72690
# 72691
# 72692
# 72693
# 72694
# 72695
# 72696
# 72697
# 72698
# 72699
# 72700
# 72701
# 72702
# 72703
# 72704
# 72705
# 72706
# 72707
# 72708
# 72709
# 72710
# 72711
# 72712
# 72713
# 72714
# 72715
# 72716
# 72717
# 72718
# 72719
# 72720
# 72721
# 72722
# 72723
# 72724
# 72725
# 72726
# 72727
# 72728
# 72729
# 72730
# 72731
# 72732
# 72733
# 72734
# 72735
# 72736
# 72737
# 72738
# 72739
# 72740
# 72741
# 72742
# 72743
# 72744
# 72745
# 72746
# 72747
# 72748
# 72749
# 72750
# 72751
# 72752
# 72753
# 72754
# 72755
# 72756
# 72757
# 72758
# 72759
# 72760
# 72761
# 72762
# 72763
# 72764
# 72765
# 72766
# 72767
# 72768
# 72769
# 72770
# 72771
# 72772
# 72773
# 72774
# 72775
# 72776
# 72777
# 72778
# 72779
# 72780
# 72781
# 72782
# 72783
# 72784
# 72785
# 72786
# 72787
# 72788
# 72789
# 72790
# 72791
# 72792
# 72793
# 72794
# 72795
# 72796
# 72797
# 72798
# 72799
# 72800
# 72801
# 72802
# 72803
# 72804
# 72805
# 72806
# 72807
# 72808
# 72809
# 72810
# 72811
# 72812
# 72813
# 72814
# 72815
# 72816
# 72817
# 72818
# 72819
# 72820
# 72821
# 72822
# 72823
# 72824
# 72825
# 72826
# 72827
# 72828
# 72829
# 72830
# 72831
# 72832
# 72833
# 72834
# 72835
# 72836
# 72837
# 72838
# 72839
# 72840
# 72841
# 72842
# 72843
# 72844
# 72845
# 72846
# 72847
# 72848
# 72849
# 72850
# 72851
# 72852
# 72853
# 72854
# 72855
# 72856
# 72857
# 72858
# 72859
# 72860
# 72861
# 72862
# 72863
# 72864
# 72865
# 72866
# 72867
# 72868
# 72869
# 72870
# 72871
# 72872
# 72873
# 72874
# 72875
# 72876
# 72877
# 72878
# 72879
# 72880
# 72881
# 72882
# 72883
# 72884
# 72885
# 72886
# 72887
# 72888
# 72889
# 72890
# 72891
# 72892
# 72893
# 72894
# 72895
# 72896
# 72897
# 72898
# 72899
# 72900
# 72901
# 72902
# 72903
# 72904
# 72905
# 72906
# 72907
# 72908
# 72909
# 72910
# 72911
# 72912
# 72913
# 72914
# 72915
# 72916
# 72917
# 72918
# 72919
# 72920
# 72921
# 72922
# 72923
# 72924
# 72925
# 72926
# 72927
# 72928
# 72929
# 72930
# 72931
# 72932
# 72933
# 72934
# 72935
# 72936
# 72937
# 72938
# 72939
# 72940
# 72941
# 72942
# 72943
# 72944
# 72945
# 72946
# 72947
# 72948
# 72949
# 72950
# 72951
# 72952
# 72953
# 72954
# 72955
# 72956
# 72957
# 72958
# 72959
# 72960
# 72961
# 72962
# 72963
# 72964
# 72965
# 72966
# 72967
# 72968
# 72969
# 72970
# 72971
# 72972
# 72973
# 72974
# 72975
# 72976
# 72977
# 72978
# 72979
# 72980
# 72981
# 72982
# 72983
# 72984
# 72985
# 72986
# 72987
# 72988
# 72989
# 72990
# 72991
# 72992
# 72993
# 72994
# 72995
# 72996
# 72997
# 72998
# 72999
# 73000
# 73001
# 73002
# 73003
# 73004
# 73005
# 73006
# 73007
# 73008
# 73009
# 73010
# 73011
# 73012
# 73013
# 73014
# 73015
# 73016
# 73017
# 73018
# 73019
# 73020
# 73021
# 73022
# 73023
# 73024
# 73025
# 73026
# 73027
# 73028
# 73029
# 73030
# 73031
# 73032
# 73033
# 73034
# 73035
# 73036
# 73037
# 73038
# 73039
# 73040
# 73041
# 73042
# 73043
# 73044
# 73045
# 73046
# 73047
# 73048
# 73049
# 73050
# 73051
# 73052
# 73053
# 73054
# 73055
# 73056
# 73057
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [72], in <cell line: 1>()
#      51 print(divenum)
#      53 # plot dashed line
# ---> 54 dive_df = raw_df[raw_df["Time"] <= df["stime"].iloc[divenum+1]]
#      55 dive_df = dive_df[dive_df["Time"] >= df["stime"].iloc[divenum]]
#      56 dive_df = dive_df
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3496, in DataFrame.__getitem__(self, key)
#    3494 # Do we have a (boolean) 1d indexer?
#    3495 if com.is_bool_indexer(key):
# -> 3496     return self._getitem_bool_array(key)
#    3498 # We are left with two options: a single key, and a collection of keys,
#    3499 # We interpret tuples as collections only for non-MultiIndex
#    3500 is_single_key = isinstance(key, tuple) or not is_list_like(key)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3551, in DataFrame._getitem_bool_array(self, key)
#    3549 key = check_bool_indexer(self.index, key)
#    3550 indexer = key.nonzero()[0]
# -> 3551 return self._take_with_is_copy(indexer, axis=0)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:3716, in NDFrame._take_with_is_copy(self, indices, axis)
#    3708 def _take_with_is_copy(self: NDFrameT, indices, axis=0) -> NDFrameT:
#    3709     """
#    3710     Internal version of the `take` method that sets the `_is_copy`
#    3711     attribute to keep track of the parent dataframe (using in indexing
#    (...)
#    3714     See the docstring of `take` for full explanation of the parameters.
#    3715     """
# -> 3716     result = self.take(indices=indices, axis=axis)
#    3717     # Maybe set copy if we didn't actually change the index.
#    3718     if not result._get_axis(axis).equals(self._get_axis(axis)):
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:3703, in NDFrame.take(self, indices, axis, is_copy, **kwargs)
#    3699 nv.validate_take((), kwargs)
#    3701 self._consolidate_inplace()
# -> 3703 new_data = self._mgr.take(
#    3704     indices, axis=self._get_block_manager_axis(axis), verify=True
#    3705 )
#    3706 return self._constructor(new_data).__finalize__(self, method="take")
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py:900, in BaseBlockManager.take(self, indexer, axis, verify)
#     897 indexer = maybe_convert_indices(indexer, n, verify=verify)
#     899 new_labels = self.axes[axis].take(indexer)
# --> 900 return self.reindex_indexer(
#     901     new_axis=new_labels,
#     902     indexer=indexer,
#     903     axis=axis,
#     904     allow_dups=True,
#     905     consolidate=False,
#     906 )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py:692, in BaseBlockManager.reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, consolidate, only_slice, use_na_proxy)
#     685     new_blocks = self._slice_take_blocks_ax0(
#     686         indexer,
#     687         fill_value=fill_value,
#     688         only_slice=only_slice,
#     689         use_na_proxy=use_na_proxy,
#     690     )
#     691 else:
# --> 692     new_blocks = [
#     693         blk.take_nd(
#     694             indexer,
#     695             axis=1,
#     696             fill_value=(
#     697                 fill_value if fill_value is not None else blk.fill_value
#     698             ),
#     699         )
#     700         for blk in self.blocks
#     701     ]
#     703 new_axes = list(self.axes)
#     704 new_axes[axis] = new_axis
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py:693, in <listcomp>(.0)
#     685     new_blocks = self._slice_take_blocks_ax0(
#     686         indexer,
#     687         fill_value=fill_value,
#     688         only_slice=only_slice,
#     689         use_na_proxy=use_na_proxy,
#     690     )
#     691 else:
#     692     new_blocks = [
# --> 693         blk.take_nd(
#     694             indexer,
#     695             axis=1,
#     696             fill_value=(
#     697                 fill_value if fill_value is not None else blk.fill_value
#     698             ),
#     699         )
#     700         for blk in self.blocks
#     701     ]
#     703 new_axes = list(self.axes)
#     704 new_axes[axis] = new_axis
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/blocks.py:1137, in Block.take_nd(self, indexer, axis, new_mgr_locs, fill_value)
#    1134 else:
#    1135     allow_fill = True
# -> 1137 new_values = algos.take_nd(
#    1138     values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#    1139 )
#    1141 # Called from three places in managers, all of which satisfy
#    1142 #  this assertion
#    1143 assert not (axis == 0 and new_mgr_locs is None)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/array_algos/take.py:117, in take_nd(arr, indexer, axis, fill_value, allow_fill)
#     114     return arr.take(indexer, fill_value=fill_value, allow_fill=allow_fill)
#     116 arr = np.asarray(arr)
# --> 117 return _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/array_algos/take.py:163, in _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#     158     out = np.empty(out_shape, dtype=dtype)
#     160 func = _get_take_nd_function(
#     161     arr.ndim, arr.dtype, out.dtype, axis=axis, mask_info=mask_info
#     162 )
# --> 163 func(arr, indexer, out, fill_value)
#     165 if flip_order:
#     166     out = out.T
#
# KeyboardInterrupt:

# %% [markdown]
# # Plot Pseudoresiduals

# %%
for feature in self.features[1]:

    print(feature)
    
    pseudoresids = self.get_pseudoresids(feature)
        
    plt.hist(pseudoresids,bins=25,density=True,alpha=0.5,color='k')
    x = np.linspace(-5,5,1000)
    plt.plot(x,norm.pdf(x),'k-')
    plt.title("Pseudoresiduals of %s" % x_labels[feature])
    plt.xlabel("Pseudoresidual")
    plt.ylabel("Density")
    plt.savefig('../plt/pseudo_hist_%s_K_%d_%d_nWhales_%d.png'%(feature,self.K[0],self.K[1],len(whales)),dpi=300)
    plt.show()
    
    plt.plot(pseudoresids,'.')
    plt.title("Pseudoresiduals of %s" % x_labels[feature])
    plt.ylabel("Pseudoresidual")
    plt.xlabel(r"t")
    plt.plot(np.zeros_like(pseudoresids),'k--')
    plt.savefig('../plt/pseudo_%s_K_%d_%d_nWhales_%d.png'%(feature,self.K[0],self.K[1],len(whales)),dpi=300)
    plt.show()
    
    sm.qqplot(np.array(pseudoresids), line='45')
    plt.title("Pseudoresidual QQ plot of %s" % x_labels[feature])
    plt.savefig('../plt/pseudo_qq_%s_K_%d_%d_nWhales_%d.png'%(feature,self.K[0],self.K[1],len(whales)),dpi=300)
    plt.show()

# %% [markdown]
# # Save Results
